# %%
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import time

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# # PyTorch
# In this notebook you will gain some hands-on experience with [PyTorch](https://pytorch.org/), one of the major frameworks for deep learning. To install PyTorch. follow [the official installation instructions](https://pytorch.org/get-started/locally/). Make sure that you select the correct OS & select the version with CUDA if your computer supports it.
# If you do not have an Nvidia GPU, you can install the CPU version by setting `CUDA` to `None`.
# However, in this case we recommend using [Google Colab](https://colab.research.google.com/).
# Make sure that you enable GPU acceleration in `Runtime > Change runtime type`.
#
# You will start by re-implementing some common features of deep neural networks (dropout and batch normalization) and then implement a very popular modern architecture for image classification (ResNet) and improve its training loop.

# %% [markdown]
# # 1. Dropout
# Dropout is a form of regularization for neural networks. It works by randomly setting activations (values) to 0, each one with equal probability `p`. The values are then scaled by a factor $\frac{1}{1-p}$ to conserve their mean.
#
# Dropout effectively trains a pseudo-ensemble of models with stochastic gradient descent. During evaluation we want to use the full ensemble and therefore have to turn off dropout. Use `self.training` to check if the model is in training or evaluation mode.
#
# Do not use any dropout implementation from PyTorch for this!

# %%
class Dropout(nn.Module):
    """
    Dropout, as discussed in the lecture and described here:
    https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout
    
    Args:
        p: float, dropout probability
    """
    def __init__(self, p):
        super().__init__()
        self.p = p
        
    def forward(self, input):
        """
        The module's forward pass.
        This has to be implemented for every PyTorch module.
        PyTorch then automatically generates the backward pass
        by dynamically generating the computational graph during
        execution.
        
        Args:
            input: PyTorch tensor, arbitrary shape

        Returns:
            PyTorch tensor, same shape as input
        """
        
        # TODO: Set values randomly to 0.
        size = input.numel()
        stride = np.floor(1/self.p)
        count = 0
        for i in range(size):
            input[int(i*stride)] = 0
            count += 1
            if count == np.floor(size*self.p):
                break
        input[np.where(input!=0)] = input[np.where(input!=0)] / (1-self.p)
        return input

# %%
# Test dropout
test = torch.ones(10_000)
dropout = Dropout(0.5)
test_dropped = dropout(test)

# These assertions can in principle fail due to bad luck, but
# if implemented correctly they should almost always succeed.
assert np.isclose(test_dropped.sum().item(), 10_000, atol=400)
assert np.isclose((test_dropped > 0).sum().item(), 5_000, atol=200)

# %% [markdown]
# # 2. Batch normalization
# Batch normalization is a trick use to smoothen the loss landscape and improve training. It is defined as the function
# $$y = \frac{x - \mu_x}{\sigma_x + \epsilon} \cdot \gamma + \beta$$,
# where $\gamma$ and $\beta$ and learnable parameters and $\epsilon$ is a some small number to avoid dividing by zero. The Statistics $\mu_x$ and $\sigma_x$ are taken separately for each feature. In a CNN this means averaging over the batch and all pixels.
#
# Do not use any batch normalization implementation from PyTorch for this!

# %%
class BatchNorm(nn.Module):
    """
    Batch normalization, as discussed in the lecture and similar to
    https://pytorch.org/docs/stable/nn.html#torch.nn.BatchNorm1d
    
    Only uses batch statistics (no running mean for evaluation).
    Batch statistics are calculated for a single dimension.
    Gamma is initialized as 1, beta as 0.
    
    Args:
        num_features: Number of features to calculate batch statistics for.
    """
    def __init__(self, num_features):
        super().__init__()
        
        # TODO: Initialize the required parameters
        self.gamma = nn.Parameter(torch.ones(num_features,1),requires_grad=False)
        self.beta = nn.Parameter(torch.zeros(num_features,1),requires_grad=False)
        
    def forward(self, input):
        """
        Batch normalization over the dimension C of (N, C, L).
        
        Args:
            input: PyTorch tensor, shape [N, C, L]
            
        Return:
            PyTorch tensor, same shape as input
        """
        eps = 1e-5

        # TODO: Implement the required transformation
        num_N = input.size(0)
        input = input.permute(1,0,2)
        input = np.reshape(input,(2,-1))
        
        input_mean = input.mean(axis=1)
        input_std = torch.std(input, dim=1, unbiased=False)
        input_mean = input_mean[:,None]
        input_std = input_std[:,None]
        
        output= torch.mul(((input-input_mean)/(input_std+eps)), self.gamma) + self.beta

        output = np.reshape(output,(2,num_N,-1)) 
        output = output.permute(1,0,2)
 
        return output

# %%
# Tests the batch normalization implementation
torch.random.manual_seed(42)
test = torch.randn(8, 2, 4)

b1 = BatchNorm(2)
test_b1 = b1(test)

b2 = nn.BatchNorm1d(2, affine=False, track_running_stats=False)
test_b2 = b2(test)
assert torch.allclose(test_b1, test_b2, rtol=0.02)

# %% [markdown]
# # 3. ResNet
# ResNet is the models that first introduced residual connections (a form of skip connections). It is a rather simple, but successful and very popular architecture. In this part of the exercise we will re-implement it step by step.
#
# Note that there is also an [improved version of ResNet](https://arxiv.org/abs/1603.05027) with optimized residual blocks. Here we will implement the [original version](https://arxiv.org/abs/1512.03385) for CIFAR-10. Your dropout and batchnorm implementations won't help you here. Just use PyTorch's own layers.

# %% [markdown]
# This is just a convenience function to make e.g. `nn.Sequential` more flexible. It is e.g. useful in combination with `x.squeeze()`.

# %%
class Lambda(nn.Module):
    def __init__(self, func):
        super().__init__()
        self.func = func

    def forward(self, x):
        return self.func(x)

# %% [markdown]
# We begin by implementing the residual blocks. The block is illustrated by this sketch:
#
# ![Residual connection](img/residual_connection.png)
#
# Note that we use 'SAME' padding, no bias, and batch normalization after each convolution. You do not need `nn.Sequential` here. The skip connection is already implemented as `self.skip`. It can handle different strides and increases in the number of channels.

# %%
class ResidualBlock(nn.Module):
    """
    The residual block used by ResNet.
    
    Args:
        in_channels: The number of channels (feature maps) of the incoming embedding
        out_channels: The number of channels after the first convolution
        stride: Stride size of the first convolution, used for downsampling
    """
    
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()        
        if stride > 1 or in_channels != out_channels:
            # Add strides in the skip connection and zeros for the new channels.
            self.skip = Lambda(lambda x: F.pad(x[:, :, ::stride, ::stride],
                                               (0, 0, 0, 0, 0, out_channels - in_channels),
                                               mode="constant", value=0))
        else:
            self.skip = nn.Sequential()
            
        # TODO: Initialize the required layers
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, bias = False, padding=1)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, bias = False, padding=1)
        self.batchnorm = nn.BatchNorm2d(out_channels,track_running_stats=False)
        
    def forward(self, input):
        # TODO: Execute the required layers and functions
        
        residual = self.conv1(input)
        residual = self.batchnorm(residual)
        residual = F.relu(residual)
        residual = self.conv2(residual)
        residual = self.batchnorm(residual)
        output = F.relu(residual + self.skip(input))
        return output

# %% [markdown]
# Next we implement a stack of residual blocks for convenience. The first layer in the block is the one changing the number of channels and downsampling. You can use `nn.ModuleList` to use a list of child modules.

# %%
class ResidualStack(nn.Module):
    """
    A stack of residual blocks.
    
    Args:
        in_channels: The number of channels (feature maps) of the incoming embedding
        out_channels: The number of channels after the first layer
        stride: Stride size of the first layer, used for downsampling
        num_blocks: Number of residual blocks
    """
    
    def __init__(self, in_channels, out_channels, stride, num_blocks):
        super().__init__()
        
        # TODO: Initialize the required layers (blocks)
        
        self.stack = nn.ModuleList([ResidualBlock(in_channels, out_channels, stride)]) 
        #self.stack.extend([ResidualBlock(in_channels, out_channels, stride)])
        self.stack.extend([ResidualBlock(out_channels, out_channels) for i in range(num_blocks-1)])
        
        """
        self.stack = nn.ModuleList([ResidualBlock(in_channels,out_channels,stride)])
        for i in range (num_blocks - 1):
            self.stack.append(ResidualBlock(out_channels,out_channels))
        """
        
   
    def forward(self, input):
        # TODO: Execute the layers (blocks)
        for m in self.stack:
            input = m(input)  
        return input

# %% [markdown]
# Now we are finally ready to implement the full model! To do this, use the `nn.Sequential` API and carefully read the following paragraph from the paper (Fig. 3 is not important):
#
# ![ResNet CIFAR10 description](img/resnet_cifar10_description.png)
#
# Note that a convolution layer is always convolution + batch norm + activation (ReLU), that each ResidualBlock contains 2 layers, and that you might have to `squeeze` the embedding before the dense (fully-connected) layer.

# %%
n = 5
num_classes = 10

# TODO: Implement ResNet via nn.Sequential
#modules = []
#modules.appen(nn.Conv2d(3, 32*32, kernel_size=3, stride=stride, bias = False))

resnet = nn.Sequential(
    #pic size 32*32
    Lambda(lambda x: x.view(-1, 3, 32, 32)),
    #one extra layer
    nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),
    nn.BatchNorm2d(16,track_running_stats=False),
    nn.ReLU(),

    ResidualStack(16, 16, stride=1, num_blocks=n), #output-shape: 128*16*32*32
    ResidualStack(16, 32, stride=2, num_blocks=n), #pic size 16*16
    ResidualStack(32, 64, stride=2, num_blocks=n), #pic size 8*8
    
    nn.AdaptiveAvgPool2d(1),
    Lambda(lambda x: x.squeeze()),
    nn.Linear(64, num_classes),
    #nn.Softmax(dim=1),
    
)

# %% [markdown]
# Next we need to initialize the weights of our model.

# %%
def initialize_weight(module):
    if isinstance(module, (nn.Linear, nn.Conv2d)):
        nn.init.kaiming_normal_(module.weight, nonlinearity='relu')
    elif isinstance(module, nn.BatchNorm2d):
        nn.init.constant_(module.weight, 1)
        nn.init.constant_(module.bias, 0)
        
resnet.apply(initialize_weight);

# %% [markdown]
# # 4. Training
# So now we have a shiny new model, but that doesn't really help when we can't train it. So that's what we do next.
#
# First we need to load the data. Note that we split the official training data into train and validation sets, because you must not look at the test set until you are completely done developing your model and report the final results. Some people don't do this properly, but you should not copy other people's bad habits.

# %%
class CIFAR10Subset(torchvision.datasets.CIFAR10):
    """
    Get a subset of the CIFAR10 dataset, according to the passed indices.
    """
    def __init__(self, *args, idx=None, **kwargs):
        super().__init__(*args, **kwargs)
        
        if idx is None:
            return
        
        self.data = self.data[idx]
        targets_np = np.array(self.targets)
        self.targets = targets_np[idx].tolist()

# %% [markdown]
# We next define transformations that change the images into PyTorch tensors, standardize the values according to the precomputed mean and standard deviation, and provide data augmentation for the training set.

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, 4),
    transforms.ToTensor(),
    normalize,
])
transform_eval = transforms.Compose([
    transforms.ToTensor(),
    normalize
])

# %%
ntrain = 45_000
train_set = CIFAR10Subset(root='./data', train=True, idx=range(ntrain),
                          download=True, transform=transform_train)
val_set = CIFAR10Subset(root='./data', train=True, idx=range(ntrain, 50_000),
                        download=True, transform=transform_eval)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False,
                                        download=True, transform=transform_eval)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataloaders = {}
dataloaders['train'] = torch.utils.data.DataLoader(train_set, batch_size=128,
                                                   shuffle=True, num_workers=2,
                                                   pin_memory=True)
dataloaders['val'] = torch.utils.data.DataLoader(val_set, batch_size=128,
                                                 shuffle=False, num_workers=2,
                                                 pin_memory=True)
dataloaders['test'] = torch.utils.data.DataLoader(test_set, batch_size=128,
                                                  shuffle=False, num_workers=2,
                                                  pin_memory=True)

# %% [markdown]
# Next we push the model to our GPU (if there is one).

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
resnet.to(device);

# %% [markdown]
# Next we define a helper method that does one epoch of training or evaluation. We have only defined training here, so you need to implement the necessary changes for evaluation!

# %%
def run_epoch(model, optimizer, dataloader, train):
    """
    Run one epoch of training or evaluation.
    
    Args:
        model: The model used for prediction
        optimizer: Optimization algorithm for the model
        dataloader: Dataloader providing the data to run our model on
        train: Whether this epoch is used for training or evaluation
        
    Returns:
        Loss and accuracy in this epoch.
    """
    # TODO: Change the necessary parts to work correctly during evaluation (train=False)   
    device = next(model.parameters()).device  
    epoch_loss = 0.0
    epoch_acc = 0.0
    #print("size of dataloader: ", len(dataloader))
    
    if train:
        model.train()
        # Iterate over data
        for xb, yb in dataloader:
            xb, yb = xb.to(device), yb.to(device)
            #print(len(dataloader))

            # forward
            #with torch.set_grad_enabled(True):
            pred = model(xb)
            loss = F.cross_entropy(pred, yb)
            top1 = torch.argmax(pred, dim=1)
            ncorrect = torch.sum(top1 == yb)
            #print("correct number", ncorrect)
        
            # zero the parameter gradients
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # statistics
            epoch_loss += loss.item()
            epoch_acc += ncorrect.item()
        
    else:
        model.eval()
        # Iterate over data
        for xb, yb in dataloader:
            xb, yb = xb.to(device), yb.to(device)
            #print(len(dataloader))

            # forward
            pred = model(xb)
            loss = F.cross_entropy(pred, yb)
            top1 = torch.argmax(pred, dim=1)
            ncorrect = torch.sum(top1 == yb)
            #print("correct number", ncorrect)

            # statistics
            epoch_loss += loss.item()
            epoch_acc += ncorrect.item()
 
    epoch_loss /= len(dataloader.dataset)
    epoch_acc /= len(dataloader.dataset)
    #print("loss: ", epoch_loss)
    return epoch_loss, epoch_acc

# %% [markdown]
# Next we implement a method for fitting (training) our model. For many models early stopping can save a lot of training time. Your task is to add early stopping to the loop (based on validation accuracy). Early stopping usually means exiting the training loop if the validation accuracy hasn't improved for `patience` number of steps. Don't forget to save the best model parameters according to validation accuracy. You will need `copy.deepcopy` and the `state_dict` for this.

# %%
def fit(model, optimizer, lr_scheduler, dataloaders, max_epochs, patience):
    """
    Fit the given model on the dataset.
    
    Args:
        model: The model used for prediction
        optimizer: Optimization algorithm for the model
        lr_scheduler: Learning rate scheduler that improves training
                      in late epochs with learning rate decay
        dataloaders: Dataloaders for training and validation
        max_epochs: Maximum number of epochs for training
        patience: Number of epochs to wait with early stopping the
                  training if validation loss has decreased
                  
    Returns:
        Loss and accuracy in this epoch.
    """
    
    best_acc = 0
    curr_patience = patience
    
    for epoch in range(max_epochs):
        train_loss, train_acc = run_epoch(model, optimizer, dataloaders['train'], train=True)
        lr_scheduler.step()
        print(f"Epoch {epoch + 1: >3}/{max_epochs}, train loss: {train_loss:.2e}, accuracy: {train_acc * 100:.2f}%")
        
        val_loss, val_acc = run_epoch(model, None, dataloaders['val'], train=False)
        print(f"Epoch {epoch + 1: >3}/{max_epochs}, val loss: {val_loss:.2e}, accuracy: {val_acc * 100:.2f}%")
        
        # TODO: Add early stopping and save the best weights (in best_model_weights)
        if val_acc > best_acc:
            curr_patience = patience
            best_acc = val_acc
            best_model_weights = copy.deepcopy(model.state_dict())
        else:
            curr_patience -= 1
            if curr_patience <= 0:
                print("early stopping")
                break
    
    model.load_state_dict(best_model_weights)

# %% [markdown]
# In most cases you should just use the Adam optimizer for training, because it works well out of the box. However, a well-tuned SGD (with momentum) will in most cases outperform Adam. And since the original paper gives us a well-tuned SGD we will just use that.

# %%
optimizer = torch.optim.SGD(resnet.parameters(), lr=0.1, momentum=0.9, weight_decay=1e-4)
lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[100, 150], gamma=0.1)

# Fit model
fit(resnet, optimizer, lr_scheduler, dataloaders, max_epochs=200, patience=100)
# Out:
# Epoch   1/200, train loss: 1.54e-02, accuracy: 29.58%
# Epoch   1/200, val loss: 1.25e-02, accuracy: 43.16%
# Epoch   2/200, train loss: 1.10e-02, accuracy: 48.73%
# Epoch   2/200, val loss: 9.80e-03, accuracy: 56.16%
# Epoch   3/200, train loss: 8.82e-03, accuracy: 59.74%
# Epoch   3/200, val loss: 8.44e-03, accuracy: 63.26%
# Epoch   4/200, train loss: 7.42e-03, accuracy: 66.39%
# Epoch   4/200, val loss: 7.56e-03, accuracy: 67.96%
# Epoch   5/200, train loss: 6.42e-03, accuracy: 71.24%
# Epoch   5/200, val loss: 6.97e-03, accuracy: 70.64%
# Epoch   6/200, train loss: 5.68e-03, accuracy: 74.73%
# Epoch   6/200, val loss: 6.26e-03, accuracy: 73.78%
# Epoch   7/200, train loss: 5.17e-03, accuracy: 77.07%
# Epoch   7/200, val loss: 5.55e-03, accuracy: 76.90%
# Epoch   8/200, train loss: 4.76e-03, accuracy: 78.78%
# Epoch   8/200, val loss: 5.61e-03, accuracy: 77.26%
# Epoch   9/200, train loss: 4.47e-03, accuracy: 80.14%
# Epoch   9/200, val loss: 5.52e-03, accuracy: 77.78%
# Epoch  10/200, train loss: 4.25e-03, accuracy: 81.24%
# Epoch  10/200, val loss: 5.21e-03, accuracy: 79.12%
# Epoch  11/200, train loss: 4.01e-03, accuracy: 82.21%
# Epoch  11/200, val loss: 5.12e-03, accuracy: 79.84%
# Epoch  12/200, train loss: 3.85e-03, accuracy: 82.96%
# Epoch  12/200, val loss: 5.05e-03, accuracy: 79.74%
# Epoch  13/200, train loss: 3.67e-03, accuracy: 83.74%
# Epoch  13/200, val loss: 5.11e-03, accuracy: 79.38%
# Epoch  14/200, train loss: 3.49e-03, accuracy: 84.50%
# Epoch  14/200, val loss: 5.00e-03, accuracy: 79.90%
# Epoch  15/200, train loss: 3.37e-03, accuracy: 84.91%
# Epoch  15/200, val loss: 5.04e-03, accuracy: 80.20%
# Epoch  16/200, train loss: 3.25e-03, accuracy: 85.55%
# Epoch  16/200, val loss: 4.81e-03, accuracy: 80.78%
# Epoch  17/200, train loss: 3.15e-03, accuracy: 85.96%
# Epoch  17/200, val loss: 4.72e-03, accuracy: 80.86%
# Epoch  18/200, train loss: 3.03e-03, accuracy: 86.64%
# Epoch  18/200, val loss: 4.69e-03, accuracy: 81.92%
# Epoch  19/200, train loss: 2.94e-03, accuracy: 86.89%
# Epoch  19/200, val loss: 4.48e-03, accuracy: 81.10%
# Epoch  20/200, train loss: 2.88e-03, accuracy: 87.22%
# Epoch  20/200, val loss: 4.87e-03, accuracy: 81.10%
# Epoch  21/200, train loss: 2.81e-03, accuracy: 87.41%
# Epoch  21/200, val loss: 4.55e-03, accuracy: 81.94%
# Epoch  22/200, train loss: 2.72e-03, accuracy: 88.04%
# Epoch  22/200, val loss: 4.49e-03, accuracy: 82.52%
# Epoch  23/200, train loss: 2.62e-03, accuracy: 88.49%
# Epoch  23/200, val loss: 4.34e-03, accuracy: 82.74%
# Epoch  24/200, train loss: 2.58e-03, accuracy: 88.75%
# Epoch  24/200, val loss: 4.24e-03, accuracy: 83.02%
# Epoch  25/200, train loss: 2.50e-03, accuracy: 88.83%
# Epoch  25/200, val loss: 4.42e-03, accuracy: 83.46%
# Epoch  26/200, train loss: 2.51e-03, accuracy: 88.78%
# Epoch  26/200, val loss: 4.62e-03, accuracy: 81.94%
# Epoch  27/200, train loss: 2.44e-03, accuracy: 89.26%
# Epoch  27/200, val loss: 4.07e-03, accuracy: 83.56%
# Epoch  28/200, train loss: 2.44e-03, accuracy: 89.09%
# Epoch  28/200, val loss: 4.55e-03, accuracy: 81.72%
# Epoch  29/200, train loss: 2.33e-03, accuracy: 89.79%
# Epoch  29/200, val loss: 4.11e-03, accuracy: 83.68%
# Epoch  30/200, train loss: 2.33e-03, accuracy: 89.49%
# Epoch  30/200, val loss: 4.82e-03, accuracy: 82.10%
# Epoch  31/200, train loss: 2.27e-03, accuracy: 89.81%
# Epoch  31/200, val loss: 4.43e-03, accuracy: 83.16%
# Epoch  32/200, train loss: 2.24e-03, accuracy: 89.95%
# Epoch  32/200, val loss: 3.92e-03, accuracy: 83.82%
# Epoch  33/200, train loss: 2.17e-03, accuracy: 90.52%
# Epoch  33/200, val loss: 4.52e-03, accuracy: 82.78%
# Epoch  34/200, train loss: 2.14e-03, accuracy: 90.54%
# Epoch  34/200, val loss: 4.49e-03, accuracy: 82.72%
# Epoch  35/200, train loss: 2.11e-03, accuracy: 90.58%
# Epoch  35/200, val loss: 4.27e-03, accuracy: 83.00%
# Epoch  36/200, train loss: 2.11e-03, accuracy: 90.55%
# Epoch  36/200, val loss: 4.37e-03, accuracy: 82.96%
# Epoch  37/200, train loss: 2.04e-03, accuracy: 90.69%
# Epoch  37/200, val loss: 4.36e-03, accuracy: 83.46%
# Epoch  38/200, train loss: 2.08e-03, accuracy: 90.78%
# Epoch  38/200, val loss: 4.38e-03, accuracy: 82.66%
# Epoch  39/200, train loss: 1.97e-03, accuracy: 91.18%
# Epoch  39/200, val loss: 4.18e-03, accuracy: 84.62%
# Epoch  40/200, train loss: 2.01e-03, accuracy: 91.13%
# Epoch  40/200, val loss: 4.18e-03, accuracy: 84.18%
# Epoch  41/200, train loss: 2.00e-03, accuracy: 90.97%
# Epoch  41/200, val loss: 4.13e-03, accuracy: 84.60%
# Epoch  42/200, train loss: 1.95e-03, accuracy: 91.18%
# Epoch  42/200, val loss: 4.61e-03, accuracy: 83.28%
# Epoch  43/200, train loss: 1.93e-03, accuracy: 91.34%
# Epoch  43/200, val loss: 4.76e-03, accuracy: 82.26%
# Epoch  44/200, train loss: 1.91e-03, accuracy: 91.48%
# Epoch  44/200, val loss: 4.57e-03, accuracy: 83.00%
# Epoch  45/200, train loss: 1.90e-03, accuracy: 91.49%
# Epoch  45/200, val loss: 4.32e-03, accuracy: 83.18%
# Epoch  46/200, train loss: 1.92e-03, accuracy: 91.46%
# Epoch  46/200, val loss: 4.18e-03, accuracy: 84.26%
# Epoch  47/200, train loss: 1.84e-03, accuracy: 91.74%
# Epoch  47/200, val loss: 4.06e-03, accuracy: 84.68%
# Epoch  48/200, train loss: 1.85e-03, accuracy: 91.56%
# Epoch  48/200, val loss: 4.30e-03, accuracy: 84.18%
# Epoch  49/200, train loss: 1.81e-03, accuracy: 91.86%
# Epoch  49/200, val loss: 4.61e-03, accuracy: 83.30%
# Epoch  50/200, train loss: 1.77e-03, accuracy: 92.03%
# Epoch  50/200, val loss: 4.45e-03, accuracy: 83.08%
# Epoch  51/200, train loss: 1.79e-03, accuracy: 92.01%
# Epoch  51/200, val loss: 4.41e-03, accuracy: 84.50%
# Epoch  52/200, train loss: 1.76e-03, accuracy: 92.03%
# Epoch  52/200, val loss: 4.24e-03, accuracy: 84.16%
# Epoch  53/200, train loss: 1.75e-03, accuracy: 92.11%
# Epoch  53/200, val loss: 4.74e-03, accuracy: 83.70%
# Epoch  54/200, train loss: 1.76e-03, accuracy: 92.17%
# Epoch  54/200, val loss: 4.20e-03, accuracy: 84.36%
# Epoch  55/200, train loss: 1.72e-03, accuracy: 92.24%
# Epoch  55/200, val loss: 4.20e-03, accuracy: 84.32%
# Epoch  56/200, train loss: 1.71e-03, accuracy: 92.18%
# Epoch  56/200, val loss: 4.31e-03, accuracy: 84.60%
# Epoch  57/200, train loss: 1.69e-03, accuracy: 92.28%
# Epoch  57/200, val loss: 4.35e-03, accuracy: 84.44%
# Epoch  58/200, train loss: 1.71e-03, accuracy: 92.41%
# Epoch  58/200, val loss: 4.12e-03, accuracy: 84.66%
# Epoch  59/200, train loss: 1.65e-03, accuracy: 92.64%
# Epoch  59/200, val loss: 4.67e-03, accuracy: 84.56%
# Epoch  60/200, train loss: 1.67e-03, accuracy: 92.46%
# Epoch  60/200, val loss: 4.39e-03, accuracy: 83.60%
# Epoch  61/200, train loss: 1.66e-03, accuracy: 92.49%
# Epoch  61/200, val loss: 4.43e-03, accuracy: 84.04%
# Epoch  62/200, train loss: 1.63e-03, accuracy: 92.63%
# Epoch  62/200, val loss: 4.41e-03, accuracy: 84.32%
# Epoch  63/200, train loss: 1.60e-03, accuracy: 92.89%
# Epoch  63/200, val loss: 4.43e-03, accuracy: 84.28%
# Epoch  64/200, train loss: 1.60e-03, accuracy: 92.76%
# Epoch  64/200, val loss: 4.26e-03, accuracy: 84.70%
# Epoch  65/200, train loss: 1.63e-03, accuracy: 92.70%
# Epoch  65/200, val loss: 4.38e-03, accuracy: 83.90%
# Epoch  66/200, train loss: 1.58e-03, accuracy: 92.87%
# Epoch  66/200, val loss: 4.38e-03, accuracy: 84.36%
# Epoch  67/200, train loss: 1.60e-03, accuracy: 92.75%
# Epoch  67/200, val loss: 4.27e-03, accuracy: 84.50%
# Epoch  68/200, train loss: 1.61e-03, accuracy: 92.78%
# Epoch  68/200, val loss: 4.47e-03, accuracy: 84.16%
# Epoch  69/200, train loss: 1.53e-03, accuracy: 93.13%
# Epoch  69/200, val loss: 4.35e-03, accuracy: 84.80%
# Epoch  70/200, train loss: 1.59e-03, accuracy: 92.77%
# Epoch  70/200, val loss: 4.64e-03, accuracy: 83.28%
# Epoch  71/200, train loss: 1.56e-03, accuracy: 92.88%
# Epoch  71/200, val loss: 4.88e-03, accuracy: 82.72%
# Epoch  72/200, train loss: 1.57e-03, accuracy: 92.85%
# Epoch  72/200, val loss: 4.51e-03, accuracy: 84.52%
# Epoch  73/200, train loss: 1.57e-03, accuracy: 92.84%
# Epoch  73/200, val loss: 4.64e-03, accuracy: 83.12%
# Epoch  74/200, train loss: 1.52e-03, accuracy: 93.09%
# Epoch  74/200, val loss: 4.62e-03, accuracy: 83.46%
# Epoch  75/200, train loss: 1.55e-03, accuracy: 92.92%
# Epoch  75/200, val loss: 4.32e-03, accuracy: 84.10%
# Epoch  76/200, train loss: 1.51e-03, accuracy: 93.30%
# Epoch  76/200, val loss: 4.39e-03, accuracy: 84.26%
# Epoch  77/200, train loss: 1.49e-03, accuracy: 93.36%
# Epoch  77/200, val loss: 4.21e-03, accuracy: 85.16%
# Epoch  78/200, train loss: 1.50e-03, accuracy: 93.19%
# Epoch  78/200, val loss: 4.33e-03, accuracy: 84.60%
# Epoch  79/200, train loss: 1.49e-03, accuracy: 93.28%
# Epoch  79/200, val loss: 4.28e-03, accuracy: 84.28%
# Epoch  80/200, train loss: 1.49e-03, accuracy: 93.32%
# Epoch  80/200, val loss: 4.85e-03, accuracy: 82.72%
# Epoch  81/200, train loss: 1.49e-03, accuracy: 93.19%
# Epoch  81/200, val loss: 4.11e-03, accuracy: 84.74%
# Epoch  82/200, train loss: 1.48e-03, accuracy: 93.38%
# Epoch  82/200, val loss: 4.68e-03, accuracy: 83.94%
# Epoch  83/200, train loss: 1.53e-03, accuracy: 92.98%
# Epoch  83/200, val loss: 4.33e-03, accuracy: 84.86%
# Epoch  84/200, train loss: 1.45e-03, accuracy: 93.50%
# Epoch  84/200, val loss: 4.40e-03, accuracy: 84.42%
# Epoch  85/200, train loss: 1.48e-03, accuracy: 93.36%
# Epoch  85/200, val loss: 3.98e-03, accuracy: 85.36%
# Epoch  86/200, train loss: 1.44e-03, accuracy: 93.65%
# Epoch  86/200, val loss: 4.42e-03, accuracy: 83.90%
# Epoch  87/200, train loss: 1.45e-03, accuracy: 93.44%
# Epoch  87/200, val loss: 4.73e-03, accuracy: 83.30%
# Epoch  88/200, train loss: 1.49e-03, accuracy: 93.24%
# Epoch  88/200, val loss: 4.46e-03, accuracy: 84.46%
# Epoch  89/200, train loss: 1.44e-03, accuracy: 93.47%
# Epoch  89/200, val loss: 4.35e-03, accuracy: 84.18%
# Epoch  90/200, train loss: 1.45e-03, accuracy: 93.47%
# Epoch  90/200, val loss: 4.16e-03, accuracy: 84.70%
# Epoch  91/200, train loss: 1.44e-03, accuracy: 93.50%
# Epoch  91/200, val loss: 4.88e-03, accuracy: 83.36%
# Epoch  92/200, train loss: 1.43e-03, accuracy: 93.59%
# Epoch  92/200, val loss: 4.02e-03, accuracy: 84.86%
# Epoch  93/200, train loss: 1.42e-03, accuracy: 93.64%
# Epoch  93/200, val loss: 4.54e-03, accuracy: 83.54%
# Epoch  94/200, train loss: 1.44e-03, accuracy: 93.57%
# Epoch  94/200, val loss: 4.13e-03, accuracy: 85.38%
# Epoch  95/200, train loss: 1.42e-03, accuracy: 93.49%
# Epoch  95/200, val loss: 4.51e-03, accuracy: 84.36%
# Epoch  96/200, train loss: 1.41e-03, accuracy: 93.66%
# Epoch  96/200, val loss: 4.39e-03, accuracy: 84.48%
# Epoch  97/200, train loss: 1.42e-03, accuracy: 93.74%
# Epoch  97/200, val loss: 4.38e-03, accuracy: 84.22%
# Epoch  98/200, train loss: 1.45e-03, accuracy: 93.44%
# Epoch  98/200, val loss: 4.35e-03, accuracy: 84.04%
# Epoch  99/200, train loss: 1.41e-03, accuracy: 93.76%
# Epoch  99/200, val loss: 4.10e-03, accuracy: 85.24%
# Epoch 100/200, train loss: 1.34e-03, accuracy: 93.98%
# Epoch 100/200, val loss: 4.72e-03, accuracy: 83.94%
# Epoch 101/200, train loss: 8.07e-04, accuracy: 96.57%
# Epoch 101/200, val loss: 3.68e-03, accuracy: 87.18%
# Epoch 102/200, train loss: 5.80e-04, accuracy: 97.61%
# Epoch 102/200, val loss: 3.58e-03, accuracy: 87.66%
# Epoch 103/200, train loss: 4.90e-04, accuracy: 97.99%
# Epoch 103/200, val loss: 3.62e-03, accuracy: 87.76%
# Epoch 104/200, train loss: 4.67e-04, accuracy: 97.97%
# Epoch 104/200, val loss: 3.73e-03, accuracy: 87.58%
# Epoch 105/200, train loss: 4.15e-04, accuracy: 98.27%
# Epoch 105/200, val loss: 3.78e-03, accuracy: 87.64%
# Epoch 106/200, train loss: 3.76e-04, accuracy: 98.44%
# Epoch 106/200, val loss: 3.78e-03, accuracy: 88.06%
# Epoch 107/200, train loss: 3.68e-04, accuracy: 98.51%
# Epoch 107/200, val loss: 3.82e-03, accuracy: 87.86%
# Epoch 108/200, train loss: 3.27e-04, accuracy: 98.65%
# Epoch 108/200, val loss: 3.80e-03, accuracy: 88.16%
# Epoch 109/200, train loss: 2.98e-04, accuracy: 98.88%
# Epoch 109/200, val loss: 3.78e-03, accuracy: 88.60%
# Epoch 110/200, train loss: 2.99e-04, accuracy: 98.80%
# Epoch 110/200, val loss: 3.94e-03, accuracy: 88.14%
# Epoch 111/200, train loss: 2.89e-04, accuracy: 98.81%
# Epoch 111/200, val loss: 3.95e-03, accuracy: 87.92%
# Epoch 112/200, train loss: 2.62e-04, accuracy: 98.96%
# Epoch 112/200, val loss: 3.89e-03, accuracy: 88.32%
# Epoch 113/200, train loss: 2.60e-04, accuracy: 98.96%
# Epoch 113/200, val loss: 3.96e-03, accuracy: 88.14%
# Epoch 114/200, train loss: 2.48e-04, accuracy: 99.09%
# Epoch 114/200, val loss: 3.98e-03, accuracy: 88.20%
# Epoch 115/200, train loss: 2.33e-04, accuracy: 99.10%
# Epoch 115/200, val loss: 3.95e-03, accuracy: 88.40%
# Epoch 116/200, train loss: 2.22e-04, accuracy: 99.20%
# Epoch 116/200, val loss: 4.12e-03, accuracy: 88.04%
# Epoch 117/200, train loss: 2.08e-04, accuracy: 99.18%
# Epoch 117/200, val loss: 4.18e-03, accuracy: 88.20%
# Epoch 118/200, train loss: 2.08e-04, accuracy: 99.23%
# Epoch 118/200, val loss: 4.24e-03, accuracy: 88.10%
# Epoch 119/200, train loss: 1.96e-04, accuracy: 99.26%
# Epoch 119/200, val loss: 4.18e-03, accuracy: 87.84%
# Epoch 120/200, train loss: 1.84e-04, accuracy: 99.31%
# Epoch 120/200, val loss: 4.19e-03, accuracy: 87.86%
# Epoch 121/200, train loss: 1.86e-04, accuracy: 99.32%
# Epoch 121/200, val loss: 4.21e-03, accuracy: 87.88%
# Epoch 122/200, train loss: 1.78e-04, accuracy: 99.32%
# Epoch 122/200, val loss: 4.22e-03, accuracy: 88.20%
# Epoch 123/200, train loss: 1.70e-04, accuracy: 99.40%
# Epoch 123/200, val loss: 4.28e-03, accuracy: 88.08%
# Epoch 124/200, train loss: 1.74e-04, accuracy: 99.34%
# Epoch 124/200, val loss: 4.25e-03, accuracy: 87.88%
# Epoch 125/200, train loss: 1.68e-04, accuracy: 99.39%
# Epoch 125/200, val loss: 4.35e-03, accuracy: 88.08%
# Epoch 126/200, train loss: 1.57e-04, accuracy: 99.44%
# Epoch 126/200, val loss: 4.36e-03, accuracy: 88.00%
# Epoch 127/200, train loss: 1.58e-04, accuracy: 99.39%
# Epoch 127/200, val loss: 4.34e-03, accuracy: 87.90%
# Epoch 128/200, train loss: 1.61e-04, accuracy: 99.37%
# Epoch 128/200, val loss: 4.34e-03, accuracy: 87.66%
# Epoch 129/200, train loss: 1.44e-04, accuracy: 99.52%
# Epoch 129/200, val loss: 4.36e-03, accuracy: 87.86%
# Epoch 130/200, train loss: 1.50e-04, accuracy: 99.44%
# Epoch 130/200, val loss: 4.40e-03, accuracy: 87.94%
# Epoch 131/200, train loss: 1.45e-04, accuracy: 99.47%
# Epoch 131/200, val loss: 4.38e-03, accuracy: 87.84%
# Epoch 132/200, train loss: 1.43e-04, accuracy: 99.50%
# Epoch 132/200, val loss: 4.48e-03, accuracy: 87.76%
# Epoch 133/200, train loss: 1.26e-04, accuracy: 99.59%
# Epoch 133/200, val loss: 4.39e-03, accuracy: 87.68%
# Epoch 134/200, train loss: 1.26e-04, accuracy: 99.56%
# Epoch 134/200, val loss: 4.52e-03, accuracy: 87.98%
# Epoch 135/200, train loss: 1.21e-04, accuracy: 99.57%
# Epoch 135/200, val loss: 4.44e-03, accuracy: 87.94%
# Epoch 136/200, train loss: 1.26e-04, accuracy: 99.53%
# Epoch 136/200, val loss: 4.44e-03, accuracy: 87.76%
# Epoch 137/200, train loss: 1.23e-04, accuracy: 99.56%
# Epoch 137/200, val loss: 4.48e-03, accuracy: 87.78%
# Epoch 138/200, train loss: 1.13e-04, accuracy: 99.59%
# Epoch 138/200, val loss: 4.39e-03, accuracy: 88.16%
# Epoch 139/200, train loss: 1.22e-04, accuracy: 99.55%
# Epoch 139/200, val loss: 4.46e-03, accuracy: 87.74%
# Epoch 140/200, train loss: 1.19e-04, accuracy: 99.56%
# Epoch 140/200, val loss: 4.49e-03, accuracy: 87.72%
# Epoch 141/200, train loss: 1.07e-04, accuracy: 99.66%
# Epoch 141/200, val loss: 4.46e-03, accuracy: 87.72%
# Epoch 142/200, train loss: 1.07e-04, accuracy: 99.66%
# Epoch 142/200, val loss: 4.50e-03, accuracy: 88.48%
# Epoch 143/200, train loss: 1.15e-04, accuracy: 99.61%
# Epoch 143/200, val loss: 4.64e-03, accuracy: 87.82%
# Epoch 144/200, train loss: 1.07e-04, accuracy: 99.62%
# Epoch 144/200, val loss: 4.59e-03, accuracy: 87.86%
# Epoch 145/200, train loss: 1.09e-04, accuracy: 99.60%
# Epoch 145/200, val loss: 4.70e-03, accuracy: 87.52%
# Epoch 146/200, train loss: 1.10e-04, accuracy: 99.62%
# Epoch 146/200, val loss: 4.70e-03, accuracy: 87.26%
# Epoch 147/200, train loss: 1.08e-04, accuracy: 99.60%
# Epoch 147/200, val loss: 4.75e-03, accuracy: 87.68%
# Epoch 148/200, train loss: 1.07e-04, accuracy: 99.62%
# Epoch 148/200, val loss: 4.65e-03, accuracy: 87.68%
# Epoch 149/200, train loss: 9.10e-05, accuracy: 99.69%
# Epoch 149/200, val loss: 4.57e-03, accuracy: 87.68%
# Epoch 150/200, train loss: 9.96e-05, accuracy: 99.65%
# Epoch 150/200, val loss: 4.66e-03, accuracy: 87.76%
# Epoch 151/200, train loss: 9.10e-05, accuracy: 99.70%
# Epoch 151/200, val loss: 4.63e-03, accuracy: 87.86%
# Epoch 152/200, train loss: 8.07e-05, accuracy: 99.76%
# Epoch 152/200, val loss: 4.63e-03, accuracy: 87.86%
# Epoch 153/200, train loss: 7.68e-05, accuracy: 99.78%
# Epoch 153/200, val loss: 4.61e-03, accuracy: 87.94%
# Epoch 154/200, train loss: 7.88e-05, accuracy: 99.77%
# Epoch 154/200, val loss: 4.62e-03, accuracy: 87.96%
# Epoch 155/200, train loss: 7.81e-05, accuracy: 99.78%
# Epoch 155/200, val loss: 4.63e-03, accuracy: 88.00%
# Epoch 156/200, train loss: 7.87e-05, accuracy: 99.73%
# Epoch 156/200, val loss: 4.61e-03, accuracy: 87.96%
# Epoch 157/200, train loss: 7.55e-05, accuracy: 99.78%
# Epoch 157/200, val loss: 4.61e-03, accuracy: 88.06%
# Epoch 158/200, train loss: 7.28e-05, accuracy: 99.78%
# Epoch 158/200, val loss: 4.61e-03, accuracy: 88.02%
# Epoch 159/200, train loss: 7.21e-05, accuracy: 99.78%
# Epoch 159/200, val loss: 4.61e-03, accuracy: 87.86%
# Epoch 160/200, train loss: 6.65e-05, accuracy: 99.83%
# Epoch 160/200, val loss: 4.61e-03, accuracy: 87.96%
# Epoch 161/200, train loss: 6.97e-05, accuracy: 99.80%
# Epoch 161/200, val loss: 4.61e-03, accuracy: 87.94%
# Epoch 162/200, train loss: 6.80e-05, accuracy: 99.81%
# Epoch 162/200, val loss: 4.62e-03, accuracy: 88.02%
# Epoch 163/200, train loss: 6.76e-05, accuracy: 99.81%
# Epoch 163/200, val loss: 4.61e-03, accuracy: 88.00%
# Epoch 164/200, train loss: 6.71e-05, accuracy: 99.84%
# Epoch 164/200, val loss: 4.62e-03, accuracy: 87.94%
# Epoch 165/200, train loss: 6.41e-05, accuracy: 99.82%
# Epoch 165/200, val loss: 4.60e-03, accuracy: 87.96%
# Epoch 166/200, train loss: 6.65e-05, accuracy: 99.82%
# Epoch 166/200, val loss: 4.61e-03, accuracy: 87.96%
# Epoch 167/200, train loss: 6.64e-05, accuracy: 99.81%
# Epoch 167/200, val loss: 4.60e-03, accuracy: 88.06%
# Epoch 168/200, train loss: 7.02e-05, accuracy: 99.80%
# Epoch 168/200, val loss: 4.60e-03, accuracy: 88.08%
# Epoch 169/200, train loss: 6.36e-05, accuracy: 99.84%
# Epoch 169/200, val loss: 4.58e-03, accuracy: 88.00%
# Epoch 170/200, train loss: 6.53e-05, accuracy: 99.81%
# Epoch 170/200, val loss: 4.58e-03, accuracy: 88.12%
# Epoch 171/200, train loss: 6.18e-05, accuracy: 99.83%
# Epoch 171/200, val loss: 4.57e-03, accuracy: 88.10%
# Epoch 172/200, train loss: 6.70e-05, accuracy: 99.81%
# Epoch 172/200, val loss: 4.59e-03, accuracy: 88.14%
# Epoch 173/200, train loss: 6.42e-05, accuracy: 99.84%
# Epoch 173/200, val loss: 4.59e-03, accuracy: 88.12%
# Epoch 174/200, train loss: 6.60e-05, accuracy: 99.81%
# Epoch 174/200, val loss: 4.60e-03, accuracy: 88.02%
# Epoch 175/200, train loss: 6.94e-05, accuracy: 99.80%
# Epoch 175/200, val loss: 4.59e-03, accuracy: 88.14%
# Epoch 176/200, train loss: 6.65e-05, accuracy: 99.82%
# Epoch 176/200, val loss: 4.60e-03, accuracy: 88.04%
# Epoch 177/200, train loss: 6.29e-05, accuracy: 99.82%
# Epoch 177/200, val loss: 4.58e-03, accuracy: 88.06%
# Epoch 178/200, train loss: 5.76e-05, accuracy: 99.87%
# Epoch 178/200, val loss: 4.59e-03, accuracy: 88.02%
# Epoch 179/200, train loss: 6.59e-05, accuracy: 99.80%
# Epoch 179/200, val loss: 4.56e-03, accuracy: 88.08%
# Epoch 180/200, train loss: 6.31e-05, accuracy: 99.84%
# Epoch 180/200, val loss: 4.57e-03, accuracy: 88.04%
# Epoch 181/200, train loss: 6.85e-05, accuracy: 99.80%
# Epoch 181/200, val loss: 4.56e-03, accuracy: 88.02%
# Epoch 182/200, train loss: 6.13e-05, accuracy: 99.85%
# Epoch 182/200, val loss: 4.55e-03, accuracy: 88.14%
# Epoch 183/200, train loss: 6.21e-05, accuracy: 99.85%
# Epoch 183/200, val loss: 4.55e-03, accuracy: 88.08%
# Epoch 184/200, train loss: 6.43e-05, accuracy: 99.81%
# Epoch 184/200, val loss: 4.57e-03, accuracy: 87.92%
# Epoch 185/200, train loss: 6.43e-05, accuracy: 99.83%
# Epoch 185/200, val loss: 4.57e-03, accuracy: 87.88%
# Epoch 186/200, train loss: 5.68e-05, accuracy: 99.85%
# Epoch 186/200, val loss: 4.57e-03, accuracy: 87.90%
# Epoch 187/200, train loss: 6.71e-05, accuracy: 99.80%
# Epoch 187/200, val loss: 4.58e-03, accuracy: 87.88%
# Epoch 188/200, train loss: 6.09e-05, accuracy: 99.83%
# Epoch 188/200, val loss: 4.58e-03, accuracy: 87.92%
# Epoch 189/200, train loss: 5.81e-05, accuracy: 99.86%
# Epoch 189/200, val loss: 4.60e-03, accuracy: 87.72%
# Epoch 190/200, train loss: 6.28e-05, accuracy: 99.82%
# Epoch 190/200, val loss: 4.57e-03, accuracy: 87.94%
# Epoch 191/200, train loss: 5.82e-05, accuracy: 99.86%
# Epoch 191/200, val loss: 4.58e-03, accuracy: 87.94%
# Epoch 192/200, train loss: 6.01e-05, accuracy: 99.86%
# Epoch 192/200, val loss: 4.58e-03, accuracy: 88.00%
# Epoch 193/200, train loss: 6.09e-05, accuracy: 99.83%
# Epoch 193/200, val loss: 4.56e-03, accuracy: 87.94%
# Epoch 194/200, train loss: 5.97e-05, accuracy: 99.82%
# Epoch 194/200, val loss: 4.56e-03, accuracy: 87.92%
# Epoch 195/200, train loss: 5.87e-05, accuracy: 99.86%
# Epoch 195/200, val loss: 4.57e-03, accuracy: 87.96%
# Epoch 196/200, train loss: 5.89e-05, accuracy: 99.85%
# Epoch 196/200, val loss: 4.58e-03, accuracy: 87.98%
# Epoch 197/200, train loss: 6.19e-05, accuracy: 99.85%
# Epoch 197/200, val loss: 4.58e-03, accuracy: 88.00%
# Epoch 198/200, train loss: 5.76e-05, accuracy: 99.85%
# Epoch 198/200, val loss: 4.58e-03, accuracy: 88.04%
# Epoch 199/200, train loss: 6.34e-05, accuracy: 99.83%
# Epoch 199/200, val loss: 4.57e-03, accuracy: 87.98%
# Epoch 200/200, train loss: 6.30e-05, accuracy: 99.82%
# Epoch 200/200, val loss: 4.58e-03, accuracy: 88.00%

# %% [markdown]
# Once the model is trained we run it on the test set to obtain our final accuracy.
# Note that we can only look at the test set once, everything else would lead to overfitting. So you _must_ ignore the test set while developing your model!

# %%
test_loss, test_acc = run_epoch(resnet, None, dataloaders['test'], train=False)
print(f"Test loss: {test_loss:.1e}, accuracy: {test_acc * 100:.2f}%")
# Out:
# Test loss: 3.6e-03, accuracy: 87.61%

# %% [markdown]
# That's almost what was reported in the paper (92.49%) and we didn't even train on the full training set.

# %% [markdown]
# # Optional task: Squeeze out all the juice!

# %% [markdown]
# Can you do even better? Have a look at [A Recipe for Training Neural Networks](https://karpathy.github.io/2019/04/25/recipe/) and some state-of-the-art architectures such as [EfficientNet architecture](https://ai.googleblog.com/2019/05/efficientnet-improving-accuracy-and.html). Play around with the possibilities PyTorch offers you and see how close you can get to the [state of the art on CIFAR-10](https://paperswithcode.com/sota/image-classification-on-cifar-10).
