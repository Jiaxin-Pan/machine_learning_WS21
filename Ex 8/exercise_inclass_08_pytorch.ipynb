# %% [markdown]
# # In-class exercise 8: PyTorch from the bottom up

# %% [markdown]
# Based on Jeremy Howard's PyTorch tutorial "What is torch.nn really?"

# %% [markdown]
# In this tutorial we will start at [PyTorch](https://pytorch.org/docs)'s lowest layer and then gradually introduce functions and features until we arrive at `nn.Sequential`. Lower layers give you more control over what you want to do, while higher layers allow for faster implementations. So in practice you have to choose at which layer you want to work. Moreover, knowing how the lower layers work will give you a better understanding of what is happening behind the scenes when working with the higher level abstractions.

# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt

# %% [markdown]
# # Download the data
# In this tutorial we will be working with the MNIST dataset. This is a classic dataset consisting of black and white images of hand-drawn digits.
#
# We will use [torchvision](https://pytorch.org/docs/stable/torchvision) to download the dataset. Torchvision also provides a lot of functionality for data preprocessing and augmentation, which is beyond the scope of this tutorial.

# %%
mnist_dev = torchvision.datasets.MNIST('./data', train=True, download=True)  #dev = development
mnist_test = torchvision.datasets.MNIST('./data', train=False, download=True)

# %% [markdown]
# The input data $\mathbf{X}$ and targets $\mathbf{y}$ are saved in `data` and `targets`, so we will at first just extract these and work with the raw data. We also convert them to values between 0 and 1.

# %%
x_dev = mnist_dev.data / 255.0   #convert to 0-1
y_dev = mnist_dev.targets

# %% [markdown]
# MNIST consists of 60,000 28x28 images, each corresponding to a single digit (0 to 9).

# %%
print(x_dev.shape)         #6000个sample 每个尺寸28*28
print(y_dev.shape)

plt.imshow(x_dev[0], cmap='gray')
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([60000])

# %% [markdown]
# Note that setting `train=True` gives you the development set, i.e. both training and validation data. So we need to split this further.

# %%
#把development分为training和validation
ntrain = 50000     
x_train, y_train = x_dev[:ntrain].flatten(1), y_dev[:ntrain]
x_val, y_val = x_dev[ntrain:].flatten(1), y_dev[ntrain:]

x_train.shape
# Out:
# torch.Size([50000, 784])

# %% [markdown]
# # torch.tensor
# PyTorch uses its own `torch.tensor` datatype. This is very similar to a Numpy Array, but can also be moved to and used for calculations on a GPU, and supports storing gradient information and hence dynamic backpropagation.

# %% [markdown]
# We start by manually setting up an affine layer. The special function `requires_grad` tells PyTorch that these weights require gradients. PyTorch will then record all operations done on the tensor, so backpropagation can be done automatically. Thanks to this ability we can use any normal function as a model in PyTorch.
#
# Note that we initialize the weights via Xavier (Glorot) initialization. We only activate gradients after initialization, since we don't want gradients for that.
#
# Appending a function with `_` in PyTorch denotes in-place operations.

# %%
num_features = 28 * 28
num_classes = 10

weight = torch.randn(num_features, num_classes) * np.sqrt(2 / (num_features + num_classes))  #xavier initialization
weight.requires_grad_()
bias = torch.zeros(num_classes, requires_grad=True)
weight
weight.shape
# Out:
# torch.Size([784, 10])

# %% [markdown]
# We now use these weights to create a simple linear model (i.e. logistic regression). We furthermore define a loss (negative log-likelihood) for training and a function to obtain the prediction accuracy.

# %%
def model(input):
    return log_softmax(input @ weight + bias)   #括号里是affine layer

def log_softmax(input):
    return input - input.exp().sum(-1).log().unsqueeze(-1) #对softmax求log, input是affine layer
#也可以用input-input.logsumexp(-1. keepdims = True)

def nll_loss(output, target):
    return -output[range(target.shape[0]), target].mean()  #cross antropy loss, average loss
loss_fn = nll_loss

def get_accuracy(output, target):
    pred = torch.argmax(output, dim=1)
    return (pred == target).float().mean() #boolean变为float

# %% [markdown]
# Let's see how our model performs before training.

# %%
batch_size = 64

print(get_accuracy(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(0.1250)

# %% [markdown]
# We can now define a training loop. In this loop we need to
# 1. Get a mini-batch of data. When using dynamic computation graphs like in PyTorch it is important to choose a batch size that is large enough to leverage your hardware properly.
# 2. Generate predictions with our model
# 3. Calculate the loss
# 4. Update the gradients via `loss.backward()`
# 5. Update the `weight` and `bias` based on the gradients (optimization)

# %%
learning_rate = 0.5
num_epochs = 2

for epoch in range(num_epochs):                                        #go through epochs
    for i in range(int(np.ceil(ntrain / batch_size))): #np.ceil向上取整  go throuch mini-batches
        # Get mini-batch
        start_i = i * batch_size
        end_i = min(start_i + batch_size, ntrain)
        xb = x_train[start_i:end_i]                #shape: [batch-size, num_features]
        yb = y_train[start_i:end_i]                #       [batch-size]
        
        # Generate predictions
        pred = model(xb)
        
        # Calculate loss
        loss = loss_fn(pred, yb)
        
        # compute the gradient of the loss w.r.t. parameters (pytorch generate the backward automatically)
        loss.backward()
        
        # Optimization step
        with torch.no_grad():   
            #没有这句的话会自动计算图的构建（这里不需要）,这句话告诉python这里不需要额外计算gradient（gradient之前在backward里计算过了）
            weight -= learning_rate * weight.grad
            bias -= learning_rate * bias.grad
        weight.grad.zero_()
        bias.grad.zero_()

# %% [markdown]
# That is all we need! And now we can check if our performance has improved.

# %%
print(loss_fn(model(x_train[:batch_size]), y_train[:batch_size]))
print(get_accuracy(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(0.2277, grad_fn=<NegBackward>)
# tensor(0.9531)

# %% [markdown]
# Nice, it works! Wasn't this already way easier than with pure Numpy? But this is just the start. Now that we've implemented our model in the lowest level of PyTorch we can start to go up the ladder and make this even better and simpler!

# %% [markdown]
# # torch.nn.functional

# %% [markdown]
# We will start by replacing some of our hand-written functions with their professionally implemented counterparts in `torch.nn.functional`. This library contains all of the PyTorch functions (other parts contain the classes). It is commonly imported via

# %%
import torch.nn.functional as F

# %% [markdown]
# Instead of using `log_softmax` and `neg_loglikelihood` we can instead just use `F.cross_entropy`, which combines both of these.

# %%
def model(xb):
    return xb @ weight + bias

loss_fn = F.cross_entropy

# %% [markdown]
# The loss should still be the same.

# %%
print(loss_fn(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(0.2277, grad_fn=<NllLossBackward>)

# %% [markdown]
# # nn.Module
# Next we will use `nn.Module` and `nn.Parameter` for a clearer and more concise model definition and training loop. By subclassing `nn.Module` we obtain various convenience functions such as `.parameters()` and `.zero_grad()`.

# %%
from torch import nn

class LogisticRegression(nn.Module):    #从nn.Module继承而来
    def __init__(self, num_features, num_classes):
        super().__init__()
        #用nn.parameters创建系数
        self.weight = nn.Parameter(torch.randn(num_features, num_classes) * np.sqrt(2 / (num_features + num_classes)))
        self.bias = nn.Parameter(torch.zeros(num_classes))
        
    def forward(self, input):
        return input @ self.weight + self.bias

# %% [markdown]
# Since `LogRegression` is now a class we will have to first instantiate it before using it. We can then call it as if it were a function.

# %%
model = LogisticRegression(28 * 28, 10)
print(loss_fn(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(2.2722, grad_fn=<NllLossBackward>)

# %% [markdown]
# We can now take advantage of `.parameters()` and `.zero_grad()` to make our training loop more concise.

# %%
learning_rate = 0.5
num_epochs = 2

def fit(model, num_epochs):
    for epoch in range(num_epochs):
        for i in range(int(np.ceil(ntrain / batch_size))):
            # Get mini-batch
            start_i = i * batch_size
            end_i = min(start_i + batch_size, ntrain)
            xb = x_train[start_i:end_i]
            yb = y_train[start_i:end_i]

            # Generate predictions
            pred = model(xb)

            # Calculate loss
            loss = loss_fn(pred, yb)

            # Update gradients
            model.zero_grad()
            loss.backward()

            # Optimization step
            with torch.no_grad():
                for param in model.parameters():
                    param -= learning_rate * param.grad

# %%
fit(model, num_epochs=2)

# %% [markdown]
# And check if our results are similar to before.

# %%
print(loss_fn(model(x_train[:batch_size]), y_train[:batch_size]))
print(get_accuracy(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(0.2305, grad_fn=<NllLossBackward>)
# tensor(0.9531)

# %% [markdown]
# # nn.Linear

# %% [markdown]
# Instead of manually defining and initializing the affine layer, we can instead use the PyTorch class `nn.Linear`. PyTorch provides a wide range of predefined layers to simplify our code (and make it faster). On GitHub you will find layers for pretty much anything you might want to do.

# %%
class LogisticRegression(nn.Module):
    def __init__(self, num_features, num_classes):
        super().__init__()
        self.lin = nn.Linear(num_features, num_classes)  #即affine layer
        
    def forward(self, input):
        return self.lin(input)

# %% [markdown]
# To control weight initialization we must define a function and apply it to the model with `.apply(_)`.

# %%
def initialize_weight(module):
    if isinstance(module, (nn.Linear, nn.Conv2d)):   #if it is linear or convolution
        nn.init.xavier_normal_(module.weight)

# %% [markdown]
# Now let's check if we still get the same results as before.

# %%
model = LogisticRegression(28 * 28, 10)
model.apply(initialize_weight)

fit(model, num_epochs=2)

print(loss_fn(model(x_train[:batch_size]), y_train[:batch_size]))
print(get_accuracy(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(0.2278, grad_fn=<NllLossBackward>)
# tensor(0.9531)

# %% [markdown]
# # torch.optim

# %% [markdown]
# `torch.optim` provides various optimization algorithms. Here we will continue to use simple `SGD`, but you could just as easily switch to Adam or AMSgrad. Optimizers provide `.step()` and `.zero_grad()` methods, which allows us to make the last block in our `fit` function more concise.

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
optimizer
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.5
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )

# %%
def fit(model, optimizer, num_epochs):
    for epoch in range(num_epochs):
        for i in range(int(np.ceil(ntrain / batch_size))):
            # Get mini-batch
            start_i = i * batch_size
            end_i = min(start_i + batch_size, ntrain)
            xb = x_train[start_i:end_i]
            yb = y_train[start_i:end_i]

            # Generate predictions
            pred = model(xb)

            # Calculate loss
            loss = loss_fn(pred, yb)

            # Update gradients
            optimizer.zero_grad()
            loss.backward()

            # Optimization step
            optimizer.step()         ####这里变了####

# %%
fit(model, optimizer, num_epochs=2)

# %%
print(loss_fn(model(x_train[:batch_size]), y_train[:batch_size]))
print(get_accuracy(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(0.1951, grad_fn=<NllLossBackward>)
# tensor(0.9375)

# %% [markdown]
# # Dataset
# PyTorch also provides an abstract Dataset class for easier handling of various data. You can subclass this just like we subclassed `nn.Module`. A Dataset only needs to provide a `__len__` (which is called by Python's `len` function) and a `__getitem__` function for indexing the dataset.
#
# `TensorDataset` provides an easy way of converting tensors to datasets. This will make our data loading more concise, since we can handle both `x_train` and `y_train` simultaneously.

# %%
from torch.utils.data import TensorDataset

train_set = TensorDataset(x_train, y_train)

# %%
def fit(model, optimizer, train_set, num_epochs):
    for epoch in range(num_epochs):
        for i in range(int(np.ceil(ntrain / batch_size))):
            # Get mini-batch
            start_i = i * batch_size
            end_i = min(start_i + batch_size, ntrain)
            xb, yb = train_set[start_i:end_i]          ####这里变了####

            # Generate predictions
            pred = model(xb)

            # Calculate loss
            loss = loss_fn(pred, yb)

            # Update gradients
            optimizer.zero_grad()
            loss.backward()

            # Optimization step
            optimizer.step()

# %%
model = LogisticRegression(28 * 28, 10)
model.apply(initialize_weight)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

fit(model, optimizer, train_set, num_epochs=2)

print(loss_fn(model(x_train[:batch_size]), y_train[:batch_size]))
print(get_accuracy(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(0.2299, grad_fn=<NllLossBackward>)
# tensor(0.9375)

# %% [markdown]
# # DataLoader

# %% [markdown]
# A `DataLoader` automatically generates mini-batches for your training loop. It can run multiple workers in parallel and provides useful functionality such as data shuffling. You can create a `DataLoader` for any `Dataset`.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_set, batch_size=batch_size,shuffle=True)

# %% [markdown]
# Using the DataLoader makes our training loop a lot cleaner:

# %%
def fit(model, optimizer, train_loader, num_epochs):
    for epoch in range(num_epochs):
        for xb, yb in train_loader:            ####这里一段简化了####
            # Generate predictions
            pred = model(xb)

            # Calculate loss
            loss = loss_fn(pred, yb)

            # Update gradients
            optimizer.zero_grad()
            loss.backward()

            # Optimization step
            optimizer.step()

# %%
model = LogisticRegression(28 * 28, 10)
model.apply(initialize_weight)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

fit(model, optimizer, train_loader, num_epochs=2)

print(loss_fn(model(x_train[:batch_size]), y_train[:batch_size]))
print(get_accuracy(model(x_train[:batch_size]), y_train[:batch_size]))
# Out:
# tensor(0.2119, grad_fn=<NllLossBackward>)
# tensor(0.9375)

# %% [markdown]
# # Validation
#
# Now that we have a training loop we can go ahead and do some real work. ###To avoid overfitting, enable early stopping### and have some information for model development we always need a validation set.
#
# Since the validation set does not need backpropagation we can use 2x larger batches for it. Furthermore, we should shuffle our training data to avoid correlation between batches. This is not necessary (and would waste computation time) for the validation set.

# %%
train_set = TensorDataset(x_train, y_train)
val_set = TensorDataset(x_val, y_val)

dataloaders = {}
dataloaders['train'] = DataLoader(train_set, batch_size=batch_size, shuffle=True)
dataloaders['val'] = DataLoader(val_set, batch_size=2 * batch_size)

# %% [markdown]
# Note that you need to call `model.train()` before training and `model.eval()` before evaluation (inference), since some layers like dropout and batch normalization work differently in each mode.

# %%
def fit(model, optimizer, dataloaders, num_epochs):     #包含完整的training和validation
    for epoch in range(num_epochs):
        
        # Training
        model.train()                        #对于dropout有用
        for xb, yb in dataloaders['train']:
            pred = model(xb)
            loss = loss_fn(pred, yb)
            print("train",loss)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        # Evaluation
        model.eval()
        loss = 0
        for xb, yb in dataloaders['val']:
            pred = model(xb)
            loss += loss_fn(pred, yb).sum()
            print(loss)
        avg_loss = loss / len(dataloaders['val'])
            
        print(f"Epoch {epoch}: {avg_loss:.3f}")

# %%
model = LogisticRegression(28 * 28, 10)
model.apply(initialize_weight)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

fit(model, optimizer, dataloaders, num_epochs=2)
# Out:
# train tensor(2.5153, grad_fn=<NllLossBackward>)
# train tensor(2.8540, grad_fn=<NllLossBackward>)
# train tensor(2.6360, grad_fn=<NllLossBackward>)
# train tensor(2.4610, grad_fn=<NllLossBackward>)
# train tensor(1.7337, grad_fn=<NllLossBackward>)
# train tensor(1.4752, grad_fn=<NllLossBackward>)
# train tensor(1.0003, grad_fn=<NllLossBackward>)
# train tensor(1.1636, grad_fn=<NllLossBackward>)
# train tensor(1.0762, grad_fn=<NllLossBackward>)
# train tensor(1.0773, grad_fn=<NllLossBackward>)
# train tensor(0.7843, grad_fn=<NllLossBackward>)
# train tensor(0.8405, grad_fn=<NllLossBackward>)
# train tensor(0.7637, grad_fn=<NllLossBackward>)
# train tensor(0.6004, grad_fn=<NllLossBackward>)
# train tensor(0.8181, grad_fn=<NllLossBackward>)
# train tensor(0.8684, grad_fn=<NllLossBackward>)
# train tensor(0.7186, grad_fn=<NllLossBackward>)
# train tensor(0.8615, grad_fn=<NllLossBackward>)
# train tensor(0.7438, grad_fn=<NllLossBackward>)
# train tensor(0.6640, grad_fn=<NllLossBackward>)
# train tensor(0.9222, grad_fn=<NllLossBackward>)
# train tensor(0.6640, grad_fn=<NllLossBackward>)
# train tensor(0.4414, grad_fn=<NllLossBackward>)
# train tensor(0.6800, grad_fn=<NllLossBackward>)
# train tensor(0.6002, grad_fn=<NllLossBackward>)
# train tensor(0.6670, grad_fn=<NllLossBackward>)
# train tensor(0.5613, grad_fn=<NllLossBackward>)
# train tensor(0.4018, grad_fn=<NllLossBackward>)
# train tensor(0.8275, grad_fn=<NllLossBackward>)
# train tensor(0.5624, grad_fn=<NllLossBackward>)
# train tensor(0.4468, grad_fn=<NllLossBackward>)
# train tensor(0.4607, grad_fn=<NllLossBackward>)
# train tensor(0.4494, grad_fn=<NllLossBackward>)
# train tensor(0.4228, grad_fn=<NllLossBackward>)
# train tensor(0.5200, grad_fn=<NllLossBackward>)
# train tensor(0.5839, grad_fn=<NllLossBackward>)
# train tensor(0.7997, grad_fn=<NllLossBackward>)
# train tensor(0.5570, grad_fn=<NllLossBackward>)
# train tensor(0.6697, grad_fn=<NllLossBackward>)
# train tensor(0.4161, grad_fn=<NllLossBackward>)
# train tensor(0.5975, grad_fn=<NllLossBackward>)
# train tensor(0.4958, grad_fn=<NllLossBackward>)
# train tensor(0.4729, grad_fn=<NllLossBackward>)
# train tensor(0.4150, grad_fn=<NllLossBackward>)
# train tensor(0.6395, grad_fn=<NllLossBackward>)
# train tensor(0.4746, grad_fn=<NllLossBackward>)
# train tensor(0.5429, grad_fn=<NllLossBackward>)
# train tensor(0.3443, grad_fn=<NllLossBackward>)
# train tensor(0.5585, grad_fn=<NllLossBackward>)
# train tensor(0.5321, grad_fn=<NllLossBackward>)
# train tensor(0.4998, grad_fn=<NllLossBackward>)
# train tensor(0.3490, grad_fn=<NllLossBackward>)
# train tensor(0.4479, grad_fn=<NllLossBackward>)
# train tensor(0.5640, grad_fn=<NllLossBackward>)
# train tensor(0.5240, grad_fn=<NllLossBackward>)
# train tensor(0.3685, grad_fn=<NllLossBackward>)
# train tensor(0.4719, grad_fn=<NllLossBackward>)
# train tensor(0.5486, grad_fn=<NllLossBackward>)
# train tensor(0.4031, grad_fn=<NllLossBackward>)
# train tensor(0.5302, grad_fn=<NllLossBackward>)
# train tensor(0.5083, grad_fn=<NllLossBackward>)
# train tensor(0.6664, grad_fn=<NllLossBackward>)
# train tensor(0.5544, grad_fn=<NllLossBackward>)
# train tensor(0.4666, grad_fn=<NllLossBackward>)
# train tensor(0.3947, grad_fn=<NllLossBackward>)
# train tensor(0.4832, grad_fn=<NllLossBackward>)
# train tensor(0.4750, grad_fn=<NllLossBackward>)
# train tensor(0.4707, grad_fn=<NllLossBackward>)
# train tensor(0.5060, grad_fn=<NllLossBackward>)
# train tensor(0.4585, grad_fn=<NllLossBackward>)
# train tensor(0.3824, grad_fn=<NllLossBackward>)
# train tensor(0.6100, grad_fn=<NllLossBackward>)
# train tensor(0.3717, grad_fn=<NllLossBackward>)
# train tensor(0.4451, grad_fn=<NllLossBackward>)
# train tensor(0.5219, grad_fn=<NllLossBackward>)
# train tensor(0.4383, grad_fn=<NllLossBackward>)
# train tensor(0.3827, grad_fn=<NllLossBackward>)
# train tensor(0.4625, grad_fn=<NllLossBackward>)
# train tensor(0.3923, grad_fn=<NllLossBackward>)
# train tensor(0.5186, grad_fn=<NllLossBackward>)
# train tensor(0.6610, grad_fn=<NllLossBackward>)
# train tensor(0.4855, grad_fn=<NllLossBackward>)
# train tensor(0.4448, grad_fn=<NllLossBackward>)
# train tensor(0.6061, grad_fn=<NllLossBackward>)
# train tensor(0.4789, grad_fn=<NllLossBackward>)
# train tensor(0.5564, grad_fn=<NllLossBackward>)
# train tensor(0.3498, grad_fn=<NllLossBackward>)
# train tensor(0.4164, grad_fn=<NllLossBackward>)
# train tensor(0.5519, grad_fn=<NllLossBackward>)
# train tensor(0.3755, grad_fn=<NllLossBackward>)
# train tensor(0.2947, grad_fn=<NllLossBackward>)
# train tensor(0.4487, grad_fn=<NllLossBackward>)
# train tensor(0.7605, grad_fn=<NllLossBackward>)
# train tensor(0.3748, grad_fn=<NllLossBackward>)
# train tensor(0.3702, grad_fn=<NllLossBackward>)
# train tensor(0.4216, grad_fn=<NllLossBackward>)
# train tensor(0.6016, grad_fn=<NllLossBackward>)
# train tensor(0.5263, grad_fn=<NllLossBackward>)
# train tensor(0.3402, grad_fn=<NllLossBackward>)
# train tensor(0.3759, grad_fn=<NllLossBackward>)
# train tensor(0.5477, grad_fn=<NllLossBackward>)
# train tensor(0.3293, grad_fn=<NllLossBackward>)
# train tensor(0.4201, grad_fn=<NllLossBackward>)
# train tensor(0.3606, grad_fn=<NllLossBackward>)
# train tensor(0.2141, grad_fn=<NllLossBackward>)
# train tensor(0.6330, grad_fn=<NllLossBackward>)
# train tensor(0.4170, grad_fn=<NllLossBackward>)
# train tensor(0.3471, grad_fn=<NllLossBackward>)
# train tensor(0.5832, grad_fn=<NllLossBackward>)
# train tensor(0.4684, grad_fn=<NllLossBackward>)
# train tensor(0.2130, grad_fn=<NllLossBackward>)
# train tensor(0.4252, grad_fn=<NllLossBackward>)
# train tensor(0.4031, grad_fn=<NllLossBackward>)
# train tensor(0.1720, grad_fn=<NllLossBackward>)
# train tensor(0.4259, grad_fn=<NllLossBackward>)
# train tensor(0.6883, grad_fn=<NllLossBackward>)
# train tensor(0.4911, grad_fn=<NllLossBackward>)
# train tensor(0.3446, grad_fn=<NllLossBackward>)
# train tensor(0.4759, grad_fn=<NllLossBackward>)
# train tensor(0.3593, grad_fn=<NllLossBackward>)
# train tensor(0.4402, grad_fn=<NllLossBackward>)
# train tensor(0.2376, grad_fn=<NllLossBackward>)
# train tensor(0.5116, grad_fn=<NllLossBackward>)
# train tensor(0.6102, grad_fn=<NllLossBackward>)
# train tensor(0.4716, grad_fn=<NllLossBackward>)
# train tensor(0.3502, grad_fn=<NllLossBackward>)
# train tensor(0.4297, grad_fn=<NllLossBackward>)
# train tensor(0.4170, grad_fn=<NllLossBackward>)
# train tensor(0.5007, grad_fn=<NllLossBackward>)
# train tensor(0.4718, grad_fn=<NllLossBackward>)
# train tensor(0.3150, grad_fn=<NllLossBackward>)
# train tensor(0.1952, grad_fn=<NllLossBackward>)
# train tensor(0.4468, grad_fn=<NllLossBackward>)
# train tensor(0.2790, grad_fn=<NllLossBackward>)
# train tensor(0.6160, grad_fn=<NllLossBackward>)
# train tensor(0.2284, grad_fn=<NllLossBackward>)
# train tensor(0.5048, grad_fn=<NllLossBackward>)
# train tensor(0.5654, grad_fn=<NllLossBackward>)
# train tensor(0.6106, grad_fn=<NllLossBackward>)
# train tensor(0.4372, grad_fn=<NllLossBackward>)
# train tensor(0.3052, grad_fn=<NllLossBackward>)
# train tensor(0.4743, grad_fn=<NllLossBackward>)
# train tensor(0.2731, grad_fn=<NllLossBackward>)
# train tensor(0.4907, grad_fn=<NllLossBackward>)
# train tensor(0.4201, grad_fn=<NllLossBackward>)
# train tensor(0.3796, grad_fn=<NllLossBackward>)
# train tensor(0.4278, grad_fn=<NllLossBackward>)
# train tensor(0.3884, grad_fn=<NllLossBackward>)
# train tensor(0.4570, grad_fn=<NllLossBackward>)
# train tensor(0.5048, grad_fn=<NllLossBackward>)
# train tensor(0.3076, grad_fn=<NllLossBackward>)
# train tensor(0.4918, grad_fn=<NllLossBackward>)
# train tensor(0.4660, grad_fn=<NllLossBackward>)
# train tensor(0.3583, grad_fn=<NllLossBackward>)
# train tensor(0.4703, grad_fn=<NllLossBackward>)
# train tensor(0.2061, grad_fn=<NllLossBackward>)
# train tensor(0.3794, grad_fn=<NllLossBackward>)
# train tensor(0.3269, grad_fn=<NllLossBackward>)
# train tensor(0.4411, grad_fn=<NllLossBackward>)
# train tensor(0.4541, grad_fn=<NllLossBackward>)
# train tensor(0.2528, grad_fn=<NllLossBackward>)
# train tensor(0.3214, grad_fn=<NllLossBackward>)
# train tensor(0.3727, grad_fn=<NllLossBackward>)
# train tensor(0.2407, grad_fn=<NllLossBackward>)
# train tensor(0.5008, grad_fn=<NllLossBackward>)
# train tensor(0.4929, grad_fn=<NllLossBackward>)
# train tensor(0.4098, grad_fn=<NllLossBackward>)
# train tensor(0.4121, grad_fn=<NllLossBackward>)
# train tensor(0.4809, grad_fn=<NllLossBackward>)
# train tensor(0.4053, grad_fn=<NllLossBackward>)
# train tensor(0.3487, grad_fn=<NllLossBackward>)
# train tensor(0.3518, grad_fn=<NllLossBackward>)
# train tensor(0.3456, grad_fn=<NllLossBackward>)
# train tensor(0.3784, grad_fn=<NllLossBackward>)
# train tensor(0.5058, grad_fn=<NllLossBackward>)
# train tensor(0.2418, grad_fn=<NllLossBackward>)
# train tensor(0.4997, grad_fn=<NllLossBackward>)
# train tensor(0.5361, grad_fn=<NllLossBackward>)
# train tensor(0.4617, grad_fn=<NllLossBackward>)
# train tensor(0.2835, grad_fn=<NllLossBackward>)
# train tensor(0.3417, grad_fn=<NllLossBackward>)
# train tensor(0.3830, grad_fn=<NllLossBackward>)
# train tensor(0.2478, grad_fn=<NllLossBackward>)
# train tensor(0.2128, grad_fn=<NllLossBackward>)
# train tensor(0.2357, grad_fn=<NllLossBackward>)
# train tensor(0.3453, grad_fn=<NllLossBackward>)
# train tensor(0.3414, grad_fn=<NllLossBackward>)
# train tensor(0.2319, grad_fn=<NllLossBackward>)
# train tensor(0.4272, grad_fn=<NllLossBackward>)
# train tensor(0.4203, grad_fn=<NllLossBackward>)
# train tensor(0.4614, grad_fn=<NllLossBackward>)
# train tensor(0.3474, grad_fn=<NllLossBackward>)
# train tensor(0.3041, grad_fn=<NllLossBackward>)
# train tensor(0.3646, grad_fn=<NllLossBackward>)
# train tensor(0.6332, grad_fn=<NllLossBackward>)
# train tensor(0.2942, grad_fn=<NllLossBackward>)
# train tensor(0.4853, grad_fn=<NllLossBackward>)
# train tensor(0.2706, grad_fn=<NllLossBackward>)
# train tensor(0.5011, grad_fn=<NllLossBackward>)
# train tensor(0.3726, grad_fn=<NllLossBackward>)
# train tensor(0.3067, grad_fn=<NllLossBackward>)
# train tensor(0.2403, grad_fn=<NllLossBackward>)
# train tensor(0.4406, grad_fn=<NllLossBackward>)
# train tensor(0.2906, grad_fn=<NllLossBackward>)
# train tensor(0.3017, grad_fn=<NllLossBackward>)
# train tensor(0.3397, grad_fn=<NllLossBackward>)
# train tensor(0.5157, grad_fn=<NllLossBackward>)
# train tensor(0.4802, grad_fn=<NllLossBackward>)
# train tensor(0.5390, grad_fn=<NllLossBackward>)
# train tensor(0.5586, grad_fn=<NllLossBackward>)
# train tensor(0.2708, grad_fn=<NllLossBackward>)
# train tensor(0.3219, grad_fn=<NllLossBackward>)
# train tensor(0.3166, grad_fn=<NllLossBackward>)
# train tensor(0.4150, grad_fn=<NllLossBackward>)
# train tensor(0.2971, grad_fn=<NllLossBackward>)
# train tensor(0.4335, grad_fn=<NllLossBackward>)
# train tensor(0.4457, grad_fn=<NllLossBackward>)
# train tensor(0.2052, grad_fn=<NllLossBackward>)
# train tensor(0.2677, grad_fn=<NllLossBackward>)
# train tensor(0.4017, grad_fn=<NllLossBackward>)
# train tensor(0.4431, grad_fn=<NllLossBackward>)
# train tensor(0.2163, grad_fn=<NllLossBackward>)
# train tensor(0.3478, grad_fn=<NllLossBackward>)
# train tensor(0.4027, grad_fn=<NllLossBackward>)
# train tensor(0.5203, grad_fn=<NllLossBackward>)
# train tensor(0.2073, grad_fn=<NllLossBackward>)
# train tensor(0.3460, grad_fn=<NllLossBackward>)
# train tensor(0.2762, grad_fn=<NllLossBackward>)
# train tensor(0.3812, grad_fn=<NllLossBackward>)
# train tensor(0.5054, grad_fn=<NllLossBackward>)
# train tensor(0.4079, grad_fn=<NllLossBackward>)
# train tensor(0.3788, grad_fn=<NllLossBackward>)
# train tensor(0.2833, grad_fn=<NllLossBackward>)
# train tensor(0.6714, grad_fn=<NllLossBackward>)
# train tensor(0.4205, grad_fn=<NllLossBackward>)
# train tensor(0.4949, grad_fn=<NllLossBackward>)
# train tensor(0.3290, grad_fn=<NllLossBackward>)
# train tensor(0.5204, grad_fn=<NllLossBackward>)
# train tensor(0.4125, grad_fn=<NllLossBackward>)
# train tensor(0.3282, grad_fn=<NllLossBackward>)
# train tensor(0.3964, grad_fn=<NllLossBackward>)
# train tensor(0.2763, grad_fn=<NllLossBackward>)
# train tensor(0.5235, grad_fn=<NllLossBackward>)
# train tensor(0.4292, grad_fn=<NllLossBackward>)
# train tensor(0.4281, grad_fn=<NllLossBackward>)
# train tensor(0.3063, grad_fn=<NllLossBackward>)
# train tensor(0.4663, grad_fn=<NllLossBackward>)
# train tensor(0.5414, grad_fn=<NllLossBackward>)
# train tensor(0.3913, grad_fn=<NllLossBackward>)
# train tensor(0.2341, grad_fn=<NllLossBackward>)
# train tensor(0.2641, grad_fn=<NllLossBackward>)
# train tensor(0.3705, grad_fn=<NllLossBackward>)
# train tensor(0.4415, grad_fn=<NllLossBackward>)
# train tensor(0.4897, grad_fn=<NllLossBackward>)
# train tensor(0.1785, grad_fn=<NllLossBackward>)
# train tensor(0.6448, grad_fn=<NllLossBackward>)
# train tensor(0.5079, grad_fn=<NllLossBackward>)
# train tensor(0.3502, grad_fn=<NllLossBackward>)
# train tensor(0.4329, grad_fn=<NllLossBackward>)
# train tensor(0.4197, grad_fn=<NllLossBackward>)
# train tensor(0.3472, grad_fn=<NllLossBackward>)
# train tensor(0.3614, grad_fn=<NllLossBackward>)
# train tensor(0.3751, grad_fn=<NllLossBackward>)
# train tensor(0.6256, grad_fn=<NllLossBackward>)
# train tensor(0.3517, grad_fn=<NllLossBackward>)
# train tensor(0.3760, grad_fn=<NllLossBackward>)
# train tensor(0.2931, grad_fn=<NllLossBackward>)
# train tensor(0.3152, grad_fn=<NllLossBackward>)
# train tensor(0.2991, grad_fn=<NllLossBackward>)
# train tensor(0.2566, grad_fn=<NllLossBackward>)
# train tensor(0.2029, grad_fn=<NllLossBackward>)
# train tensor(0.5182, grad_fn=<NllLossBackward>)
# train tensor(0.3657, grad_fn=<NllLossBackward>)
# train tensor(0.2251, grad_fn=<NllLossBackward>)
# train tensor(0.2267, grad_fn=<NllLossBackward>)
# train tensor(0.1968, grad_fn=<NllLossBackward>)
# train tensor(0.6016, grad_fn=<NllLossBackward>)
# train tensor(0.2835, grad_fn=<NllLossBackward>)
# train tensor(0.3260, grad_fn=<NllLossBackward>)
# train tensor(0.5019, grad_fn=<NllLossBackward>)
# train tensor(0.3219, grad_fn=<NllLossBackward>)
# train tensor(0.3854, grad_fn=<NllLossBackward>)
# train tensor(0.3355, grad_fn=<NllLossBackward>)
# train tensor(0.4522, grad_fn=<NllLossBackward>)
# train tensor(0.4151, grad_fn=<NllLossBackward>)
# train tensor(0.2909, grad_fn=<NllLossBackward>)
# train tensor(0.4422, grad_fn=<NllLossBackward>)
# train tensor(0.3808, grad_fn=<NllLossBackward>)
# train tensor(0.5611, grad_fn=<NllLossBackward>)
# train tensor(0.2951, grad_fn=<NllLossBackward>)
# train tensor(0.2880, grad_fn=<NllLossBackward>)
# train tensor(0.5016, grad_fn=<NllLossBackward>)
# train tensor(0.2240, grad_fn=<NllLossBackward>)
# train tensor(0.4547, grad_fn=<NllLossBackward>)
# train tensor(0.3584, grad_fn=<NllLossBackward>)
# train tensor(0.2968, grad_fn=<NllLossBackward>)
# train tensor(0.2417, grad_fn=<NllLossBackward>)
# train tensor(0.2789, grad_fn=<NllLossBackward>)
# train tensor(0.5964, grad_fn=<NllLossBackward>)
# train tensor(0.3670, grad_fn=<NllLossBackward>)
# train tensor(0.1821, grad_fn=<NllLossBackward>)
# train tensor(0.1887, grad_fn=<NllLossBackward>)
# train tensor(0.3000, grad_fn=<NllLossBackward>)
# train tensor(0.4459, grad_fn=<NllLossBackward>)
# train tensor(0.3603, grad_fn=<NllLossBackward>)
# train tensor(0.2179, grad_fn=<NllLossBackward>)
# train tensor(0.4106, grad_fn=<NllLossBackward>)
# train tensor(0.4743, grad_fn=<NllLossBackward>)
# train tensor(0.2467, grad_fn=<NllLossBackward>)
# train tensor(0.1828, grad_fn=<NllLossBackward>)
# train tensor(0.2504, grad_fn=<NllLossBackward>)
# train tensor(0.3755, grad_fn=<NllLossBackward>)
# train tensor(0.3845, grad_fn=<NllLossBackward>)
# train tensor(0.3796, grad_fn=<NllLossBackward>)
# train tensor(0.2856, grad_fn=<NllLossBackward>)
# train tensor(0.3966, grad_fn=<NllLossBackward>)
# train tensor(0.2861, grad_fn=<NllLossBackward>)
# train tensor(0.4148, grad_fn=<NllLossBackward>)
# train tensor(0.3450, grad_fn=<NllLossBackward>)
# train tensor(0.6122, grad_fn=<NllLossBackward>)
# train tensor(0.4943, grad_fn=<NllLossBackward>)
# train tensor(0.3526, grad_fn=<NllLossBackward>)
# train tensor(0.5065, grad_fn=<NllLossBackward>)
# train tensor(0.1505, grad_fn=<NllLossBackward>)
# train tensor(0.2489, grad_fn=<NllLossBackward>)
# train tensor(0.3049, grad_fn=<NllLossBackward>)
# train tensor(0.5140, grad_fn=<NllLossBackward>)
# train tensor(0.3533, grad_fn=<NllLossBackward>)
# train tensor(0.2534, grad_fn=<NllLossBackward>)
# train tensor(0.6128, grad_fn=<NllLossBackward>)
# train tensor(0.4115, grad_fn=<NllLossBackward>)
# train tensor(0.2578, grad_fn=<NllLossBackward>)
# train tensor(0.3155, grad_fn=<NllLossBackward>)
# train tensor(0.3926, grad_fn=<NllLossBackward>)
# train tensor(0.2849, grad_fn=<NllLossBackward>)
# train tensor(0.2440, grad_fn=<NllLossBackward>)
# train tensor(0.3166, grad_fn=<NllLossBackward>)
# train tensor(0.3100, grad_fn=<NllLossBackward>)
# train tensor(0.3436, grad_fn=<NllLossBackward>)
# train tensor(0.3319, grad_fn=<NllLossBackward>)
# train tensor(0.3984, grad_fn=<NllLossBackward>)
# train tensor(0.4272, grad_fn=<NllLossBackward>)
# train tensor(0.1712, grad_fn=<NllLossBackward>)
# train tensor(0.3285, grad_fn=<NllLossBackward>)
# train tensor(0.4045, grad_fn=<NllLossBackward>)
# train tensor(0.4789, grad_fn=<NllLossBackward>)
# train tensor(0.5189, grad_fn=<NllLossBackward>)
# train tensor(0.3979, grad_fn=<NllLossBackward>)
# train tensor(0.3415, grad_fn=<NllLossBackward>)
# train tensor(0.2204, grad_fn=<NllLossBackward>)
# train tensor(0.6245, grad_fn=<NllLossBackward>)
# train tensor(0.2715, grad_fn=<NllLossBackward>)
# train tensor(0.5299, grad_fn=<NllLossBackward>)
# train tensor(0.3184, grad_fn=<NllLossBackward>)
# train tensor(0.1671, grad_fn=<NllLossBackward>)
# train tensor(0.3877, grad_fn=<NllLossBackward>)
# train tensor(0.3808, grad_fn=<NllLossBackward>)
# train tensor(0.4478, grad_fn=<NllLossBackward>)
# train tensor(0.2537, grad_fn=<NllLossBackward>)
# train tensor(0.3999, grad_fn=<NllLossBackward>)
# train tensor(0.4527, grad_fn=<NllLossBackward>)
# train tensor(0.3053, grad_fn=<NllLossBackward>)
# train tensor(0.3919, grad_fn=<NllLossBackward>)
# train tensor(0.2467, grad_fn=<NllLossBackward>)
# train tensor(0.4321, grad_fn=<NllLossBackward>)
# train tensor(0.5264, grad_fn=<NllLossBackward>)
# train tensor(0.2107, grad_fn=<NllLossBackward>)
# train tensor(0.4135, grad_fn=<NllLossBackward>)
# train tensor(0.1918, grad_fn=<NllLossBackward>)
# train tensor(0.2382, grad_fn=<NllLossBackward>)
# train tensor(0.5493, grad_fn=<NllLossBackward>)
# train tensor(0.3795, grad_fn=<NllLossBackward>)
# train tensor(0.3320, grad_fn=<NllLossBackward>)
# train tensor(0.4594, grad_fn=<NllLossBackward>)
# train tensor(0.3322, grad_fn=<NllLossBackward>)
# train tensor(0.3894, grad_fn=<NllLossBackward>)
# train tensor(0.4134, grad_fn=<NllLossBackward>)
# train tensor(0.4972, grad_fn=<NllLossBackward>)
# train tensor(0.3748, grad_fn=<NllLossBackward>)
# train tensor(0.4872, grad_fn=<NllLossBackward>)
# train tensor(0.5271, grad_fn=<NllLossBackward>)
# train tensor(0.4043, grad_fn=<NllLossBackward>)
# train tensor(0.2988, grad_fn=<NllLossBackward>)
# train tensor(0.4090, grad_fn=<NllLossBackward>)
# train tensor(0.2801, grad_fn=<NllLossBackward>)
# train tensor(0.6783, grad_fn=<NllLossBackward>)
# train tensor(0.2762, grad_fn=<NllLossBackward>)
# train tensor(0.4325, grad_fn=<NllLossBackward>)
# train tensor(0.3808, grad_fn=<NllLossBackward>)
# train tensor(0.2793, grad_fn=<NllLossBackward>)
# train tensor(0.2632, grad_fn=<NllLossBackward>)
# train tensor(0.2943, grad_fn=<NllLossBackward>)
# train tensor(0.2908, grad_fn=<NllLossBackward>)
# train tensor(0.2187, grad_fn=<NllLossBackward>)
# train tensor(0.3459, grad_fn=<NllLossBackward>)
# train tensor(0.4846, grad_fn=<NllLossBackward>)
# train tensor(0.3617, grad_fn=<NllLossBackward>)
# train tensor(0.5039, grad_fn=<NllLossBackward>)
# train tensor(0.3620, grad_fn=<NllLossBackward>)
# train tensor(0.4626, grad_fn=<NllLossBackward>)
# train tensor(0.4347, grad_fn=<NllLossBackward>)
# train tensor(0.2913, grad_fn=<NllLossBackward>)
# train tensor(0.3032, grad_fn=<NllLossBackward>)
# train tensor(0.7294, grad_fn=<NllLossBackward>)
# train tensor(0.4999, grad_fn=<NllLossBackward>)
# train tensor(0.3697, grad_fn=<NllLossBackward>)
# train tensor(0.5359, grad_fn=<NllLossBackward>)
# train tensor(0.4247, grad_fn=<NllLossBackward>)
# train tensor(0.3074, grad_fn=<NllLossBackward>)
# train tensor(0.3114, grad_fn=<NllLossBackward>)
# train tensor(0.3209, grad_fn=<NllLossBackward>)
# train tensor(0.4228, grad_fn=<NllLossBackward>)
# train tensor(0.2829, grad_fn=<NllLossBackward>)
# train tensor(0.3323, grad_fn=<NllLossBackward>)
# train tensor(0.2321, grad_fn=<NllLossBackward>)
# train tensor(0.3987, grad_fn=<NllLossBackward>)
# train tensor(0.3992, grad_fn=<NllLossBackward>)
# train tensor(0.4195, grad_fn=<NllLossBackward>)
# train tensor(0.3794, grad_fn=<NllLossBackward>)
# train tensor(0.3542, grad_fn=<NllLossBackward>)
# train tensor(0.3767, grad_fn=<NllLossBackward>)
# train tensor(0.4140, grad_fn=<NllLossBackward>)
# train tensor(0.5393, grad_fn=<NllLossBackward>)
# train tensor(0.6132, grad_fn=<NllLossBackward>)
# train tensor(0.1956, grad_fn=<NllLossBackward>)
# train tensor(0.5369, grad_fn=<NllLossBackward>)
# train tensor(0.3938, grad_fn=<NllLossBackward>)
# train tensor(0.4497, grad_fn=<NllLossBackward>)
# train tensor(0.2385, grad_fn=<NllLossBackward>)
# train tensor(0.4345, grad_fn=<NllLossBackward>)
# train tensor(0.4468, grad_fn=<NllLossBackward>)
# train tensor(0.3518, grad_fn=<NllLossBackward>)
# train tensor(0.4696, grad_fn=<NllLossBackward>)
# train tensor(0.3629, grad_fn=<NllLossBackward>)
# train tensor(0.2427, grad_fn=<NllLossBackward>)
# train tensor(0.2107, grad_fn=<NllLossBackward>)
# train tensor(0.3322, grad_fn=<NllLossBackward>)
# train tensor(0.5210, grad_fn=<NllLossBackward>)
# train tensor(0.3610, grad_fn=<NllLossBackward>)
# train tensor(0.3142, grad_fn=<NllLossBackward>)
# train tensor(0.3138, grad_fn=<NllLossBackward>)
# train tensor(0.2371, grad_fn=<NllLossBackward>)
# train tensor(0.6797, grad_fn=<NllLossBackward>)
# train tensor(0.5135, grad_fn=<NllLossBackward>)
# train tensor(0.3576, grad_fn=<NllLossBackward>)
# train tensor(0.3921, grad_fn=<NllLossBackward>)
# train tensor(0.1937, grad_fn=<NllLossBackward>)
# train tensor(0.2581, grad_fn=<NllLossBackward>)
# train tensor(0.3724, grad_fn=<NllLossBackward>)
# train tensor(0.4055, grad_fn=<NllLossBackward>)
# train tensor(0.3066, grad_fn=<NllLossBackward>)
# train tensor(0.3227, grad_fn=<NllLossBackward>)
# train tensor(0.3782, grad_fn=<NllLossBackward>)
# train tensor(0.1788, grad_fn=<NllLossBackward>)
# train tensor(0.4340, grad_fn=<NllLossBackward>)
# train tensor(0.1845, grad_fn=<NllLossBackward>)
# train tensor(0.2346, grad_fn=<NllLossBackward>)
# train tensor(0.5547, grad_fn=<NllLossBackward>)
# train tensor(0.3887, grad_fn=<NllLossBackward>)
# train tensor(0.4118, grad_fn=<NllLossBackward>)
# train tensor(0.3248, grad_fn=<NllLossBackward>)
# train tensor(0.4950, grad_fn=<NllLossBackward>)
# train tensor(0.4507, grad_fn=<NllLossBackward>)
# train tensor(0.4168, grad_fn=<NllLossBackward>)
# train tensor(0.2124, grad_fn=<NllLossBackward>)
# train tensor(0.2454, grad_fn=<NllLossBackward>)
# train tensor(0.3188, grad_fn=<NllLossBackward>)
# train tensor(0.1319, grad_fn=<NllLossBackward>)
# train tensor(0.2340, grad_fn=<NllLossBackward>)
# train tensor(0.5312, grad_fn=<NllLossBackward>)
# train tensor(0.4852, grad_fn=<NllLossBackward>)
# train tensor(0.3260, grad_fn=<NllLossBackward>)
# train tensor(0.1258, grad_fn=<NllLossBackward>)
# train tensor(0.1187, grad_fn=<NllLossBackward>)
# train tensor(0.3505, grad_fn=<NllLossBackward>)
# train tensor(0.3051, grad_fn=<NllLossBackward>)
# train tensor(0.4233, grad_fn=<NllLossBackward>)
# train tensor(0.2149, grad_fn=<NllLossBackward>)
# train tensor(0.2592, grad_fn=<NllLossBackward>)
# train tensor(0.2657, grad_fn=<NllLossBackward>)
# train tensor(0.4533, grad_fn=<NllLossBackward>)
# train tensor(0.2740, grad_fn=<NllLossBackward>)
# train tensor(0.2779, grad_fn=<NllLossBackward>)
# train tensor(0.3425, grad_fn=<NllLossBackward>)
# train tensor(0.3699, grad_fn=<NllLossBackward>)
# train tensor(0.3057, grad_fn=<NllLossBackward>)
# train tensor(0.3027, grad_fn=<NllLossBackward>)
# train tensor(0.2776, grad_fn=<NllLossBackward>)
# train tensor(0.3744, grad_fn=<NllLossBackward>)
# train tensor(0.4014, grad_fn=<NllLossBackward>)
# train tensor(0.3363, grad_fn=<NllLossBackward>)
# train tensor(0.3174, grad_fn=<NllLossBackward>)
# train tensor(0.3190, grad_fn=<NllLossBackward>)
# train tensor(0.3852, grad_fn=<NllLossBackward>)
# train tensor(0.1496, grad_fn=<NllLossBackward>)
# train tensor(0.6552, grad_fn=<NllLossBackward>)
# train tensor(0.4239, grad_fn=<NllLossBackward>)
# train tensor(0.2574, grad_fn=<NllLossBackward>)
# train tensor(0.2029, grad_fn=<NllLossBackward>)
# train tensor(0.3809, grad_fn=<NllLossBackward>)
# train tensor(0.3552, grad_fn=<NllLossBackward>)
# train tensor(0.3337, grad_fn=<NllLossBackward>)
# train tensor(0.2477, grad_fn=<NllLossBackward>)
# train tensor(0.2163, grad_fn=<NllLossBackward>)
# train tensor(0.4986, grad_fn=<NllLossBackward>)
# train tensor(0.1871, grad_fn=<NllLossBackward>)
# train tensor(0.3999, grad_fn=<NllLossBackward>)
# train tensor(0.2413, grad_fn=<NllLossBackward>)
# train tensor(0.2777, grad_fn=<NllLossBackward>)
# train tensor(0.4045, grad_fn=<NllLossBackward>)
# train tensor(0.4007, grad_fn=<NllLossBackward>)
# train tensor(0.4841, grad_fn=<NllLossBackward>)
# train tensor(0.5536, grad_fn=<NllLossBackward>)
# train tensor(0.6241, grad_fn=<NllLossBackward>)
# train tensor(0.2322, grad_fn=<NllLossBackward>)
# train tensor(0.3803, grad_fn=<NllLossBackward>)
# train tensor(0.5541, grad_fn=<NllLossBackward>)
# train tensor(0.3573, grad_fn=<NllLossBackward>)
# train tensor(0.4185, grad_fn=<NllLossBackward>)
# train tensor(0.2958, grad_fn=<NllLossBackward>)
# train tensor(0.3411, grad_fn=<NllLossBackward>)
# train tensor(0.3831, grad_fn=<NllLossBackward>)
# train tensor(0.2481, grad_fn=<NllLossBackward>)
# train tensor(0.4202, grad_fn=<NllLossBackward>)
# train tensor(0.2959, grad_fn=<NllLossBackward>)
# train tensor(0.5543, grad_fn=<NllLossBackward>)
# train tensor(0.3637, grad_fn=<NllLossBackward>)
# train tensor(0.2809, grad_fn=<NllLossBackward>)
# train tensor(0.5687, grad_fn=<NllLossBackward>)
# train tensor(0.4461, grad_fn=<NllLossBackward>)
# train tensor(0.2164, grad_fn=<NllLossBackward>)
# train tensor(0.3843, grad_fn=<NllLossBackward>)
# train tensor(0.3912, grad_fn=<NllLossBackward>)
# train tensor(0.3985, grad_fn=<NllLossBackward>)
# train tensor(0.3620, grad_fn=<NllLossBackward>)
# train tensor(0.3146, grad_fn=<NllLossBackward>)
# train tensor(0.2903, grad_fn=<NllLossBackward>)
# train tensor(0.3699, grad_fn=<NllLossBackward>)
# train tensor(0.3235, grad_fn=<NllLossBackward>)
# train tensor(0.3433, grad_fn=<NllLossBackward>)
# train tensor(0.3282, grad_fn=<NllLossBackward>)
# train tensor(0.2992, grad_fn=<NllLossBackward>)
# train tensor(0.2686, grad_fn=<NllLossBackward>)
# train tensor(0.3820, grad_fn=<NllLossBackward>)
# train tensor(0.5478, grad_fn=<NllLossBackward>)
# train tensor(0.2976, grad_fn=<NllLossBackward>)
# train tensor(0.6748, grad_fn=<NllLossBackward>)
# train tensor(0.3136, grad_fn=<NllLossBackward>)
# train tensor(0.2730, grad_fn=<NllLossBackward>)
# train tensor(0.2381, grad_fn=<NllLossBackward>)
# train tensor(0.2177, grad_fn=<NllLossBackward>)
# train tensor(0.3551, grad_fn=<NllLossBackward>)
# train tensor(0.4615, grad_fn=<NllLossBackward>)
# train tensor(0.2997, grad_fn=<NllLossBackward>)
# train tensor(0.3896, grad_fn=<NllLossBackward>)
# train tensor(0.3268, grad_fn=<NllLossBackward>)
# train tensor(0.3407, grad_fn=<NllLossBackward>)
# train tensor(0.2304, grad_fn=<NllLossBackward>)
# train tensor(0.2470, grad_fn=<NllLossBackward>)
# train tensor(0.4250, grad_fn=<NllLossBackward>)
# train tensor(0.1923, grad_fn=<NllLossBackward>)
# train tensor(0.3232, grad_fn=<NllLossBackward>)
# train tensor(0.2230, grad_fn=<NllLossBackward>)
# train tensor(0.1654, grad_fn=<NllLossBackward>)
# train tensor(0.3075, grad_fn=<NllLossBackward>)
# train tensor(0.1766, grad_fn=<NllLossBackward>)
# train tensor(0.2219, grad_fn=<NllLossBackward>)
# train tensor(0.1942, grad_fn=<NllLossBackward>)
# train tensor(0.2478, grad_fn=<NllLossBackward>)
# train tensor(0.1827, grad_fn=<NllLossBackward>)
# train tensor(0.3351, grad_fn=<NllLossBackward>)
# train tensor(0.3104, grad_fn=<NllLossBackward>)
# train tensor(0.1247, grad_fn=<NllLossBackward>)
# train tensor(0.1582, grad_fn=<NllLossBackward>)
# train tensor(0.2886, grad_fn=<NllLossBackward>)
# train tensor(0.1546, grad_fn=<NllLossBackward>)
# train tensor(0.2616, grad_fn=<NllLossBackward>)
# train tensor(0.2244, grad_fn=<NllLossBackward>)
# train tensor(0.7060, grad_fn=<NllLossBackward>)
# train tensor(0.3798, grad_fn=<NllLossBackward>)
# train tensor(0.1854, grad_fn=<NllLossBackward>)
# train tensor(0.3608, grad_fn=<NllLossBackward>)
# train tensor(0.3897, grad_fn=<NllLossBackward>)
# train tensor(0.5181, grad_fn=<NllLossBackward>)
# train tensor(0.4005, grad_fn=<NllLossBackward>)
# train tensor(0.2370, grad_fn=<NllLossBackward>)
# train tensor(0.2324, grad_fn=<NllLossBackward>)
# train tensor(0.2569, grad_fn=<NllLossBackward>)
# train tensor(0.5165, grad_fn=<NllLossBackward>)
# train tensor(0.3266, grad_fn=<NllLossBackward>)
# train tensor(0.3203, grad_fn=<NllLossBackward>)
# train tensor(0.6231, grad_fn=<NllLossBackward>)
# train tensor(0.4971, grad_fn=<NllLossBackward>)
# train tensor(0.2364, grad_fn=<NllLossBackward>)
# train tensor(0.1568, grad_fn=<NllLossBackward>)
# train tensor(0.2990, grad_fn=<NllLossBackward>)
# train tensor(0.2914, grad_fn=<NllLossBackward>)
# train tensor(0.3911, grad_fn=<NllLossBackward>)
# train tensor(0.3166, grad_fn=<NllLossBackward>)
# train tensor(0.2137, grad_fn=<NllLossBackward>)
# train tensor(0.3352, grad_fn=<NllLossBackward>)
# train tensor(0.4564, grad_fn=<NllLossBackward>)
# train tensor(0.2447, grad_fn=<NllLossBackward>)
# train tensor(0.2434, grad_fn=<NllLossBackward>)
# train tensor(0.1928, grad_fn=<NllLossBackward>)
# train tensor(0.1576, grad_fn=<NllLossBackward>)
# train tensor(0.3299, grad_fn=<NllLossBackward>)
# train tensor(0.4167, grad_fn=<NllLossBackward>)
# train tensor(0.3303, grad_fn=<NllLossBackward>)
# train tensor(0.1561, grad_fn=<NllLossBackward>)
# train tensor(0.3545, grad_fn=<NllLossBackward>)
# train tensor(0.3567, grad_fn=<NllLossBackward>)
# train tensor(0.2593, grad_fn=<NllLossBackward>)
# train tensor(0.3026, grad_fn=<NllLossBackward>)
# train tensor(0.4129, grad_fn=<NllLossBackward>)
# train tensor(0.2379, grad_fn=<NllLossBackward>)
# train tensor(0.3337, grad_fn=<NllLossBackward>)
# train tensor(0.2813, grad_fn=<NllLossBackward>)
# train tensor(0.2987, grad_fn=<NllLossBackward>)
# train tensor(0.2264, grad_fn=<NllLossBackward>)
# train tensor(0.3206, grad_fn=<NllLossBackward>)
# train tensor(0.3954, grad_fn=<NllLossBackward>)
# train tensor(0.3072, grad_fn=<NllLossBackward>)
# train tensor(0.2088, grad_fn=<NllLossBackward>)
# train tensor(0.1914, grad_fn=<NllLossBackward>)
# train tensor(0.3217, grad_fn=<NllLossBackward>)
# train tensor(0.5496, grad_fn=<NllLossBackward>)
# train tensor(0.3607, grad_fn=<NllLossBackward>)
# train tensor(0.3791, grad_fn=<NllLossBackward>)
# train tensor(0.2926, grad_fn=<NllLossBackward>)
# train tensor(0.4344, grad_fn=<NllLossBackward>)
# train tensor(0.4177, grad_fn=<NllLossBackward>)
# train tensor(0.2811, grad_fn=<NllLossBackward>)
# train tensor(0.3757, grad_fn=<NllLossBackward>)
# train tensor(0.1986, grad_fn=<NllLossBackward>)
# train tensor(0.3028, grad_fn=<NllLossBackward>)
# train tensor(0.1943, grad_fn=<NllLossBackward>)
# train tensor(0.2978, grad_fn=<NllLossBackward>)
# train tensor(0.3303, grad_fn=<NllLossBackward>)
# train tensor(0.1844, grad_fn=<NllLossBackward>)
# train tensor(0.3184, grad_fn=<NllLossBackward>)
# train tensor(0.5473, grad_fn=<NllLossBackward>)
# train tensor(0.3734, grad_fn=<NllLossBackward>)
# train tensor(0.2078, grad_fn=<NllLossBackward>)
# train tensor(0.3545, grad_fn=<NllLossBackward>)
# train tensor(0.4451, grad_fn=<NllLossBackward>)
# train tensor(0.2639, grad_fn=<NllLossBackward>)
# train tensor(0.3072, grad_fn=<NllLossBackward>)
# train tensor(0.3105, grad_fn=<NllLossBackward>)
# train tensor(0.2146, grad_fn=<NllLossBackward>)
# train tensor(0.3353, grad_fn=<NllLossBackward>)
# train tensor(0.3555, grad_fn=<NllLossBackward>)
# train tensor(0.4505, grad_fn=<NllLossBackward>)
# train tensor(0.1948, grad_fn=<NllLossBackward>)
# train tensor(0.2702, grad_fn=<NllLossBackward>)
# train tensor(0.4508, grad_fn=<NllLossBackward>)
# train tensor(0.3120, grad_fn=<NllLossBackward>)
# train tensor(0.1739, grad_fn=<NllLossBackward>)
# train tensor(0.3206, grad_fn=<NllLossBackward>)
# train tensor(0.2840, grad_fn=<NllLossBackward>)
# train tensor(0.2781, grad_fn=<NllLossBackward>)
# train tensor(0.3598, grad_fn=<NllLossBackward>)
# train tensor(0.5481, grad_fn=<NllLossBackward>)
# train tensor(0.3850, grad_fn=<NllLossBackward>)
# train tensor(0.4171, grad_fn=<NllLossBackward>)
# train tensor(0.3992, grad_fn=<NllLossBackward>)
# train tensor(0.1943, grad_fn=<NllLossBackward>)
# train tensor(0.3082, grad_fn=<NllLossBackward>)
# train tensor(0.4626, grad_fn=<NllLossBackward>)
# train tensor(0.3588, grad_fn=<NllLossBackward>)
# train tensor(0.3040, grad_fn=<NllLossBackward>)
# train tensor(0.4486, grad_fn=<NllLossBackward>)
# train tensor(0.2635, grad_fn=<NllLossBackward>)
# train tensor(0.2467, grad_fn=<NllLossBackward>)
# train tensor(0.3631, grad_fn=<NllLossBackward>)
# train tensor(0.4676, grad_fn=<NllLossBackward>)
# train tensor(0.2980, grad_fn=<NllLossBackward>)
# train tensor(0.1832, grad_fn=<NllLossBackward>)
# train tensor(0.2738, grad_fn=<NllLossBackward>)
# train tensor(0.3315, grad_fn=<NllLossBackward>)
# train tensor(0.2249, grad_fn=<NllLossBackward>)
# train tensor(0.4538, grad_fn=<NllLossBackward>)
# train tensor(0.3268, grad_fn=<NllLossBackward>)
# train tensor(0.3079, grad_fn=<NllLossBackward>)
# train tensor(0.3704, grad_fn=<NllLossBackward>)
# train tensor(0.2098, grad_fn=<NllLossBackward>)
# train tensor(0.2902, grad_fn=<NllLossBackward>)
# train tensor(0.4417, grad_fn=<NllLossBackward>)
# train tensor(0.3488, grad_fn=<NllLossBackward>)
# train tensor(0.1764, grad_fn=<NllLossBackward>)
# train tensor(0.1538, grad_fn=<NllLossBackward>)
# train tensor(0.4193, grad_fn=<NllLossBackward>)
# train tensor(0.2736, grad_fn=<NllLossBackward>)
# train tensor(0.4597, grad_fn=<NllLossBackward>)
# train tensor(0.2931, grad_fn=<NllLossBackward>)
# train tensor(0.3087, grad_fn=<NllLossBackward>)
# train tensor(0.3244, grad_fn=<NllLossBackward>)
# train tensor(0.4066, grad_fn=<NllLossBackward>)
# train tensor(0.3950, grad_fn=<NllLossBackward>)
# train tensor(0.4654, grad_fn=<NllLossBackward>)
# train tensor(0.2412, grad_fn=<NllLossBackward>)
# train tensor(0.3545, grad_fn=<NllLossBackward>)
# train tensor(0.4067, grad_fn=<NllLossBackward>)
# train tensor(0.4584, grad_fn=<NllLossBackward>)
# train tensor(0.3695, grad_fn=<NllLossBackward>)
# train tensor(0.2730, grad_fn=<NllLossBackward>)
# train tensor(0.2275, grad_fn=<NllLossBackward>)
# train tensor(0.3467, grad_fn=<NllLossBackward>)
# train tensor(0.2892, grad_fn=<NllLossBackward>)
# train tensor(0.3904, grad_fn=<NllLossBackward>)
# train tensor(0.2424, grad_fn=<NllLossBackward>)
# train tensor(0.1744, grad_fn=<NllLossBackward>)
# train tensor(0.2641, grad_fn=<NllLossBackward>)
# train tensor(0.3407, grad_fn=<NllLossBackward>)
# train tensor(0.1897, grad_fn=<NllLossBackward>)
# train tensor(0.4701, grad_fn=<NllLossBackward>)
# train tensor(0.3441, grad_fn=<NllLossBackward>)
# train tensor(0.3483, grad_fn=<NllLossBackward>)
# train tensor(0.2741, grad_fn=<NllLossBackward>)
# train tensor(0.1456, grad_fn=<NllLossBackward>)
# train tensor(0.2574, grad_fn=<NllLossBackward>)
# train tensor(0.2681, grad_fn=<NllLossBackward>)
# train tensor(0.2086, grad_fn=<NllLossBackward>)
# train tensor(0.2218, grad_fn=<NllLossBackward>)
# train tensor(0.3689, grad_fn=<NllLossBackward>)
# train tensor(0.4997, grad_fn=<NllLossBackward>)
# train tensor(0.3606, grad_fn=<NllLossBackward>)
# train tensor(0.4497, grad_fn=<NllLossBackward>)
# train tensor(0.2048, grad_fn=<NllLossBackward>)
# train tensor(0.1390, grad_fn=<NllLossBackward>)
# train tensor(0.2826, grad_fn=<NllLossBackward>)
# train tensor(0.3273, grad_fn=<NllLossBackward>)
# train tensor(0.3267, grad_fn=<NllLossBackward>)
# train tensor(0.5172, grad_fn=<NllLossBackward>)
# train tensor(0.4102, grad_fn=<NllLossBackward>)
# train tensor(0.1639, grad_fn=<NllLossBackward>)
# train tensor(0.2445, grad_fn=<NllLossBackward>)
# train tensor(0.3363, grad_fn=<NllLossBackward>)
# train tensor(0.2739, grad_fn=<NllLossBackward>)
# train tensor(0.1704, grad_fn=<NllLossBackward>)
# train tensor(0.4014, grad_fn=<NllLossBackward>)
# train tensor(0.2953, grad_fn=<NllLossBackward>)
# train tensor(0.1970, grad_fn=<NllLossBackward>)
# train tensor(0.3612, grad_fn=<NllLossBackward>)
# train tensor(0.3738, grad_fn=<NllLossBackward>)
# train tensor(0.3775, grad_fn=<NllLossBackward>)
# train tensor(0.2468, grad_fn=<NllLossBackward>)
# train tensor(0.2972, grad_fn=<NllLossBackward>)
# train tensor(0.4549, grad_fn=<NllLossBackward>)
# train tensor(0.5230, grad_fn=<NllLossBackward>)
# train tensor(0.2205, grad_fn=<NllLossBackward>)
# train tensor(0.6658, grad_fn=<NllLossBackward>)
# train tensor(0.3911, grad_fn=<NllLossBackward>)
# train tensor(0.2319, grad_fn=<NllLossBackward>)
# train tensor(0.5994, grad_fn=<NllLossBackward>)
# train tensor(0.1742, grad_fn=<NllLossBackward>)
# train tensor(0.4088, grad_fn=<NllLossBackward>)
# train tensor(0.3712, grad_fn=<NllLossBackward>)
# train tensor(0.3822, grad_fn=<NllLossBackward>)
# train tensor(0.2702, grad_fn=<NllLossBackward>)
# train tensor(0.5243, grad_fn=<NllLossBackward>)
# train tensor(0.4408, grad_fn=<NllLossBackward>)
# train tensor(0.2037, grad_fn=<NllLossBackward>)
# train tensor(0.3427, grad_fn=<NllLossBackward>)
# train tensor(0.2452, grad_fn=<NllLossBackward>)
# train tensor(0.2952, grad_fn=<NllLossBackward>)
# train tensor(0.2137, grad_fn=<NllLossBackward>)
# train tensor(0.4776, grad_fn=<NllLossBackward>)
# train tensor(0.2619, grad_fn=<NllLossBackward>)
# train tensor(0.2867, grad_fn=<NllLossBackward>)
# train tensor(0.3355, grad_fn=<NllLossBackward>)
# train tensor(0.2027, grad_fn=<NllLossBackward>)
# train tensor(0.3941, grad_fn=<NllLossBackward>)
# train tensor(0.3365, grad_fn=<NllLossBackward>)
# train tensor(0.3598, grad_fn=<NllLossBackward>)
# train tensor(0.2281, grad_fn=<NllLossBackward>)
# train tensor(0.3345, grad_fn=<NllLossBackward>)
# train tensor(0.2600, grad_fn=<NllLossBackward>)
# train tensor(0.3044, grad_fn=<NllLossBackward>)
# train tensor(0.5464, grad_fn=<NllLossBackward>)
# train tensor(0.2870, grad_fn=<NllLossBackward>)
# train tensor(0.4239, grad_fn=<NllLossBackward>)
# tensor(0.3251, grad_fn=<AddBackward0>)
# tensor(0.7494, grad_fn=<AddBackward0>)
# tensor(1.2213, grad_fn=<AddBackward0>)
# tensor(1.6995, grad_fn=<AddBackward0>)
# tensor(2.2073, grad_fn=<AddBackward0>)
# tensor(2.5164, grad_fn=<AddBackward0>)
# tensor(2.7718, grad_fn=<AddBackward0>)
# tensor(2.9898, grad_fn=<AddBackward0>)
# tensor(3.2409, grad_fn=<AddBackward0>)
# tensor(3.6635, grad_fn=<AddBackward0>)
# tensor(3.9816, grad_fn=<AddBackward0>)
# tensor(4.2394, grad_fn=<AddBackward0>)
# tensor(4.4594, grad_fn=<AddBackward0>)
# tensor(4.7946, grad_fn=<AddBackward0>)
# tensor(5.0305, grad_fn=<AddBackward0>)
# tensor(5.4510, grad_fn=<AddBackward0>)
# tensor(6.0966, grad_fn=<AddBackward0>)
# tensor(6.4912, grad_fn=<AddBackward0>)
# tensor(6.8732, grad_fn=<AddBackward0>)
# tensor(7.0889, grad_fn=<AddBackward0>)
# tensor(7.4158, grad_fn=<AddBackward0>)
# tensor(7.8154, grad_fn=<AddBackward0>)
# tensor(8.4343, grad_fn=<AddBackward0>)
# tensor(9.0260, grad_fn=<AddBackward0>)
# tensor(9.3361, grad_fn=<AddBackward0>)
# tensor(9.6028, grad_fn=<AddBackward0>)
# tensor(9.6945, grad_fn=<AddBackward0>)
# tensor(10.0997, grad_fn=<AddBackward0>)
# tensor(10.3890, grad_fn=<AddBackward0>)
# tensor(10.6314, grad_fn=<AddBackward0>)
# tensor(11.0359, grad_fn=<AddBackward0>)
# tensor(11.4813, grad_fn=<AddBackward0>)
# tensor(11.8798, grad_fn=<AddBackward0>)
# tensor(12.0561, grad_fn=<AddBackward0>)
# tensor(12.3841, grad_fn=<AddBackward0>)
# tensor(12.8085, grad_fn=<AddBackward0>)
# tensor(12.9982, grad_fn=<AddBackward0>)
# tensor(13.2930, grad_fn=<AddBackward0>)
# tensor(13.8567, grad_fn=<AddBackward0>)
# tensor(14.1483, grad_fn=<AddBackward0>)
# tensor(14.3923, grad_fn=<AddBackward0>)
# tensor(14.7311, grad_fn=<AddBackward0>)
# tensor(14.9489, grad_fn=<AddBackward0>)
# tensor(15.2389, grad_fn=<AddBackward0>)
# tensor(15.6259, grad_fn=<AddBackward0>)
# tensor(15.8721, grad_fn=<AddBackward0>)
# tensor(16.1024, grad_fn=<AddBackward0>)
# tensor(16.3059, grad_fn=<AddBackward0>)
# tensor(16.6663, grad_fn=<AddBackward0>)
# tensor(16.9659, grad_fn=<AddBackward0>)
# tensor(17.3848, grad_fn=<AddBackward0>)
# tensor(17.7171, grad_fn=<AddBackward0>)
# tensor(17.9156, grad_fn=<AddBackward0>)
# tensor(18.1803, grad_fn=<AddBackward0>)
# tensor(18.4745, grad_fn=<AddBackward0>)
# tensor(18.7534, grad_fn=<AddBackward0>)
# tensor(18.9854, grad_fn=<AddBackward0>)
# tensor(19.3089, grad_fn=<AddBackward0>)
# tensor(19.6940, grad_fn=<AddBackward0>)
# tensor(20.1429, grad_fn=<AddBackward0>)
# tensor(20.5058, grad_fn=<AddBackward0>)
# tensor(20.7401, grad_fn=<AddBackward0>)
# tensor(20.9813, grad_fn=<AddBackward0>)
# tensor(21.2100, grad_fn=<AddBackward0>)
# tensor(21.3709, grad_fn=<AddBackward0>)
# tensor(21.5197, grad_fn=<AddBackward0>)
# tensor(21.7167, grad_fn=<AddBackward0>)
# tensor(21.9506, grad_fn=<AddBackward0>)
# tensor(22.1584, grad_fn=<AddBackward0>)
# tensor(22.3208, grad_fn=<AddBackward0>)
# tensor(22.4466, grad_fn=<AddBackward0>)
# tensor(22.5682, grad_fn=<AddBackward0>)
# tensor(22.8418, grad_fn=<AddBackward0>)
# tensor(23.3794, grad_fn=<AddBackward0>)
# tensor(23.4756, grad_fn=<AddBackward0>)
# tensor(23.9209, grad_fn=<AddBackward0>)
# tensor(24.2527, grad_fn=<AddBackward0>)
# tensor(24.5199, grad_fn=<AddBackward0>)
# tensor(24.5752, grad_fn=<AddBackward0>)
# Epoch 0: 0.311
# train tensor(0.2875, grad_fn=<NllLossBackward>)
# train tensor(0.4231, grad_fn=<NllLossBackward>)
# train tensor(0.1890, grad_fn=<NllLossBackward>)
# train tensor(0.2536, grad_fn=<NllLossBackward>)
# train tensor(0.4762, grad_fn=<NllLossBackward>)
# train tensor(0.3693, grad_fn=<NllLossBackward>)
# train tensor(0.5531, grad_fn=<NllLossBackward>)
# train tensor(0.3364, grad_fn=<NllLossBackward>)
# train tensor(0.2382, grad_fn=<NllLossBackward>)
# train tensor(0.3300, grad_fn=<NllLossBackward>)
# train tensor(0.2312, grad_fn=<NllLossBackward>)
# train tensor(0.2754, grad_fn=<NllLossBackward>)
# train tensor(0.6782, grad_fn=<NllLossBackward>)
# train tensor(0.4235, grad_fn=<NllLossBackward>)
# train tensor(0.3414, grad_fn=<NllLossBackward>)
# train tensor(0.3339, grad_fn=<NllLossBackward>)
# train tensor(0.4336, grad_fn=<NllLossBackward>)
# train tensor(0.2043, grad_fn=<NllLossBackward>)
# train tensor(0.3840, grad_fn=<NllLossBackward>)
# train tensor(0.2947, grad_fn=<NllLossBackward>)
# train tensor(0.4071, grad_fn=<NllLossBackward>)
# train tensor(0.3244, grad_fn=<NllLossBackward>)
# train tensor(0.2421, grad_fn=<NllLossBackward>)
# train tensor(0.3083, grad_fn=<NllLossBackward>)
# train tensor(0.1850, grad_fn=<NllLossBackward>)
# train tensor(0.4841, grad_fn=<NllLossBackward>)
# train tensor(0.2428, grad_fn=<NllLossBackward>)
# train tensor(0.2597, grad_fn=<NllLossBackward>)
# train tensor(0.2951, grad_fn=<NllLossBackward>)
# train tensor(0.2090, grad_fn=<NllLossBackward>)
# train tensor(0.1784, grad_fn=<NllLossBackward>)
# train tensor(0.2318, grad_fn=<NllLossBackward>)
# train tensor(0.3028, grad_fn=<NllLossBackward>)
# train tensor(0.2310, grad_fn=<NllLossBackward>)
# train tensor(0.3085, grad_fn=<NllLossBackward>)
# train tensor(0.4138, grad_fn=<NllLossBackward>)
# train tensor(0.2792, grad_fn=<NllLossBackward>)
# train tensor(0.5830, grad_fn=<NllLossBackward>)
# train tensor(0.2760, grad_fn=<NllLossBackward>)
# train tensor(0.3300, grad_fn=<NllLossBackward>)
# train tensor(0.5034, grad_fn=<NllLossBackward>)
# train tensor(0.4171, grad_fn=<NllLossBackward>)
# train tensor(0.3638, grad_fn=<NllLossBackward>)
# train tensor(0.2462, grad_fn=<NllLossBackward>)
# train tensor(0.3388, grad_fn=<NllLossBackward>)
# train tensor(0.2449, grad_fn=<NllLossBackward>)
# train tensor(0.2480, grad_fn=<NllLossBackward>)
# train tensor(0.1937, grad_fn=<NllLossBackward>)
# train tensor(0.1363, grad_fn=<NllLossBackward>)
# train tensor(0.3241, grad_fn=<NllLossBackward>)
# train tensor(0.4140, grad_fn=<NllLossBackward>)
# train tensor(0.1936, grad_fn=<NllLossBackward>)
# train tensor(0.2856, grad_fn=<NllLossBackward>)
# train tensor(0.3589, grad_fn=<NllLossBackward>)
# train tensor(0.2802, grad_fn=<NllLossBackward>)
# train tensor(0.3389, grad_fn=<NllLossBackward>)
# train tensor(0.2270, grad_fn=<NllLossBackward>)
# train tensor(0.1560, grad_fn=<NllLossBackward>)
# train tensor(0.3996, grad_fn=<NllLossBackward>)
# train tensor(0.6252, grad_fn=<NllLossBackward>)
# train tensor(0.3342, grad_fn=<NllLossBackward>)
# train tensor(0.2845, grad_fn=<NllLossBackward>)
# train tensor(0.1771, grad_fn=<NllLossBackward>)
# train tensor(0.5166, grad_fn=<NllLossBackward>)
# train tensor(0.3213, grad_fn=<NllLossBackward>)
# train tensor(0.2443, grad_fn=<NllLossBackward>)
# train tensor(0.3871, grad_fn=<NllLossBackward>)
# train tensor(0.2392, grad_fn=<NllLossBackward>)
# train tensor(0.3613, grad_fn=<NllLossBackward>)
# train tensor(0.4978, grad_fn=<NllLossBackward>)
# train tensor(0.3442, grad_fn=<NllLossBackward>)
# train tensor(0.3585, grad_fn=<NllLossBackward>)
# train tensor(0.4214, grad_fn=<NllLossBackward>)
# train tensor(0.3050, grad_fn=<NllLossBackward>)
# train tensor(0.3158, grad_fn=<NllLossBackward>)
# train tensor(0.2377, grad_fn=<NllLossBackward>)
# train tensor(0.2558, grad_fn=<NllLossBackward>)
# train tensor(0.2506, grad_fn=<NllLossBackward>)
# train tensor(0.3393, grad_fn=<NllLossBackward>)
# train tensor(0.1889, grad_fn=<NllLossBackward>)
# train tensor(0.4377, grad_fn=<NllLossBackward>)
# train tensor(0.1289, grad_fn=<NllLossBackward>)
# train tensor(0.3222, grad_fn=<NllLossBackward>)
# train tensor(0.2909, grad_fn=<NllLossBackward>)
# train tensor(0.3701, grad_fn=<NllLossBackward>)
# train tensor(0.1029, grad_fn=<NllLossBackward>)
# train tensor(0.3226, grad_fn=<NllLossBackward>)
# train tensor(0.3421, grad_fn=<NllLossBackward>)
# train tensor(0.2300, grad_fn=<NllLossBackward>)
# train tensor(0.4806, grad_fn=<NllLossBackward>)
# train tensor(0.3172, grad_fn=<NllLossBackward>)
# train tensor(0.2220, grad_fn=<NllLossBackward>)
# train tensor(0.2468, grad_fn=<NllLossBackward>)
# train tensor(0.3522, grad_fn=<NllLossBackward>)
# train tensor(0.4015, grad_fn=<NllLossBackward>)
# train tensor(0.2444, grad_fn=<NllLossBackward>)
# train tensor(0.5170, grad_fn=<NllLossBackward>)
# train tensor(0.4838, grad_fn=<NllLossBackward>)
# train tensor(0.2810, grad_fn=<NllLossBackward>)
# train tensor(0.2386, grad_fn=<NllLossBackward>)
# train tensor(0.3050, grad_fn=<NllLossBackward>)
# train tensor(0.1707, grad_fn=<NllLossBackward>)
# train tensor(0.1565, grad_fn=<NllLossBackward>)
# train tensor(0.4329, grad_fn=<NllLossBackward>)
# train tensor(0.4022, grad_fn=<NllLossBackward>)
# train tensor(0.2098, grad_fn=<NllLossBackward>)
# train tensor(0.3232, grad_fn=<NllLossBackward>)
# train tensor(0.3320, grad_fn=<NllLossBackward>)
# train tensor(0.3299, grad_fn=<NllLossBackward>)
# train tensor(0.3927, grad_fn=<NllLossBackward>)
# train tensor(0.5765, grad_fn=<NllLossBackward>)
# train tensor(0.3328, grad_fn=<NllLossBackward>)
# train tensor(0.1548, grad_fn=<NllLossBackward>)
# train tensor(0.0970, grad_fn=<NllLossBackward>)
# train tensor(0.2546, grad_fn=<NllLossBackward>)
# train tensor(0.4724, grad_fn=<NllLossBackward>)
# train tensor(0.3001, grad_fn=<NllLossBackward>)
# train tensor(0.2948, grad_fn=<NllLossBackward>)
# train tensor(0.3776, grad_fn=<NllLossBackward>)
# train tensor(0.2769, grad_fn=<NllLossBackward>)
# train tensor(0.2982, grad_fn=<NllLossBackward>)
# train tensor(0.2845, grad_fn=<NllLossBackward>)
# train tensor(0.1862, grad_fn=<NllLossBackward>)
# train tensor(0.1711, grad_fn=<NllLossBackward>)
# train tensor(0.2231, grad_fn=<NllLossBackward>)
# train tensor(0.2292, grad_fn=<NllLossBackward>)
# train tensor(0.2820, grad_fn=<NllLossBackward>)
# train tensor(0.3286, grad_fn=<NllLossBackward>)
# train tensor(0.2750, grad_fn=<NllLossBackward>)
# train tensor(0.5642, grad_fn=<NllLossBackward>)
# train tensor(0.2721, grad_fn=<NllLossBackward>)
# train tensor(0.5115, grad_fn=<NllLossBackward>)
# train tensor(0.2521, grad_fn=<NllLossBackward>)
# train tensor(0.2994, grad_fn=<NllLossBackward>)
# train tensor(0.2305, grad_fn=<NllLossBackward>)
# train tensor(0.2528, grad_fn=<NllLossBackward>)
# train tensor(0.2849, grad_fn=<NllLossBackward>)
# train tensor(0.3574, grad_fn=<NllLossBackward>)
# train tensor(0.1654, grad_fn=<NllLossBackward>)
# train tensor(0.1599, grad_fn=<NllLossBackward>)
# train tensor(0.3852, grad_fn=<NllLossBackward>)
# train tensor(0.2135, grad_fn=<NllLossBackward>)
# train tensor(0.3323, grad_fn=<NllLossBackward>)
# train tensor(0.4066, grad_fn=<NllLossBackward>)
# train tensor(0.3438, grad_fn=<NllLossBackward>)
# train tensor(0.2925, grad_fn=<NllLossBackward>)
# train tensor(0.4657, grad_fn=<NllLossBackward>)
# train tensor(0.2299, grad_fn=<NllLossBackward>)
# train tensor(0.2822, grad_fn=<NllLossBackward>)
# train tensor(0.2705, grad_fn=<NllLossBackward>)
# train tensor(0.1236, grad_fn=<NllLossBackward>)
# train tensor(0.2804, grad_fn=<NllLossBackward>)
# ...
# train tensor(0.2539, grad_fn=<NllLossBackward>)
# train tensor(0.3808, grad_fn=<NllLossBackward>)
# train tensor(0.2239, grad_fn=<NllLossBackward>)
# train tensor(0.2912, grad_fn=<NllLossBackward>)
# train tensor(0.2261, grad_fn=<NllLossBackward>)
# train tensor(0.2576, grad_fn=<NllLossBackward>)
# train tensor(0.1638, grad_fn=<NllLossBackward>)
# train tensor(0.3066, grad_fn=<NllLossBackward>)
# train tensor(0.3261, grad_fn=<NllLossBackward>)
# train tensor(0.1934, grad_fn=<NllLossBackward>)
# train tensor(0.1201, grad_fn=<NllLossBackward>)
# train tensor(0.3083, grad_fn=<NllLossBackward>)
# train tensor(0.3093, grad_fn=<NllLossBackward>)
# train tensor(0.2833, grad_fn=<NllLossBackward>)
# train tensor(0.2696, grad_fn=<NllLossBackward>)
# train tensor(0.3007, grad_fn=<NllLossBackward>)
# train tensor(0.2623, grad_fn=<NllLossBackward>)
# train tensor(0.2426, grad_fn=<NllLossBackward>)
# train tensor(0.2814, grad_fn=<NllLossBackward>)
# train tensor(0.4184, grad_fn=<NllLossBackward>)
# train tensor(0.5074, grad_fn=<NllLossBackward>)
# train tensor(0.3237, grad_fn=<NllLossBackward>)
# train tensor(0.3947, grad_fn=<NllLossBackward>)
# train tensor(0.1196, grad_fn=<NllLossBackward>)
# train tensor(0.3809, grad_fn=<NllLossBackward>)
# train tensor(0.3047, grad_fn=<NllLossBackward>)
# train tensor(0.3930, grad_fn=<NllLossBackward>)
# train tensor(0.5126, grad_fn=<NllLossBackward>)
# train tensor(0.4944, grad_fn=<NllLossBackward>)
# train tensor(0.2152, grad_fn=<NllLossBackward>)
# train tensor(0.2630, grad_fn=<NllLossBackward>)
# train tensor(0.2540, grad_fn=<NllLossBackward>)
# train tensor(0.3256, grad_fn=<NllLossBackward>)
# train tensor(0.2832, grad_fn=<NllLossBackward>)
# train tensor(0.2311, grad_fn=<NllLossBackward>)
# train tensor(0.4257, grad_fn=<NllLossBackward>)
# train tensor(0.1476, grad_fn=<NllLossBackward>)
# train tensor(0.3560, grad_fn=<NllLossBackward>)
# train tensor(0.4893, grad_fn=<NllLossBackward>)
# train tensor(0.2653, grad_fn=<NllLossBackward>)
# train tensor(0.2068, grad_fn=<NllLossBackward>)
# train tensor(0.2363, grad_fn=<NllLossBackward>)
# train tensor(0.2358, grad_fn=<NllLossBackward>)
# train tensor(0.2417, grad_fn=<NllLossBackward>)
# train tensor(0.1661, grad_fn=<NllLossBackward>)
# train tensor(0.3013, grad_fn=<NllLossBackward>)
# train tensor(0.1833, grad_fn=<NllLossBackward>)
# train tensor(0.3765, grad_fn=<NllLossBackward>)
# train tensor(0.2856, grad_fn=<NllLossBackward>)
# train tensor(0.3029, grad_fn=<NllLossBackward>)
# train tensor(0.3740, grad_fn=<NllLossBackward>)
# train tensor(0.2708, grad_fn=<NllLossBackward>)
# train tensor(0.4326, grad_fn=<NllLossBackward>)
# train tensor(0.3891, grad_fn=<NllLossBackward>)
# train tensor(0.4740, grad_fn=<NllLossBackward>)
# train tensor(0.2117, grad_fn=<NllLossBackward>)
# train tensor(0.2671, grad_fn=<NllLossBackward>)
# train tensor(0.2171, grad_fn=<NllLossBackward>)
# train tensor(0.2461, grad_fn=<NllLossBackward>)
# train tensor(0.2613, grad_fn=<NllLossBackward>)
# train tensor(0.1840, grad_fn=<NllLossBackward>)
# train tensor(0.3502, grad_fn=<NllLossBackward>)
# train tensor(0.3765, grad_fn=<NllLossBackward>)
# train tensor(0.4636, grad_fn=<NllLossBackward>)
# train tensor(0.3276, grad_fn=<NllLossBackward>)
# train tensor(0.3205, grad_fn=<NllLossBackward>)
# train tensor(0.3460, grad_fn=<NllLossBackward>)
# train tensor(0.3889, grad_fn=<NllLossBackward>)
# train tensor(0.2370, grad_fn=<NllLossBackward>)
# train tensor(0.1710, grad_fn=<NllLossBackward>)
# train tensor(0.1493, grad_fn=<NllLossBackward>)
# train tensor(0.3306, grad_fn=<NllLossBackward>)
# train tensor(0.3590, grad_fn=<NllLossBackward>)
# train tensor(0.3637, grad_fn=<NllLossBackward>)
# train tensor(0.1896, grad_fn=<NllLossBackward>)
# train tensor(0.1059, grad_fn=<NllLossBackward>)
# train tensor(0.2379, grad_fn=<NllLossBackward>)
# train tensor(0.2514, grad_fn=<NllLossBackward>)
# train tensor(0.2895, grad_fn=<NllLossBackward>)
# train tensor(0.2830, grad_fn=<NllLossBackward>)
# train tensor(0.5408, grad_fn=<NllLossBackward>)
# train tensor(0.1773, grad_fn=<NllLossBackward>)
# train tensor(0.1986, grad_fn=<NllLossBackward>)
# train tensor(0.4168, grad_fn=<NllLossBackward>)
# train tensor(0.3001, grad_fn=<NllLossBackward>)
# train tensor(0.2852, grad_fn=<NllLossBackward>)
# train tensor(0.1898, grad_fn=<NllLossBackward>)
# train tensor(0.4118, grad_fn=<NllLossBackward>)
# train tensor(0.1899, grad_fn=<NllLossBackward>)
# train tensor(0.1357, grad_fn=<NllLossBackward>)
# train tensor(0.3518, grad_fn=<NllLossBackward>)
# train tensor(0.3093, grad_fn=<NllLossBackward>)
# train tensor(0.3373, grad_fn=<NllLossBackward>)
# train tensor(0.2417, grad_fn=<NllLossBackward>)
# train tensor(0.2088, grad_fn=<NllLossBackward>)
# train tensor(0.2245, grad_fn=<NllLossBackward>)
# train tensor(0.1794, grad_fn=<NllLossBackward>)
# train tensor(0.1534, grad_fn=<NllLossBackward>)
# train tensor(0.3706, grad_fn=<NllLossBackward>)
# train tensor(0.3382, grad_fn=<NllLossBackward>)
# train tensor(0.3141, grad_fn=<NllLossBackward>)
# train tensor(0.2403, grad_fn=<NllLossBackward>)
# train tensor(0.3351, grad_fn=<NllLossBackward>)
# train tensor(0.3844, grad_fn=<NllLossBackward>)
# train tensor(0.2727, grad_fn=<NllLossBackward>)
# train tensor(0.3613, grad_fn=<NllLossBackward>)
# train tensor(0.5177, grad_fn=<NllLossBackward>)
# train tensor(0.1924, grad_fn=<NllLossBackward>)
# train tensor(0.2971, grad_fn=<NllLossBackward>)
# train tensor(0.2580, grad_fn=<NllLossBackward>)
# train tensor(0.4414, grad_fn=<NllLossBackward>)
# train tensor(0.3917, grad_fn=<NllLossBackward>)
# train tensor(0.4349, grad_fn=<NllLossBackward>)
# train tensor(0.1993, grad_fn=<NllLossBackward>)
# train tensor(0.3254, grad_fn=<NllLossBackward>)
# train tensor(0.6095, grad_fn=<NllLossBackward>)
# train tensor(0.3106, grad_fn=<NllLossBackward>)
# train tensor(0.1261, grad_fn=<NllLossBackward>)
# train tensor(0.1480, grad_fn=<NllLossBackward>)
# train tensor(0.2381, grad_fn=<NllLossBackward>)
# train tensor(0.2394, grad_fn=<NllLossBackward>)
# train tensor(0.2148, grad_fn=<NllLossBackward>)
# train tensor(0.2820, grad_fn=<NllLossBackward>)
# train tensor(0.2051, grad_fn=<NllLossBackward>)
# train tensor(0.1867, grad_fn=<NllLossBackward>)
# train tensor(0.1193, grad_fn=<NllLossBackward>)
# train tensor(0.2848, grad_fn=<NllLossBackward>)
# train tensor(0.2392, grad_fn=<NllLossBackward>)
# train tensor(0.4128, grad_fn=<NllLossBackward>)
# train tensor(0.3704, grad_fn=<NllLossBackward>)
# train tensor(0.2569, grad_fn=<NllLossBackward>)
# train tensor(0.1303, grad_fn=<NllLossBackward>)
# train tensor(0.3578, grad_fn=<NllLossBackward>)
# train tensor(0.1446, grad_fn=<NllLossBackward>)
# train tensor(0.5022, grad_fn=<NllLossBackward>)
# train tensor(0.2454, grad_fn=<NllLossBackward>)
# train tensor(0.4519, grad_fn=<NllLossBackward>)
# train tensor(0.6200, grad_fn=<NllLossBackward>)
# train tensor(0.2312, grad_fn=<NllLossBackward>)
# train tensor(0.2565, grad_fn=<NllLossBackward>)
# train tensor(0.1854, grad_fn=<NllLossBackward>)
# train tensor(0.1933, grad_fn=<NllLossBackward>)
# train tensor(0.2926, grad_fn=<NllLossBackward>)
# train tensor(0.3829, grad_fn=<NllLossBackward>)
# train tensor(0.3016, grad_fn=<NllLossBackward>)
# train tensor(0.2794, grad_fn=<NllLossBackward>)
# train tensor(0.2890, grad_fn=<NllLossBackward>)
# train tensor(0.4737, grad_fn=<NllLossBackward>)
# train tensor(0.3930, grad_fn=<NllLossBackward>)
# train tensor(0.2891, grad_fn=<NllLossBackward>)
# train tensor(0.3577, grad_fn=<NllLossBackward>)
# train tensor(0.2426, grad_fn=<NllLossBackward>)
# train tensor(0.1976, grad_fn=<NllLossBackward>)
# train tensor(0.3270, grad_fn=<NllLossBackward>)
# train tensor(0.2562, grad_fn=<NllLossBackward>)
# train tensor(0.1776, grad_fn=<NllLossBackward>)
# train tensor(0.4129, grad_fn=<NllLossBackward>)
# train tensor(0.3498, grad_fn=<NllLossBackward>)
# train tensor(0.3892, grad_fn=<NllLossBackward>)
# train tensor(0.3130, grad_fn=<NllLossBackward>)
# train tensor(0.2328, grad_fn=<NllLossBackward>)
# train tensor(0.1692, grad_fn=<NllLossBackward>)
# train tensor(0.2695, grad_fn=<NllLossBackward>)
# train tensor(0.2453, grad_fn=<NllLossBackward>)
# train tensor(0.3889, grad_fn=<NllLossBackward>)
# train tensor(0.1685, grad_fn=<NllLossBackward>)
# train tensor(0.4998, grad_fn=<NllLossBackward>)
# train tensor(0.1809, grad_fn=<NllLossBackward>)
# train tensor(0.2699, grad_fn=<NllLossBackward>)
# train tensor(0.2592, grad_fn=<NllLossBackward>)
# train tensor(0.4128, grad_fn=<NllLossBackward>)
# train tensor(0.2701, grad_fn=<NllLossBackward>)
# train tensor(0.2363, grad_fn=<NllLossBackward>)
# train tensor(0.2929, grad_fn=<NllLossBackward>)
# train tensor(0.2993, grad_fn=<NllLossBackward>)
# train tensor(0.4760, grad_fn=<NllLossBackward>)
# train tensor(0.1996, grad_fn=<NllLossBackward>)
# train tensor(0.4184, grad_fn=<NllLossBackward>)
# train tensor(0.2384, grad_fn=<NllLossBackward>)
# train tensor(0.3368, grad_fn=<NllLossBackward>)
# train tensor(0.4426, grad_fn=<NllLossBackward>)
# train tensor(0.1977, grad_fn=<NllLossBackward>)
# train tensor(0.3302, grad_fn=<NllLossBackward>)
# train tensor(0.3429, grad_fn=<NllLossBackward>)
# train tensor(0.2202, grad_fn=<NllLossBackward>)
# train tensor(0.2163, grad_fn=<NllLossBackward>)
# train tensor(0.0692, grad_fn=<NllLossBackward>)
# train tensor(0.1609, grad_fn=<NllLossBackward>)
# train tensor(0.2597, grad_fn=<NllLossBackward>)
# train tensor(0.1821, grad_fn=<NllLossBackward>)
# train tensor(0.1822, grad_fn=<NllLossBackward>)
# train tensor(0.5928, grad_fn=<NllLossBackward>)
# train tensor(0.4257, grad_fn=<NllLossBackward>)
# train tensor(0.2394, grad_fn=<NllLossBackward>)
# train tensor(0.2841, grad_fn=<NllLossBackward>)
# train tensor(0.2874, grad_fn=<NllLossBackward>)
# train tensor(0.4894, grad_fn=<NllLossBackward>)
# train tensor(0.5665, grad_fn=<NllLossBackward>)
# train tensor(0.1521, grad_fn=<NllLossBackward>)
# train tensor(0.2918, grad_fn=<NllLossBackward>)
# train tensor(0.4289, grad_fn=<NllLossBackward>)
# train tensor(0.2579, grad_fn=<NllLossBackward>)
# train tensor(0.2482, grad_fn=<NllLossBackward>)
# train tensor(0.2515, grad_fn=<NllLossBackward>)
# train tensor(0.2424, grad_fn=<NllLossBackward>)
# train tensor(0.2195, grad_fn=<NllLossBackward>)
# train tensor(0.4134, grad_fn=<NllLossBackward>)
# train tensor(0.3690, grad_fn=<NllLossBackward>)
# train tensor(0.2611, grad_fn=<NllLossBackward>)
# train tensor(0.4740, grad_fn=<NllLossBackward>)
# train tensor(0.3863, grad_fn=<NllLossBackward>)
# train tensor(0.3781, grad_fn=<NllLossBackward>)
# train tensor(0.4232, grad_fn=<NllLossBackward>)
# train tensor(0.3638, grad_fn=<NllLossBackward>)
# train tensor(0.2596, grad_fn=<NllLossBackward>)
# train tensor(0.3175, grad_fn=<NllLossBackward>)
# train tensor(0.4689, grad_fn=<NllLossBackward>)
# train tensor(0.3907, grad_fn=<NllLossBackward>)
# train tensor(0.2831, grad_fn=<NllLossBackward>)
# train tensor(0.3160, grad_fn=<NllLossBackward>)
# train tensor(0.3958, grad_fn=<NllLossBackward>)
# train tensor(0.5367, grad_fn=<NllLossBackward>)
# train tensor(0.2968, grad_fn=<NllLossBackward>)
# train tensor(0.4867, grad_fn=<NllLossBackward>)
# train tensor(0.1848, grad_fn=<NllLossBackward>)
# train tensor(0.2094, grad_fn=<NllLossBackward>)
# train tensor(0.2239, grad_fn=<NllLossBackward>)
# train tensor(0.1962, grad_fn=<NllLossBackward>)
# train tensor(0.2960, grad_fn=<NllLossBackward>)
# train tensor(0.1803, grad_fn=<NllLossBackward>)
# train tensor(0.2140, grad_fn=<NllLossBackward>)
# train tensor(0.5885, grad_fn=<NllLossBackward>)
# train tensor(0.2421, grad_fn=<NllLossBackward>)
# train tensor(0.2022, grad_fn=<NllLossBackward>)
# train tensor(0.5479, grad_fn=<NllLossBackward>)
# train tensor(0.2728, grad_fn=<NllLossBackward>)
# train tensor(0.3504, grad_fn=<NllLossBackward>)
# train tensor(0.4501, grad_fn=<NllLossBackward>)
# train tensor(0.1934, grad_fn=<NllLossBackward>)
# train tensor(0.1678, grad_fn=<NllLossBackward>)
# train tensor(0.3339, grad_fn=<NllLossBackward>)
# train tensor(0.1431, grad_fn=<NllLossBackward>)
# train tensor(0.2618, grad_fn=<NllLossBackward>)
# train tensor(0.2274, grad_fn=<NllLossBackward>)
# train tensor(0.5305, grad_fn=<NllLossBackward>)
# train tensor(0.2573, grad_fn=<NllLossBackward>)
# train tensor(0.3838, grad_fn=<NllLossBackward>)
# train tensor(0.3365, grad_fn=<NllLossBackward>)
# train tensor(0.2280, grad_fn=<NllLossBackward>)
# train tensor(0.3605, grad_fn=<NllLossBackward>)
# train tensor(0.3427, grad_fn=<NllLossBackward>)
# train tensor(0.3315, grad_fn=<NllLossBackward>)
# train tensor(0.3972, grad_fn=<NllLossBackward>)
# train tensor(0.2353, grad_fn=<NllLossBackward>)
# train tensor(0.1395, grad_fn=<NllLossBackward>)
# train tensor(0.2293, grad_fn=<NllLossBackward>)
# train tensor(0.2419, grad_fn=<NllLossBackward>)
# train tensor(0.1546, grad_fn=<NllLossBackward>)
# train tensor(0.4012, grad_fn=<NllLossBackward>)
# train tensor(0.4244, grad_fn=<NllLossBackward>)
# train tensor(0.2315, grad_fn=<NllLossBackward>)
# train tensor(0.3275, grad_fn=<NllLossBackward>)
# train tensor(0.3024, grad_fn=<NllLossBackward>)
# train tensor(0.2445, grad_fn=<NllLossBackward>)
# train tensor(0.3837, grad_fn=<NllLossBackward>)
# train tensor(0.3959, grad_fn=<NllLossBackward>)
# train tensor(0.3461, grad_fn=<NllLossBackward>)
# tensor(0.3434, grad_fn=<AddBackward0>)
# tensor(0.8430, grad_fn=<AddBackward0>)
# tensor(1.2573, grad_fn=<AddBackward0>)
# tensor(1.7149, grad_fn=<AddBackward0>)
# tensor(2.2339, grad_fn=<AddBackward0>)
# tensor(2.5423, grad_fn=<AddBackward0>)
# tensor(2.7653, grad_fn=<AddBackward0>)
# tensor(2.9476, grad_fn=<AddBackward0>)
# tensor(3.1038, grad_fn=<AddBackward0>)
# tensor(3.4779, grad_fn=<AddBackward0>)
# tensor(3.7056, grad_fn=<AddBackward0>)
# tensor(3.9348, grad_fn=<AddBackward0>)
# tensor(4.1656, grad_fn=<AddBackward0>)
# tensor(4.5023, grad_fn=<AddBackward0>)
# tensor(4.6684, grad_fn=<AddBackward0>)
# tensor(5.0456, grad_fn=<AddBackward0>)
# tensor(5.5982, grad_fn=<AddBackward0>)
# tensor(5.9559, grad_fn=<AddBackward0>)
# tensor(6.3459, grad_fn=<AddBackward0>)
# tensor(6.5045, grad_fn=<AddBackward0>)
# tensor(6.8068, grad_fn=<AddBackward0>)
# tensor(7.2477, grad_fn=<AddBackward0>)
# tensor(7.8796, grad_fn=<AddBackward0>)
# tensor(8.4306, grad_fn=<AddBackward0>)
# tensor(8.6805, grad_fn=<AddBackward0>)
# tensor(8.9575, grad_fn=<AddBackward0>)
# tensor(9.0518, grad_fn=<AddBackward0>)
# tensor(9.4650, grad_fn=<AddBackward0>)
# tensor(9.7783, grad_fn=<AddBackward0>)
# tensor(10.0108, grad_fn=<AddBackward0>)
# tensor(10.3450, grad_fn=<AddBackward0>)
# tensor(10.8002, grad_fn=<AddBackward0>)
# tensor(11.0620, grad_fn=<AddBackward0>)
# tensor(11.2427, grad_fn=<AddBackward0>)
# tensor(11.5528, grad_fn=<AddBackward0>)
# tensor(12.0039, grad_fn=<AddBackward0>)
# tensor(12.1567, grad_fn=<AddBackward0>)
# tensor(12.4107, grad_fn=<AddBackward0>)
# tensor(12.8623, grad_fn=<AddBackward0>)
# tensor(13.1131, grad_fn=<AddBackward0>)
# tensor(13.3738, grad_fn=<AddBackward0>)
# tensor(13.6796, grad_fn=<AddBackward0>)
# tensor(13.8747, grad_fn=<AddBackward0>)
# tensor(14.1432, grad_fn=<AddBackward0>)
# tensor(14.4845, grad_fn=<AddBackward0>)
# tensor(14.7508, grad_fn=<AddBackward0>)
# tensor(14.9861, grad_fn=<AddBackward0>)
# tensor(15.1405, grad_fn=<AddBackward0>)
# tensor(15.4223, grad_fn=<AddBackward0>)
# tensor(15.6970, grad_fn=<AddBackward0>)
# tensor(16.0826, grad_fn=<AddBackward0>)
# tensor(16.3727, grad_fn=<AddBackward0>)
# tensor(16.5850, grad_fn=<AddBackward0>)
# tensor(16.7982, grad_fn=<AddBackward0>)
# tensor(17.0656, grad_fn=<AddBackward0>)
# tensor(17.2806, grad_fn=<AddBackward0>)
# tensor(17.4789, grad_fn=<AddBackward0>)
# tensor(17.7309, grad_fn=<AddBackward0>)
# tensor(17.9886, grad_fn=<AddBackward0>)
# tensor(18.3799, grad_fn=<AddBackward0>)
# tensor(18.7609, grad_fn=<AddBackward0>)
# tensor(18.9887, grad_fn=<AddBackward0>)
# tensor(19.2256, grad_fn=<AddBackward0>)
# tensor(19.4405, grad_fn=<AddBackward0>)
# tensor(19.5974, grad_fn=<AddBackward0>)
# tensor(19.8192, grad_fn=<AddBackward0>)
# tensor(19.9788, grad_fn=<AddBackward0>)
# tensor(20.1967, grad_fn=<AddBackward0>)
# tensor(20.3761, grad_fn=<AddBackward0>)
# tensor(20.5406, grad_fn=<AddBackward0>)
# tensor(20.6206, grad_fn=<AddBackward0>)
# tensor(20.6927, grad_fn=<AddBackward0>)
# tensor(20.9515, grad_fn=<AddBackward0>)
# tensor(21.4455, grad_fn=<AddBackward0>)
# tensor(21.5434, grad_fn=<AddBackward0>)
# tensor(22.0009, grad_fn=<AddBackward0>)
# tensor(22.3416, grad_fn=<AddBackward0>)
# tensor(22.5898, grad_fn=<AddBackward0>)
# tensor(22.6397, grad_fn=<AddBackward0>)
# Epoch 1: 0.287

# %% [markdown]
# # CNN  对于图像
# Using simple logistic regression (or an MLP) for images basically ignores the data's underlying structure. We can do much better than this by switching to a CNN. Since our training loop does not assume anything about the model we can train a CNN without any changes.
#
# Our CNN will consist of 3 convolutional layers, each using PyTorch's predefined `Conv2d` layer. At the End, we perform average pooling. Since `Conv2d` assumes a shape of `[batch_size, num_channels, height, width]` we need to reshape our input inside the model via `.view(_)`.

# %%
class CNN(nn.Module):
    def __init__(self, num_channels, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(1, num_channels, kernel_size=3, stride=2, padding=1)  
        #第一个1表示是灰色图像，如果是RGB则应该为3
        self.conv2 = nn.Conv2d(num_channels, num_channels, kernel_size=3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(num_channels, num_classes, kernel_size=3, stride=2, padding=1)

    def forward(self, xb):
        xb = xb.view(-1, 1, 28, 28)  
        #reshape，变为图片的形状 -1对应batch-size
        xb = F.relu(self.conv1(xb))
        xb = F.relu(self.conv2(xb))
        xb = F.relu(self.conv3(xb))
        xb = F.avg_pool2d(xb, 4)          #输出前的操作
        return xb.view(-1, xb.size(1))    #[batch-size, num_classes]

# %% [markdown]
# We will now furthermore use momentum in our optimizer to speed up training.

# %%
model = CNN(num_channels=16, num_classes=10)
model.apply(initialize_weight)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)

fit(model, optimizer, dataloaders, num_epochs=2)
# Out:
# train tensor(2.3040, grad_fn=<NllLossBackward>)
# train tensor(2.3015, grad_fn=<NllLossBackward>)
# train tensor(2.2946, grad_fn=<NllLossBackward>)
# train tensor(2.2997, grad_fn=<NllLossBackward>)
# train tensor(2.2944, grad_fn=<NllLossBackward>)
# train tensor(2.3108, grad_fn=<NllLossBackward>)
# train tensor(2.2955, grad_fn=<NllLossBackward>)
# train tensor(2.3130, grad_fn=<NllLossBackward>)
# train tensor(2.2886, grad_fn=<NllLossBackward>)
# train tensor(2.3105, grad_fn=<NllLossBackward>)
# train tensor(2.2953, grad_fn=<NllLossBackward>)
# train tensor(2.3012, grad_fn=<NllLossBackward>)
# train tensor(2.2793, grad_fn=<NllLossBackward>)
# train tensor(2.3052, grad_fn=<NllLossBackward>)
# train tensor(2.2945, grad_fn=<NllLossBackward>)
# train tensor(2.3076, grad_fn=<NllLossBackward>)
# train tensor(2.3042, grad_fn=<NllLossBackward>)
# train tensor(2.2972, grad_fn=<NllLossBackward>)
# train tensor(2.2989, grad_fn=<NllLossBackward>)
# train tensor(2.3006, grad_fn=<NllLossBackward>)
# train tensor(2.2951, grad_fn=<NllLossBackward>)
# train tensor(2.3003, grad_fn=<NllLossBackward>)
# train tensor(2.3236, grad_fn=<NllLossBackward>)
# train tensor(2.2908, grad_fn=<NllLossBackward>)
# train tensor(2.2994, grad_fn=<NllLossBackward>)
# train tensor(2.3036, grad_fn=<NllLossBackward>)
# train tensor(2.2978, grad_fn=<NllLossBackward>)
# train tensor(2.2912, grad_fn=<NllLossBackward>)
# train tensor(2.3031, grad_fn=<NllLossBackward>)
# train tensor(2.2976, grad_fn=<NllLossBackward>)
# train tensor(2.2814, grad_fn=<NllLossBackward>)
# train tensor(2.3026, grad_fn=<NllLossBackward>)
# train tensor(2.2845, grad_fn=<NllLossBackward>)
# train tensor(2.3011, grad_fn=<NllLossBackward>)
# train tensor(2.3091, grad_fn=<NllLossBackward>)
# train tensor(2.2990, grad_fn=<NllLossBackward>)
# train tensor(2.2748, grad_fn=<NllLossBackward>)
# train tensor(2.2906, grad_fn=<NllLossBackward>)
# train tensor(2.3037, grad_fn=<NllLossBackward>)
# train tensor(2.2814, grad_fn=<NllLossBackward>)
# train tensor(2.2819, grad_fn=<NllLossBackward>)
# train tensor(2.2851, grad_fn=<NllLossBackward>)
# train tensor(2.2972, grad_fn=<NllLossBackward>)
# train tensor(2.3026, grad_fn=<NllLossBackward>)
# train tensor(2.3073, grad_fn=<NllLossBackward>)
# train tensor(2.2784, grad_fn=<NllLossBackward>)
# train tensor(2.2820, grad_fn=<NllLossBackward>)
# train tensor(2.2779, grad_fn=<NllLossBackward>)
# train tensor(2.2861, grad_fn=<NllLossBackward>)
# train tensor(2.2497, grad_fn=<NllLossBackward>)
# train tensor(2.2679, grad_fn=<NllLossBackward>)
# train tensor(2.3154, grad_fn=<NllLossBackward>)
# train tensor(2.2867, grad_fn=<NllLossBackward>)
# train tensor(2.2830, grad_fn=<NllLossBackward>)
# train tensor(2.2641, grad_fn=<NllLossBackward>)
# train tensor(2.2541, grad_fn=<NllLossBackward>)
# train tensor(2.3292, grad_fn=<NllLossBackward>)
# train tensor(2.2884, grad_fn=<NllLossBackward>)
# train tensor(2.2865, grad_fn=<NllLossBackward>)
# train tensor(2.2488, grad_fn=<NllLossBackward>)
# train tensor(2.2670, grad_fn=<NllLossBackward>)
# train tensor(2.2906, grad_fn=<NllLossBackward>)
# train tensor(2.3163, grad_fn=<NllLossBackward>)
# train tensor(2.2495, grad_fn=<NllLossBackward>)
# train tensor(2.2732, grad_fn=<NllLossBackward>)
# train tensor(2.2259, grad_fn=<NllLossBackward>)
# train tensor(2.2609, grad_fn=<NllLossBackward>)
# train tensor(2.2543, grad_fn=<NllLossBackward>)
# train tensor(2.2965, grad_fn=<NllLossBackward>)
# train tensor(2.2789, grad_fn=<NllLossBackward>)
# train tensor(2.2621, grad_fn=<NllLossBackward>)
# train tensor(2.1995, grad_fn=<NllLossBackward>)
# train tensor(2.2144, grad_fn=<NllLossBackward>)
# train tensor(2.2659, grad_fn=<NllLossBackward>)
# train tensor(2.2320, grad_fn=<NllLossBackward>)
# train tensor(2.2652, grad_fn=<NllLossBackward>)
# train tensor(2.1382, grad_fn=<NllLossBackward>)
# train tensor(2.2270, grad_fn=<NllLossBackward>)
# train tensor(2.2792, grad_fn=<NllLossBackward>)
# train tensor(2.2046, grad_fn=<NllLossBackward>)
# train tensor(2.1887, grad_fn=<NllLossBackward>)
# train tensor(2.1069, grad_fn=<NllLossBackward>)
# train tensor(2.2003, grad_fn=<NllLossBackward>)
# train tensor(2.1632, grad_fn=<NllLossBackward>)
# train tensor(2.1065, grad_fn=<NllLossBackward>)
# train tensor(2.1787, grad_fn=<NllLossBackward>)
# train tensor(2.0973, grad_fn=<NllLossBackward>)
# train tensor(2.0967, grad_fn=<NllLossBackward>)
# train tensor(2.1472, grad_fn=<NllLossBackward>)
# train tensor(2.1745, grad_fn=<NllLossBackward>)
# train tensor(2.2124, grad_fn=<NllLossBackward>)
# train tensor(2.1310, grad_fn=<NllLossBackward>)
# train tensor(2.0664, grad_fn=<NllLossBackward>)
# train tensor(1.9675, grad_fn=<NllLossBackward>)
# train tensor(2.1726, grad_fn=<NllLossBackward>)
# train tensor(2.1262, grad_fn=<NllLossBackward>)
# train tensor(2.1286, grad_fn=<NllLossBackward>)
# train tensor(2.1504, grad_fn=<NllLossBackward>)
# train tensor(2.2440, grad_fn=<NllLossBackward>)
# train tensor(2.1651, grad_fn=<NllLossBackward>)
# train tensor(2.0792, grad_fn=<NllLossBackward>)
# train tensor(2.0690, grad_fn=<NllLossBackward>)
# train tensor(2.0346, grad_fn=<NllLossBackward>)
# train tensor(2.0583, grad_fn=<NllLossBackward>)
# train tensor(2.0767, grad_fn=<NllLossBackward>)
# train tensor(2.0065, grad_fn=<NllLossBackward>)
# train tensor(2.0598, grad_fn=<NllLossBackward>)
# train tensor(1.9965, grad_fn=<NllLossBackward>)
# train tensor(1.9791, grad_fn=<NllLossBackward>)
# train tensor(1.9089, grad_fn=<NllLossBackward>)
# train tensor(1.8490, grad_fn=<NllLossBackward>)
# train tensor(1.7332, grad_fn=<NllLossBackward>)
# train tensor(1.9849, grad_fn=<NllLossBackward>)
# train tensor(1.8926, grad_fn=<NllLossBackward>)
# train tensor(1.6666, grad_fn=<NllLossBackward>)
# train tensor(1.8301, grad_fn=<NllLossBackward>)
# train tensor(1.8141, grad_fn=<NllLossBackward>)
# train tensor(1.9818, grad_fn=<NllLossBackward>)
# train tensor(1.8488, grad_fn=<NllLossBackward>)
# train tensor(1.8468, grad_fn=<NllLossBackward>)
# train tensor(1.6216, grad_fn=<NllLossBackward>)
# train tensor(1.5657, grad_fn=<NllLossBackward>)
# train tensor(1.9214, grad_fn=<NllLossBackward>)
# train tensor(1.6732, grad_fn=<NllLossBackward>)
# train tensor(1.8178, grad_fn=<NllLossBackward>)
# train tensor(1.6756, grad_fn=<NllLossBackward>)
# train tensor(1.4614, grad_fn=<NllLossBackward>)
# train tensor(1.7011, grad_fn=<NllLossBackward>)
# train tensor(1.6158, grad_fn=<NllLossBackward>)
# train tensor(1.6073, grad_fn=<NllLossBackward>)
# train tensor(1.5868, grad_fn=<NllLossBackward>)
# train tensor(1.5756, grad_fn=<NllLossBackward>)
# train tensor(1.4768, grad_fn=<NllLossBackward>)
# train tensor(1.3522, grad_fn=<NllLossBackward>)
# train tensor(1.5715, grad_fn=<NllLossBackward>)
# train tensor(1.6508, grad_fn=<NllLossBackward>)
# train tensor(1.2854, grad_fn=<NllLossBackward>)
# train tensor(1.4054, grad_fn=<NllLossBackward>)
# train tensor(1.4046, grad_fn=<NllLossBackward>)
# train tensor(1.7027, grad_fn=<NllLossBackward>)
# train tensor(1.6791, grad_fn=<NllLossBackward>)
# train tensor(1.1737, grad_fn=<NllLossBackward>)
# train tensor(1.4258, grad_fn=<NllLossBackward>)
# train tensor(1.2753, grad_fn=<NllLossBackward>)
# train tensor(1.6038, grad_fn=<NllLossBackward>)
# train tensor(1.0924, grad_fn=<NllLossBackward>)
# train tensor(1.6205, grad_fn=<NllLossBackward>)
# train tensor(1.3423, grad_fn=<NllLossBackward>)
# train tensor(1.2478, grad_fn=<NllLossBackward>)
# train tensor(1.3807, grad_fn=<NllLossBackward>)
# train tensor(1.5163, grad_fn=<NllLossBackward>)
# train tensor(1.5074, grad_fn=<NllLossBackward>)
# train tensor(1.5689, grad_fn=<NllLossBackward>)
# train tensor(1.2325, grad_fn=<NllLossBackward>)
# train tensor(1.4593, grad_fn=<NllLossBackward>)
# train tensor(1.8315, grad_fn=<NllLossBackward>)
# train tensor(1.4222, grad_fn=<NllLossBackward>)
# train tensor(1.2961, grad_fn=<NllLossBackward>)
# train tensor(1.5241, grad_fn=<NllLossBackward>)
# train tensor(1.4258, grad_fn=<NllLossBackward>)
# train tensor(1.4701, grad_fn=<NllLossBackward>)
# train tensor(1.5050, grad_fn=<NllLossBackward>)
# train tensor(1.4106, grad_fn=<NllLossBackward>)
# train tensor(1.9285, grad_fn=<NllLossBackward>)
# train tensor(1.7207, grad_fn=<NllLossBackward>)
# train tensor(1.3480, grad_fn=<NllLossBackward>)
# train tensor(1.4476, grad_fn=<NllLossBackward>)
# train tensor(1.5056, grad_fn=<NllLossBackward>)
# train tensor(1.4853, grad_fn=<NllLossBackward>)
# train tensor(1.7489, grad_fn=<NllLossBackward>)
# train tensor(1.2192, grad_fn=<NllLossBackward>)
# train tensor(1.4336, grad_fn=<NllLossBackward>)
# train tensor(1.2347, grad_fn=<NllLossBackward>)
# train tensor(1.3321, grad_fn=<NllLossBackward>)
# train tensor(1.3577, grad_fn=<NllLossBackward>)
# train tensor(1.3341, grad_fn=<NllLossBackward>)
# train tensor(1.4793, grad_fn=<NllLossBackward>)
# train tensor(1.3704, grad_fn=<NllLossBackward>)
# train tensor(1.0628, grad_fn=<NllLossBackward>)
# train tensor(1.1106, grad_fn=<NllLossBackward>)
# train tensor(1.2802, grad_fn=<NllLossBackward>)
# train tensor(1.3519, grad_fn=<NllLossBackward>)
# train tensor(1.4405, grad_fn=<NllLossBackward>)
# train tensor(1.1033, grad_fn=<NllLossBackward>)
# train tensor(0.9642, grad_fn=<NllLossBackward>)
# train tensor(1.3301, grad_fn=<NllLossBackward>)
# train tensor(1.3551, grad_fn=<NllLossBackward>)
# train tensor(1.0779, grad_fn=<NllLossBackward>)
# train tensor(1.3590, grad_fn=<NllLossBackward>)
# train tensor(1.2189, grad_fn=<NllLossBackward>)
# train tensor(0.8615, grad_fn=<NllLossBackward>)
# train tensor(0.9983, grad_fn=<NllLossBackward>)
# train tensor(1.0926, grad_fn=<NllLossBackward>)
# train tensor(1.0377, grad_fn=<NllLossBackward>)
# train tensor(1.0070, grad_fn=<NllLossBackward>)
# train tensor(1.0118, grad_fn=<NllLossBackward>)
# train tensor(1.1498, grad_fn=<NllLossBackward>)
# train tensor(1.2202, grad_fn=<NllLossBackward>)
# train tensor(1.0182, grad_fn=<NllLossBackward>)
# train tensor(0.8210, grad_fn=<NllLossBackward>)
# train tensor(0.9330, grad_fn=<NllLossBackward>)
# train tensor(1.1378, grad_fn=<NllLossBackward>)
# train tensor(1.0296, grad_fn=<NllLossBackward>)
# train tensor(0.8817, grad_fn=<NllLossBackward>)
# train tensor(1.1583, grad_fn=<NllLossBackward>)
# train tensor(1.0447, grad_fn=<NllLossBackward>)
# train tensor(1.1762, grad_fn=<NllLossBackward>)
# train tensor(0.9850, grad_fn=<NllLossBackward>)
# train tensor(1.1817, grad_fn=<NllLossBackward>)
# train tensor(1.0298, grad_fn=<NllLossBackward>)
# train tensor(0.7560, grad_fn=<NllLossBackward>)
# train tensor(1.2362, grad_fn=<NllLossBackward>)
# train tensor(0.9326, grad_fn=<NllLossBackward>)
# train tensor(0.9582, grad_fn=<NllLossBackward>)
# train tensor(0.9499, grad_fn=<NllLossBackward>)
# train tensor(1.1993, grad_fn=<NllLossBackward>)
# train tensor(0.9407, grad_fn=<NllLossBackward>)
# train tensor(1.0367, grad_fn=<NllLossBackward>)
# train tensor(1.0567, grad_fn=<NllLossBackward>)
# train tensor(0.8280, grad_fn=<NllLossBackward>)
# train tensor(0.8340, grad_fn=<NllLossBackward>)
# train tensor(0.8871, grad_fn=<NllLossBackward>)
# train tensor(0.8767, grad_fn=<NllLossBackward>)
# train tensor(1.0319, grad_fn=<NllLossBackward>)
# train tensor(0.9400, grad_fn=<NllLossBackward>)
# train tensor(0.7930, grad_fn=<NllLossBackward>)
# train tensor(1.1269, grad_fn=<NllLossBackward>)
# train tensor(0.9087, grad_fn=<NllLossBackward>)
# train tensor(1.0601, grad_fn=<NllLossBackward>)
# train tensor(0.9361, grad_fn=<NllLossBackward>)
# train tensor(0.9437, grad_fn=<NllLossBackward>)
# train tensor(0.9726, grad_fn=<NllLossBackward>)
# train tensor(1.1281, grad_fn=<NllLossBackward>)
# train tensor(1.2189, grad_fn=<NllLossBackward>)
# train tensor(0.9413, grad_fn=<NllLossBackward>)
# train tensor(1.0107, grad_fn=<NllLossBackward>)
# train tensor(0.8585, grad_fn=<NllLossBackward>)
# train tensor(0.9948, grad_fn=<NllLossBackward>)
# train tensor(0.9189, grad_fn=<NllLossBackward>)
# train tensor(1.0682, grad_fn=<NllLossBackward>)
# train tensor(0.7629, grad_fn=<NllLossBackward>)
# train tensor(1.0026, grad_fn=<NllLossBackward>)
# train tensor(0.7656, grad_fn=<NllLossBackward>)
# train tensor(1.0172, grad_fn=<NllLossBackward>)
# train tensor(0.7467, grad_fn=<NllLossBackward>)
# train tensor(1.0610, grad_fn=<NllLossBackward>)
# train tensor(1.1595, grad_fn=<NllLossBackward>)
# train tensor(0.6862, grad_fn=<NllLossBackward>)
# train tensor(0.5681, grad_fn=<NllLossBackward>)
# train tensor(0.9397, grad_fn=<NllLossBackward>)
# train tensor(1.0299, grad_fn=<NllLossBackward>)
# train tensor(1.0070, grad_fn=<NllLossBackward>)
# train tensor(0.8079, grad_fn=<NllLossBackward>)
# train tensor(1.0196, grad_fn=<NllLossBackward>)
# train tensor(0.9877, grad_fn=<NllLossBackward>)
# train tensor(0.6988, grad_fn=<NllLossBackward>)
# train tensor(0.7778, grad_fn=<NllLossBackward>)
# train tensor(0.7256, grad_fn=<NllLossBackward>)
# train tensor(0.8050, grad_fn=<NllLossBackward>)
# train tensor(0.8396, grad_fn=<NllLossBackward>)
# train tensor(1.1922, grad_fn=<NllLossBackward>)
# train tensor(0.8209, grad_fn=<NllLossBackward>)
# train tensor(0.8295, grad_fn=<NllLossBackward>)
# train tensor(0.7666, grad_fn=<NllLossBackward>)
# train tensor(1.1133, grad_fn=<NllLossBackward>)
# train tensor(0.9106, grad_fn=<NllLossBackward>)
# train tensor(0.9307, grad_fn=<NllLossBackward>)
# train tensor(0.9576, grad_fn=<NllLossBackward>)
# train tensor(1.0895, grad_fn=<NllLossBackward>)
# train tensor(0.8436, grad_fn=<NllLossBackward>)
# train tensor(0.7883, grad_fn=<NllLossBackward>)
# train tensor(0.8541, grad_fn=<NllLossBackward>)
# train tensor(0.7191, grad_fn=<NllLossBackward>)
# train tensor(0.8545, grad_fn=<NllLossBackward>)
# train tensor(0.5617, grad_fn=<NllLossBackward>)
# train tensor(0.6068, grad_fn=<NllLossBackward>)
# train tensor(0.8795, grad_fn=<NllLossBackward>)
# train tensor(1.2214, grad_fn=<NllLossBackward>)
# train tensor(1.1192, grad_fn=<NllLossBackward>)
# train tensor(0.8175, grad_fn=<NllLossBackward>)
# train tensor(0.9539, grad_fn=<NllLossBackward>)
# train tensor(0.7724, grad_fn=<NllLossBackward>)
# train tensor(0.7866, grad_fn=<NllLossBackward>)
# train tensor(1.0323, grad_fn=<NllLossBackward>)
# train tensor(1.0178, grad_fn=<NllLossBackward>)
# train tensor(0.6846, grad_fn=<NllLossBackward>)
# train tensor(0.7416, grad_fn=<NllLossBackward>)
# train tensor(0.5726, grad_fn=<NllLossBackward>)
# train tensor(0.6247, grad_fn=<NllLossBackward>)
# train tensor(0.7707, grad_fn=<NllLossBackward>)
# train tensor(0.4956, grad_fn=<NllLossBackward>)
# train tensor(0.8222, grad_fn=<NllLossBackward>)
# train tensor(0.7806, grad_fn=<NllLossBackward>)
# train tensor(0.6125, grad_fn=<NllLossBackward>)
# train tensor(0.3720, grad_fn=<NllLossBackward>)
# train tensor(0.6096, grad_fn=<NllLossBackward>)
# train tensor(0.7264, grad_fn=<NllLossBackward>)
# train tensor(0.5945, grad_fn=<NllLossBackward>)
# train tensor(0.5953, grad_fn=<NllLossBackward>)
# train tensor(0.4785, grad_fn=<NllLossBackward>)
# train tensor(0.7761, grad_fn=<NllLossBackward>)
# train tensor(0.8869, grad_fn=<NllLossBackward>)
# train tensor(0.6158, grad_fn=<NllLossBackward>)
# train tensor(0.8237, grad_fn=<NllLossBackward>)
# train tensor(0.4530, grad_fn=<NllLossBackward>)
# train tensor(1.0629, grad_fn=<NllLossBackward>)
# train tensor(0.7285, grad_fn=<NllLossBackward>)
# train tensor(0.6090, grad_fn=<NllLossBackward>)
# train tensor(0.8113, grad_fn=<NllLossBackward>)
# train tensor(0.7491, grad_fn=<NllLossBackward>)
# train tensor(0.7337, grad_fn=<NllLossBackward>)
# train tensor(0.6602, grad_fn=<NllLossBackward>)
# train tensor(0.8407, grad_fn=<NllLossBackward>)
# train tensor(0.6904, grad_fn=<NllLossBackward>)
# train tensor(0.3858, grad_fn=<NllLossBackward>)
# train tensor(0.7037, grad_fn=<NllLossBackward>)
# train tensor(0.6183, grad_fn=<NllLossBackward>)
# train tensor(0.6480, grad_fn=<NllLossBackward>)
# train tensor(0.3944, grad_fn=<NllLossBackward>)
# train tensor(0.7020, grad_fn=<NllLossBackward>)
# train tensor(0.4398, grad_fn=<NllLossBackward>)
# train tensor(0.6613, grad_fn=<NllLossBackward>)
# train tensor(0.5238, grad_fn=<NllLossBackward>)
# train tensor(0.7161, grad_fn=<NllLossBackward>)
# train tensor(0.5636, grad_fn=<NllLossBackward>)
# train tensor(0.7744, grad_fn=<NllLossBackward>)
# train tensor(0.5937, grad_fn=<NllLossBackward>)
# train tensor(0.7559, grad_fn=<NllLossBackward>)
# train tensor(0.6756, grad_fn=<NllLossBackward>)
# train tensor(0.7385, grad_fn=<NllLossBackward>)
# train tensor(0.7911, grad_fn=<NllLossBackward>)
# train tensor(0.7524, grad_fn=<NllLossBackward>)
# train tensor(0.5376, grad_fn=<NllLossBackward>)
# train tensor(1.1843, grad_fn=<NllLossBackward>)
# train tensor(0.9805, grad_fn=<NllLossBackward>)
# train tensor(0.6730, grad_fn=<NllLossBackward>)
# train tensor(0.6945, grad_fn=<NllLossBackward>)
# train tensor(0.6788, grad_fn=<NllLossBackward>)
# train tensor(0.6452, grad_fn=<NllLossBackward>)
# train tensor(0.6856, grad_fn=<NllLossBackward>)
# train tensor(0.7274, grad_fn=<NllLossBackward>)
# train tensor(0.6044, grad_fn=<NllLossBackward>)
# train tensor(0.4996, grad_fn=<NllLossBackward>)
# train tensor(0.7249, grad_fn=<NllLossBackward>)
# train tensor(0.7487, grad_fn=<NllLossBackward>)
# train tensor(0.6520, grad_fn=<NllLossBackward>)
# train tensor(0.5190, grad_fn=<NllLossBackward>)
# train tensor(0.5857, grad_fn=<NllLossBackward>)
# train tensor(0.6202, grad_fn=<NllLossBackward>)
# train tensor(0.6838, grad_fn=<NllLossBackward>)
# train tensor(0.7035, grad_fn=<NllLossBackward>)
# train tensor(0.3896, grad_fn=<NllLossBackward>)
# train tensor(0.5154, grad_fn=<NllLossBackward>)
# train tensor(0.6616, grad_fn=<NllLossBackward>)
# train tensor(0.5262, grad_fn=<NllLossBackward>)
# train tensor(0.6171, grad_fn=<NllLossBackward>)
# train tensor(0.7865, grad_fn=<NllLossBackward>)
# train tensor(0.6887, grad_fn=<NllLossBackward>)
# train tensor(0.4845, grad_fn=<NllLossBackward>)
# train tensor(0.5337, grad_fn=<NllLossBackward>)
# train tensor(0.8510, grad_fn=<NllLossBackward>)
# train tensor(0.9362, grad_fn=<NllLossBackward>)
# train tensor(0.6144, grad_fn=<NllLossBackward>)
# train tensor(0.7900, grad_fn=<NllLossBackward>)
# train tensor(0.7158, grad_fn=<NllLossBackward>)
# train tensor(0.4925, grad_fn=<NllLossBackward>)
# train tensor(0.5438, grad_fn=<NllLossBackward>)
# train tensor(0.5973, grad_fn=<NllLossBackward>)
# train tensor(0.8845, grad_fn=<NllLossBackward>)
# train tensor(0.6764, grad_fn=<NllLossBackward>)
# train tensor(0.6902, grad_fn=<NllLossBackward>)
# train tensor(0.6345, grad_fn=<NllLossBackward>)
# train tensor(0.5823, grad_fn=<NllLossBackward>)
# train tensor(0.5808, grad_fn=<NllLossBackward>)
# train tensor(0.6803, grad_fn=<NllLossBackward>)
# train tensor(0.4616, grad_fn=<NllLossBackward>)
# train tensor(0.4552, grad_fn=<NllLossBackward>)
# train tensor(0.6893, grad_fn=<NllLossBackward>)
# train tensor(0.9240, grad_fn=<NllLossBackward>)
# train tensor(0.5396, grad_fn=<NllLossBackward>)
# train tensor(0.4874, grad_fn=<NllLossBackward>)
# train tensor(0.6881, grad_fn=<NllLossBackward>)
# train tensor(0.6601, grad_fn=<NllLossBackward>)
# train tensor(1.0267, grad_fn=<NllLossBackward>)
# train tensor(0.6759, grad_fn=<NllLossBackward>)
# train tensor(0.5636, grad_fn=<NllLossBackward>)
# train tensor(0.6028, grad_fn=<NllLossBackward>)
# train tensor(0.4418, grad_fn=<NllLossBackward>)
# train tensor(0.6589, grad_fn=<NllLossBackward>)
# train tensor(0.4691, grad_fn=<NllLossBackward>)
# train tensor(0.7384, grad_fn=<NllLossBackward>)
# train tensor(0.5895, grad_fn=<NllLossBackward>)
# train tensor(0.6921, grad_fn=<NllLossBackward>)
# train tensor(0.5086, grad_fn=<NllLossBackward>)
# train tensor(0.5300, grad_fn=<NllLossBackward>)
# train tensor(0.8763, grad_fn=<NllLossBackward>)
# train tensor(0.9251, grad_fn=<NllLossBackward>)
# train tensor(0.6053, grad_fn=<NllLossBackward>)
# train tensor(0.4916, grad_fn=<NllLossBackward>)
# train tensor(0.5122, grad_fn=<NllLossBackward>)
# train tensor(0.4199, grad_fn=<NllLossBackward>)
# train tensor(0.6396, grad_fn=<NllLossBackward>)
# train tensor(0.6267, grad_fn=<NllLossBackward>)
# train tensor(0.4325, grad_fn=<NllLossBackward>)
# train tensor(0.7436, grad_fn=<NllLossBackward>)
# train tensor(0.4749, grad_fn=<NllLossBackward>)
# train tensor(0.4148, grad_fn=<NllLossBackward>)
# train tensor(0.4889, grad_fn=<NllLossBackward>)
# train tensor(1.0802, grad_fn=<NllLossBackward>)
# train tensor(0.4665, grad_fn=<NllLossBackward>)
# train tensor(0.6278, grad_fn=<NllLossBackward>)
# train tensor(0.5264, grad_fn=<NllLossBackward>)
# train tensor(0.6404, grad_fn=<NllLossBackward>)
# train tensor(0.5065, grad_fn=<NllLossBackward>)
# train tensor(0.5088, grad_fn=<NllLossBackward>)
# train tensor(0.3322, grad_fn=<NllLossBackward>)
# train tensor(0.3758, grad_fn=<NllLossBackward>)
# train tensor(0.7577, grad_fn=<NllLossBackward>)
# train tensor(0.4751, grad_fn=<NllLossBackward>)
# train tensor(0.5801, grad_fn=<NllLossBackward>)
# train tensor(0.5732, grad_fn=<NllLossBackward>)
# train tensor(0.5850, grad_fn=<NllLossBackward>)
# train tensor(0.7707, grad_fn=<NllLossBackward>)
# train tensor(0.5488, grad_fn=<NllLossBackward>)
# train tensor(0.8054, grad_fn=<NllLossBackward>)
# train tensor(0.5562, grad_fn=<NllLossBackward>)
# train tensor(0.3411, grad_fn=<NllLossBackward>)
# train tensor(0.6064, grad_fn=<NllLossBackward>)
# train tensor(0.4958, grad_fn=<NllLossBackward>)
# train tensor(0.5966, grad_fn=<NllLossBackward>)
# train tensor(0.5972, grad_fn=<NllLossBackward>)
# train tensor(0.6566, grad_fn=<NllLossBackward>)
# train tensor(0.6748, grad_fn=<NllLossBackward>)
# train tensor(0.4198, grad_fn=<NllLossBackward>)
# train tensor(0.4575, grad_fn=<NllLossBackward>)
# train tensor(0.5100, grad_fn=<NllLossBackward>)
# train tensor(0.8981, grad_fn=<NllLossBackward>)
# train tensor(0.4522, grad_fn=<NllLossBackward>)
# train tensor(0.8021, grad_fn=<NllLossBackward>)
# train tensor(0.7384, grad_fn=<NllLossBackward>)
# train tensor(0.5167, grad_fn=<NllLossBackward>)
# train tensor(0.5795, grad_fn=<NllLossBackward>)
# train tensor(0.5892, grad_fn=<NllLossBackward>)
# train tensor(0.4411, grad_fn=<NllLossBackward>)
# train tensor(0.5716, grad_fn=<NllLossBackward>)
# train tensor(0.5143, grad_fn=<NllLossBackward>)
# train tensor(0.7701, grad_fn=<NllLossBackward>)
# train tensor(0.4453, grad_fn=<NllLossBackward>)
# train tensor(0.5051, grad_fn=<NllLossBackward>)
# train tensor(0.6332, grad_fn=<NllLossBackward>)
# train tensor(0.4875, grad_fn=<NllLossBackward>)
# train tensor(0.6977, grad_fn=<NllLossBackward>)
# train tensor(0.4964, grad_fn=<NllLossBackward>)
# train tensor(0.5691, grad_fn=<NllLossBackward>)
# train tensor(0.6194, grad_fn=<NllLossBackward>)
# train tensor(0.6174, grad_fn=<NllLossBackward>)
# train tensor(0.4617, grad_fn=<NllLossBackward>)
# train tensor(0.7453, grad_fn=<NllLossBackward>)
# train tensor(0.6851, grad_fn=<NllLossBackward>)
# train tensor(0.4921, grad_fn=<NllLossBackward>)
# train tensor(0.3641, grad_fn=<NllLossBackward>)
# train tensor(0.7235, grad_fn=<NllLossBackward>)
# train tensor(0.5451, grad_fn=<NllLossBackward>)
# train tensor(0.4974, grad_fn=<NllLossBackward>)
# train tensor(0.6713, grad_fn=<NllLossBackward>)
# train tensor(0.5597, grad_fn=<NllLossBackward>)
# train tensor(0.8097, grad_fn=<NllLossBackward>)
# train tensor(0.4318, grad_fn=<NllLossBackward>)
# train tensor(0.5116, grad_fn=<NllLossBackward>)
# train tensor(0.7747, grad_fn=<NllLossBackward>)
# train tensor(0.9110, grad_fn=<NllLossBackward>)
# train tensor(0.6134, grad_fn=<NllLossBackward>)
# train tensor(0.6158, grad_fn=<NllLossBackward>)
# train tensor(0.5018, grad_fn=<NllLossBackward>)
# train tensor(0.6408, grad_fn=<NllLossBackward>)
# train tensor(0.7697, grad_fn=<NllLossBackward>)
# train tensor(0.4656, grad_fn=<NllLossBackward>)
# train tensor(0.5475, grad_fn=<NllLossBackward>)
# train tensor(0.4690, grad_fn=<NllLossBackward>)
# train tensor(0.4122, grad_fn=<NllLossBackward>)
# train tensor(0.5606, grad_fn=<NllLossBackward>)
# train tensor(0.5285, grad_fn=<NllLossBackward>)
# train tensor(0.5409, grad_fn=<NllLossBackward>)
# train tensor(0.5906, grad_fn=<NllLossBackward>)
# train tensor(0.7259, grad_fn=<NllLossBackward>)
# train tensor(0.4671, grad_fn=<NllLossBackward>)
# train tensor(0.2880, grad_fn=<NllLossBackward>)
# train tensor(0.4862, grad_fn=<NllLossBackward>)
# train tensor(0.3890, grad_fn=<NllLossBackward>)
# train tensor(0.6857, grad_fn=<NllLossBackward>)
# train tensor(0.3077, grad_fn=<NllLossBackward>)
# train tensor(0.2983, grad_fn=<NllLossBackward>)
# train tensor(0.4406, grad_fn=<NllLossBackward>)
# train tensor(0.5719, grad_fn=<NllLossBackward>)
# train tensor(0.5864, grad_fn=<NllLossBackward>)
# train tensor(0.2976, grad_fn=<NllLossBackward>)
# train tensor(0.6280, grad_fn=<NllLossBackward>)
# train tensor(0.5483, grad_fn=<NllLossBackward>)
# train tensor(0.7759, grad_fn=<NllLossBackward>)
# train tensor(0.2083, grad_fn=<NllLossBackward>)
# train tensor(0.5023, grad_fn=<NllLossBackward>)
# train tensor(0.4816, grad_fn=<NllLossBackward>)
# train tensor(0.5262, grad_fn=<NllLossBackward>)
# train tensor(0.6091, grad_fn=<NllLossBackward>)
# train tensor(0.9510, grad_fn=<NllLossBackward>)
# train tensor(0.7374, grad_fn=<NllLossBackward>)
# train tensor(0.4634, grad_fn=<NllLossBackward>)
# train tensor(0.3587, grad_fn=<NllLossBackward>)
# train tensor(0.5700, grad_fn=<NllLossBackward>)
# train tensor(0.3569, grad_fn=<NllLossBackward>)
# train tensor(0.2876, grad_fn=<NllLossBackward>)
# train tensor(0.4690, grad_fn=<NllLossBackward>)
# train tensor(0.5201, grad_fn=<NllLossBackward>)
# train tensor(0.5961, grad_fn=<NllLossBackward>)
# train tensor(0.3709, grad_fn=<NllLossBackward>)
# train tensor(0.7146, grad_fn=<NllLossBackward>)
# train tensor(0.4273, grad_fn=<NllLossBackward>)
# train tensor(0.5922, grad_fn=<NllLossBackward>)
# train tensor(0.5065, grad_fn=<NllLossBackward>)
# train tensor(0.5578, grad_fn=<NllLossBackward>)
# train tensor(0.3300, grad_fn=<NllLossBackward>)
# train tensor(0.3664, grad_fn=<NllLossBackward>)
# train tensor(0.7276, grad_fn=<NllLossBackward>)
# train tensor(0.5684, grad_fn=<NllLossBackward>)
# train tensor(0.2833, grad_fn=<NllLossBackward>)
# train tensor(0.3842, grad_fn=<NllLossBackward>)
# train tensor(0.5104, grad_fn=<NllLossBackward>)
# train tensor(0.4353, grad_fn=<NllLossBackward>)
# train tensor(0.3683, grad_fn=<NllLossBackward>)
# train tensor(0.7451, grad_fn=<NllLossBackward>)
# train tensor(0.6109, grad_fn=<NllLossBackward>)
# train tensor(0.4621, grad_fn=<NllLossBackward>)
# train tensor(0.5482, grad_fn=<NllLossBackward>)
# train tensor(0.5079, grad_fn=<NllLossBackward>)
# train tensor(0.5980, grad_fn=<NllLossBackward>)
# train tensor(0.5815, grad_fn=<NllLossBackward>)
# train tensor(0.6852, grad_fn=<NllLossBackward>)
# train tensor(0.3843, grad_fn=<NllLossBackward>)
# train tensor(0.3680, grad_fn=<NllLossBackward>)
# train tensor(0.3610, grad_fn=<NllLossBackward>)
# train tensor(0.3645, grad_fn=<NllLossBackward>)
# train tensor(0.2747, grad_fn=<NllLossBackward>)
# train tensor(0.3389, grad_fn=<NllLossBackward>)
# train tensor(0.5591, grad_fn=<NllLossBackward>)
# train tensor(0.5631, grad_fn=<NllLossBackward>)
# train tensor(0.5952, grad_fn=<NllLossBackward>)
# train tensor(0.5969, grad_fn=<NllLossBackward>)
# train tensor(0.7426, grad_fn=<NllLossBackward>)
# train tensor(0.3253, grad_fn=<NllLossBackward>)
# train tensor(0.5055, grad_fn=<NllLossBackward>)
# train tensor(0.5605, grad_fn=<NllLossBackward>)
# train tensor(0.3587, grad_fn=<NllLossBackward>)
# train tensor(0.5075, grad_fn=<NllLossBackward>)
# train tensor(0.5830, grad_fn=<NllLossBackward>)
# train tensor(0.4684, grad_fn=<NllLossBackward>)
# train tensor(0.4127, grad_fn=<NllLossBackward>)
# train tensor(0.9010, grad_fn=<NllLossBackward>)
# train tensor(0.6777, grad_fn=<NllLossBackward>)
# train tensor(0.6364, grad_fn=<NllLossBackward>)
# train tensor(0.4873, grad_fn=<NllLossBackward>)
# train tensor(0.4071, grad_fn=<NllLossBackward>)
# train tensor(0.6480, grad_fn=<NllLossBackward>)
# train tensor(0.7265, grad_fn=<NllLossBackward>)
# train tensor(0.5830, grad_fn=<NllLossBackward>)
# train tensor(0.3258, grad_fn=<NllLossBackward>)
# train tensor(0.6441, grad_fn=<NllLossBackward>)
# train tensor(0.9969, grad_fn=<NllLossBackward>)
# train tensor(0.8813, grad_fn=<NllLossBackward>)
# train tensor(0.5531, grad_fn=<NllLossBackward>)
# train tensor(0.5053, grad_fn=<NllLossBackward>)
# train tensor(0.5525, grad_fn=<NllLossBackward>)
# train tensor(0.7004, grad_fn=<NllLossBackward>)
# train tensor(0.5592, grad_fn=<NllLossBackward>)
# train tensor(0.5073, grad_fn=<NllLossBackward>)
# train tensor(0.6944, grad_fn=<NllLossBackward>)
# train tensor(0.2815, grad_fn=<NllLossBackward>)
# train tensor(0.5275, grad_fn=<NllLossBackward>)
# train tensor(0.5751, grad_fn=<NllLossBackward>)
# train tensor(0.5303, grad_fn=<NllLossBackward>)
# train tensor(0.4448, grad_fn=<NllLossBackward>)
# train tensor(0.6339, grad_fn=<NllLossBackward>)
# train tensor(0.5511, grad_fn=<NllLossBackward>)
# train tensor(0.2876, grad_fn=<NllLossBackward>)
# train tensor(0.6777, grad_fn=<NllLossBackward>)
# train tensor(0.4741, grad_fn=<NllLossBackward>)
# train tensor(0.3771, grad_fn=<NllLossBackward>)
# train tensor(0.6939, grad_fn=<NllLossBackward>)
# train tensor(0.4264, grad_fn=<NllLossBackward>)
# train tensor(0.4053, grad_fn=<NllLossBackward>)
# train tensor(0.6391, grad_fn=<NllLossBackward>)
# train tensor(0.5688, grad_fn=<NllLossBackward>)
# train tensor(0.5029, grad_fn=<NllLossBackward>)
# train tensor(0.5937, grad_fn=<NllLossBackward>)
# train tensor(0.6232, grad_fn=<NllLossBackward>)
# train tensor(0.5285, grad_fn=<NllLossBackward>)
# train tensor(0.3434, grad_fn=<NllLossBackward>)
# train tensor(0.5288, grad_fn=<NllLossBackward>)
# train tensor(0.4334, grad_fn=<NllLossBackward>)
# train tensor(0.6240, grad_fn=<NllLossBackward>)
# train tensor(0.4945, grad_fn=<NllLossBackward>)
# train tensor(0.4062, grad_fn=<NllLossBackward>)
# train tensor(0.5983, grad_fn=<NllLossBackward>)
# train tensor(0.6887, grad_fn=<NllLossBackward>)
# train tensor(0.3126, grad_fn=<NllLossBackward>)
# train tensor(0.4912, grad_fn=<NllLossBackward>)
# train tensor(0.5248, grad_fn=<NllLossBackward>)
# train tensor(0.4610, grad_fn=<NllLossBackward>)
# train tensor(0.4577, grad_fn=<NllLossBackward>)
# train tensor(0.5852, grad_fn=<NllLossBackward>)
# train tensor(0.5089, grad_fn=<NllLossBackward>)
# train tensor(0.5579, grad_fn=<NllLossBackward>)
# train tensor(0.3620, grad_fn=<NllLossBackward>)
# train tensor(0.5559, grad_fn=<NllLossBackward>)
# train tensor(0.3319, grad_fn=<NllLossBackward>)
# train tensor(0.4630, grad_fn=<NllLossBackward>)
# train tensor(0.2922, grad_fn=<NllLossBackward>)
# train tensor(0.3832, grad_fn=<NllLossBackward>)
# train tensor(0.4043, grad_fn=<NllLossBackward>)
# train tensor(0.4451, grad_fn=<NllLossBackward>)
# train tensor(0.2863, grad_fn=<NllLossBackward>)
# train tensor(0.5248, grad_fn=<NllLossBackward>)
# train tensor(0.4077, grad_fn=<NllLossBackward>)
# train tensor(0.5833, grad_fn=<NllLossBackward>)
# train tensor(0.7130, grad_fn=<NllLossBackward>)
# train tensor(0.9677, grad_fn=<NllLossBackward>)
# train tensor(0.6698, grad_fn=<NllLossBackward>)
# train tensor(0.5285, grad_fn=<NllLossBackward>)
# train tensor(0.5503, grad_fn=<NllLossBackward>)
# train tensor(0.5286, grad_fn=<NllLossBackward>)
# train tensor(0.4849, grad_fn=<NllLossBackward>)
# train tensor(0.3226, grad_fn=<NllLossBackward>)
# train tensor(0.4937, grad_fn=<NllLossBackward>)
# train tensor(0.5247, grad_fn=<NllLossBackward>)
# train tensor(0.7285, grad_fn=<NllLossBackward>)
# train tensor(0.5970, grad_fn=<NllLossBackward>)
# train tensor(0.6203, grad_fn=<NllLossBackward>)
# train tensor(0.6853, grad_fn=<NllLossBackward>)
# train tensor(0.4676, grad_fn=<NllLossBackward>)
# train tensor(0.5220, grad_fn=<NllLossBackward>)
# train tensor(0.6356, grad_fn=<NllLossBackward>)
# train tensor(0.3325, grad_fn=<NllLossBackward>)
# train tensor(0.6647, grad_fn=<NllLossBackward>)
# train tensor(0.4671, grad_fn=<NllLossBackward>)
# train tensor(0.7224, grad_fn=<NllLossBackward>)
# train tensor(0.4814, grad_fn=<NllLossBackward>)
# train tensor(0.3977, grad_fn=<NllLossBackward>)
# train tensor(0.4657, grad_fn=<NllLossBackward>)
# train tensor(0.6339, grad_fn=<NllLossBackward>)
# train tensor(0.7012, grad_fn=<NllLossBackward>)
# train tensor(0.5047, grad_fn=<NllLossBackward>)
# train tensor(0.4878, grad_fn=<NllLossBackward>)
# train tensor(0.4060, grad_fn=<NllLossBackward>)
# train tensor(0.3743, grad_fn=<NllLossBackward>)
# train tensor(0.6140, grad_fn=<NllLossBackward>)
# train tensor(0.5665, grad_fn=<NllLossBackward>)
# train tensor(0.4350, grad_fn=<NllLossBackward>)
# train tensor(0.3136, grad_fn=<NllLossBackward>)
# train tensor(0.3554, grad_fn=<NllLossBackward>)
# train tensor(0.3335, grad_fn=<NllLossBackward>)
# train tensor(0.3358, grad_fn=<NllLossBackward>)
# train tensor(0.5554, grad_fn=<NllLossBackward>)
# train tensor(0.5843, grad_fn=<NllLossBackward>)
# train tensor(0.5413, grad_fn=<NllLossBackward>)
# train tensor(0.2609, grad_fn=<NllLossBackward>)
# train tensor(0.4495, grad_fn=<NllLossBackward>)
# train tensor(0.3613, grad_fn=<NllLossBackward>)
# train tensor(0.5651, grad_fn=<NllLossBackward>)
# train tensor(0.3881, grad_fn=<NllLossBackward>)
# train tensor(0.4491, grad_fn=<NllLossBackward>)
# train tensor(0.3350, grad_fn=<NllLossBackward>)
# train tensor(0.2656, grad_fn=<NllLossBackward>)
# train tensor(0.4351, grad_fn=<NllLossBackward>)
# train tensor(0.2304, grad_fn=<NllLossBackward>)
# train tensor(0.5778, grad_fn=<NllLossBackward>)
# train tensor(0.5800, grad_fn=<NllLossBackward>)
# train tensor(0.3865, grad_fn=<NllLossBackward>)
# train tensor(0.4127, grad_fn=<NllLossBackward>)
# train tensor(0.4529, grad_fn=<NllLossBackward>)
# train tensor(0.4063, grad_fn=<NllLossBackward>)
# train tensor(0.5821, grad_fn=<NllLossBackward>)
# train tensor(0.4326, grad_fn=<NllLossBackward>)
# train tensor(0.2853, grad_fn=<NllLossBackward>)
# train tensor(0.3971, grad_fn=<NllLossBackward>)
# train tensor(0.5808, grad_fn=<NllLossBackward>)
# train tensor(0.4059, grad_fn=<NllLossBackward>)
# train tensor(0.2519, grad_fn=<NllLossBackward>)
# train tensor(0.6071, grad_fn=<NllLossBackward>)
# train tensor(0.3396, grad_fn=<NllLossBackward>)
# train tensor(0.5686, grad_fn=<NllLossBackward>)
# train tensor(0.5785, grad_fn=<NllLossBackward>)
# train tensor(0.2139, grad_fn=<NllLossBackward>)
# train tensor(0.4614, grad_fn=<NllLossBackward>)
# train tensor(0.5765, grad_fn=<NllLossBackward>)
# train tensor(0.3644, grad_fn=<NllLossBackward>)
# train tensor(0.8208, grad_fn=<NllLossBackward>)
# train tensor(0.3165, grad_fn=<NllLossBackward>)
# train tensor(0.1895, grad_fn=<NllLossBackward>)
# train tensor(0.5816, grad_fn=<NllLossBackward>)
# train tensor(0.3793, grad_fn=<NllLossBackward>)
# train tensor(0.3917, grad_fn=<NllLossBackward>)
# train tensor(0.3795, grad_fn=<NllLossBackward>)
# train tensor(0.3093, grad_fn=<NllLossBackward>)
# train tensor(0.5195, grad_fn=<NllLossBackward>)
# train tensor(0.4229, grad_fn=<NllLossBackward>)
# train tensor(0.7289, grad_fn=<NllLossBackward>)
# train tensor(0.3852, grad_fn=<NllLossBackward>)
# train tensor(0.4584, grad_fn=<NllLossBackward>)
# train tensor(0.6076, grad_fn=<NllLossBackward>)
# train tensor(0.4999, grad_fn=<NllLossBackward>)
# train tensor(0.4990, grad_fn=<NllLossBackward>)
# train tensor(0.7452, grad_fn=<NllLossBackward>)
# train tensor(0.4555, grad_fn=<NllLossBackward>)
# train tensor(0.2530, grad_fn=<NllLossBackward>)
# train tensor(0.2566, grad_fn=<NllLossBackward>)
# train tensor(0.4644, grad_fn=<NllLossBackward>)
# train tensor(0.6369, grad_fn=<NllLossBackward>)
# train tensor(0.5480, grad_fn=<NllLossBackward>)
# train tensor(0.5952, grad_fn=<NllLossBackward>)
# train tensor(0.4695, grad_fn=<NllLossBackward>)
# train tensor(0.5327, grad_fn=<NllLossBackward>)
# train tensor(0.4395, grad_fn=<NllLossBackward>)
# train tensor(0.4177, grad_fn=<NllLossBackward>)
# train tensor(0.4927, grad_fn=<NllLossBackward>)
# train tensor(0.6403, grad_fn=<NllLossBackward>)
# train tensor(0.3823, grad_fn=<NllLossBackward>)
# train tensor(0.3531, grad_fn=<NllLossBackward>)
# train tensor(0.5538, grad_fn=<NllLossBackward>)
# train tensor(0.4189, grad_fn=<NllLossBackward>)
# train tensor(0.3444, grad_fn=<NllLossBackward>)
# train tensor(0.3621, grad_fn=<NllLossBackward>)
# train tensor(0.5248, grad_fn=<NllLossBackward>)
# train tensor(0.2280, grad_fn=<NllLossBackward>)
# train tensor(0.3581, grad_fn=<NllLossBackward>)
# train tensor(0.6701, grad_fn=<NllLossBackward>)
# train tensor(0.5874, grad_fn=<NllLossBackward>)
# train tensor(0.6824, grad_fn=<NllLossBackward>)
# train tensor(0.7725, grad_fn=<NllLossBackward>)
# train tensor(0.2431, grad_fn=<NllLossBackward>)
# train tensor(0.4567, grad_fn=<NllLossBackward>)
# train tensor(0.5038, grad_fn=<NllLossBackward>)
# train tensor(0.5765, grad_fn=<NllLossBackward>)
# train tensor(0.8415, grad_fn=<NllLossBackward>)
# train tensor(0.4415, grad_fn=<NllLossBackward>)
# train tensor(0.3219, grad_fn=<NllLossBackward>)
# train tensor(0.3427, grad_fn=<NllLossBackward>)
# train tensor(0.3693, grad_fn=<NllLossBackward>)
# train tensor(0.5125, grad_fn=<NllLossBackward>)
# train tensor(0.7113, grad_fn=<NllLossBackward>)
# train tensor(0.3489, grad_fn=<NllLossBackward>)
# train tensor(0.5298, grad_fn=<NllLossBackward>)
# train tensor(0.5806, grad_fn=<NllLossBackward>)
# train tensor(0.8872, grad_fn=<NllLossBackward>)
# train tensor(0.7107, grad_fn=<NllLossBackward>)
# train tensor(0.4098, grad_fn=<NllLossBackward>)
# train tensor(0.5949, grad_fn=<NllLossBackward>)
# train tensor(0.4443, grad_fn=<NllLossBackward>)
# train tensor(0.4393, grad_fn=<NllLossBackward>)
# train tensor(0.4276, grad_fn=<NllLossBackward>)
# train tensor(0.5676, grad_fn=<NllLossBackward>)
# train tensor(0.5118, grad_fn=<NllLossBackward>)
# train tensor(0.4113, grad_fn=<NllLossBackward>)
# train tensor(0.5273, grad_fn=<NllLossBackward>)
# train tensor(0.4714, grad_fn=<NllLossBackward>)
# train tensor(0.4423, grad_fn=<NllLossBackward>)
# train tensor(0.4588, grad_fn=<NllLossBackward>)
# train tensor(0.5645, grad_fn=<NllLossBackward>)
# train tensor(0.4590, grad_fn=<NllLossBackward>)
# train tensor(0.5874, grad_fn=<NllLossBackward>)
# train tensor(0.5021, grad_fn=<NllLossBackward>)
# train tensor(0.4209, grad_fn=<NllLossBackward>)
# train tensor(0.4249, grad_fn=<NllLossBackward>)
# train tensor(0.4222, grad_fn=<NllLossBackward>)
# train tensor(0.6189, grad_fn=<NllLossBackward>)
# train tensor(0.5127, grad_fn=<NllLossBackward>)
# train tensor(0.5261, grad_fn=<NllLossBackward>)
# train tensor(0.4282, grad_fn=<NllLossBackward>)
# train tensor(0.5295, grad_fn=<NllLossBackward>)
# train tensor(0.4775, grad_fn=<NllLossBackward>)
# train tensor(0.3424, grad_fn=<NllLossBackward>)
# train tensor(0.4115, grad_fn=<NllLossBackward>)
# train tensor(0.3664, grad_fn=<NllLossBackward>)
# train tensor(0.2805, grad_fn=<NllLossBackward>)
# tensor(0.3368, grad_fn=<AddBackward0>)
# tensor(0.8411, grad_fn=<AddBackward0>)
# tensor(1.3049, grad_fn=<AddBackward0>)
# tensor(1.8620, grad_fn=<AddBackward0>)
# tensor(2.3709, grad_fn=<AddBackward0>)
# tensor(2.7897, grad_fn=<AddBackward0>)
# tensor(3.0971, grad_fn=<AddBackward0>)
# tensor(3.3923, grad_fn=<AddBackward0>)
# tensor(3.6239, grad_fn=<AddBackward0>)
# tensor(4.0945, grad_fn=<AddBackward0>)
# tensor(4.3802, grad_fn=<AddBackward0>)
# tensor(4.7103, grad_fn=<AddBackward0>)
# tensor(5.0676, grad_fn=<AddBackward0>)
# tensor(5.4067, grad_fn=<AddBackward0>)
# tensor(5.6819, grad_fn=<AddBackward0>)
# tensor(6.0734, grad_fn=<AddBackward0>)
# tensor(6.9161, grad_fn=<AddBackward0>)
# tensor(7.3138, grad_fn=<AddBackward0>)
# tensor(7.6686, grad_fn=<AddBackward0>)
# tensor(7.9105, grad_fn=<AddBackward0>)
# tensor(8.2627, grad_fn=<AddBackward0>)
# tensor(8.7770, grad_fn=<AddBackward0>)
# tensor(9.4412, grad_fn=<AddBackward0>)
# tensor(9.8805, grad_fn=<AddBackward0>)
# tensor(10.2585, grad_fn=<AddBackward0>)
# tensor(10.6356, grad_fn=<AddBackward0>)
# tensor(10.9971, grad_fn=<AddBackward0>)
# tensor(11.4724, grad_fn=<AddBackward0>)
# tensor(11.8970, grad_fn=<AddBackward0>)
# tensor(12.2097, grad_fn=<AddBackward0>)
# tensor(12.6640, grad_fn=<AddBackward0>)
# tensor(13.2452, grad_fn=<AddBackward0>)
# tensor(13.4785, grad_fn=<AddBackward0>)
# tensor(13.7690, grad_fn=<AddBackward0>)
# tensor(14.1673, grad_fn=<AddBackward0>)
# tensor(14.5690, grad_fn=<AddBackward0>)
# tensor(14.8212, grad_fn=<AddBackward0>)
# tensor(15.1422, grad_fn=<AddBackward0>)
# tensor(15.7816, grad_fn=<AddBackward0>)
# tensor(16.2072, grad_fn=<AddBackward0>)
# tensor(16.4473, grad_fn=<AddBackward0>)
# tensor(16.7290, grad_fn=<AddBackward0>)
# tensor(17.0621, grad_fn=<AddBackward0>)
# tensor(17.3143, grad_fn=<AddBackward0>)
# tensor(17.6143, grad_fn=<AddBackward0>)
# tensor(17.9739, grad_fn=<AddBackward0>)
# tensor(18.2735, grad_fn=<AddBackward0>)
# tensor(18.5064, grad_fn=<AddBackward0>)
# tensor(18.8981, grad_fn=<AddBackward0>)
# tensor(19.3849, grad_fn=<AddBackward0>)
# tensor(19.9806, grad_fn=<AddBackward0>)
# tensor(20.3701, grad_fn=<AddBackward0>)
# tensor(20.7533, grad_fn=<AddBackward0>)
# tensor(21.0055, grad_fn=<AddBackward0>)
# tensor(21.2478, grad_fn=<AddBackward0>)
# tensor(21.5433, grad_fn=<AddBackward0>)
# tensor(21.9324, grad_fn=<AddBackward0>)
# tensor(22.3577, grad_fn=<AddBackward0>)
# tensor(22.7126, grad_fn=<AddBackward0>)
# tensor(23.2438, grad_fn=<AddBackward0>)
# tensor(23.7280, grad_fn=<AddBackward0>)
# tensor(24.0717, grad_fn=<AddBackward0>)
# tensor(24.4289, grad_fn=<AddBackward0>)
# tensor(24.7145, grad_fn=<AddBackward0>)
# tensor(24.9186, grad_fn=<AddBackward0>)
# tensor(25.2116, grad_fn=<AddBackward0>)
# tensor(25.4198, grad_fn=<AddBackward0>)
# tensor(25.6953, grad_fn=<AddBackward0>)
# tensor(25.8857, grad_fn=<AddBackward0>)
# tensor(26.0731, grad_fn=<AddBackward0>)
# tensor(26.2236, grad_fn=<AddBackward0>)
# tensor(26.4188, grad_fn=<AddBackward0>)
# tensor(26.8358, grad_fn=<AddBackward0>)
# tensor(27.4816, grad_fn=<AddBackward0>)
# tensor(27.6148, grad_fn=<AddBackward0>)
# tensor(28.0937, grad_fn=<AddBackward0>)
# tensor(28.4027, grad_fn=<AddBackward0>)
# tensor(28.7547, grad_fn=<AddBackward0>)
# tensor(29.0308, grad_fn=<AddBackward0>)
# Epoch 0: 0.367
# train tensor(0.3093, grad_fn=<NllLossBackward>)
# train tensor(0.4972, grad_fn=<NllLossBackward>)
# train tensor(0.3115, grad_fn=<NllLossBackward>)
# train tensor(0.4779, grad_fn=<NllLossBackward>)
# train tensor(0.4320, grad_fn=<NllLossBackward>)
# train tensor(0.3818, grad_fn=<NllLossBackward>)
# train tensor(0.4583, grad_fn=<NllLossBackward>)
# train tensor(0.3092, grad_fn=<NllLossBackward>)
# train tensor(0.4780, grad_fn=<NllLossBackward>)
# train tensor(0.3107, grad_fn=<NllLossBackward>)
# train tensor(0.3366, grad_fn=<NllLossBackward>)
# train tensor(0.3813, grad_fn=<NllLossBackward>)
# train tensor(0.4943, grad_fn=<NllLossBackward>)
# train tensor(0.5108, grad_fn=<NllLossBackward>)
# train tensor(0.4094, grad_fn=<NllLossBackward>)
# train tensor(0.4390, grad_fn=<NllLossBackward>)
# train tensor(0.4559, grad_fn=<NllLossBackward>)
# train tensor(0.4108, grad_fn=<NllLossBackward>)
# train tensor(0.2996, grad_fn=<NllLossBackward>)
# train tensor(0.4083, grad_fn=<NllLossBackward>)
# train tensor(0.3654, grad_fn=<NllLossBackward>)
# train tensor(0.5057, grad_fn=<NllLossBackward>)
# train tensor(0.3952, grad_fn=<NllLossBackward>)
# train tensor(0.6655, grad_fn=<NllLossBackward>)
# train tensor(0.4199, grad_fn=<NllLossBackward>)
# train tensor(0.2559, grad_fn=<NllLossBackward>)
# train tensor(0.3734, grad_fn=<NllLossBackward>)
# train tensor(0.4528, grad_fn=<NllLossBackward>)
# train tensor(0.4756, grad_fn=<NllLossBackward>)
# train tensor(0.3417, grad_fn=<NllLossBackward>)
# train tensor(0.3293, grad_fn=<NllLossBackward>)
# train tensor(0.4250, grad_fn=<NllLossBackward>)
# train tensor(0.6124, grad_fn=<NllLossBackward>)
# train tensor(0.7702, grad_fn=<NllLossBackward>)
# train tensor(0.3658, grad_fn=<NllLossBackward>)
# train tensor(0.3416, grad_fn=<NllLossBackward>)
# train tensor(0.4912, grad_fn=<NllLossBackward>)
# train tensor(0.4396, grad_fn=<NllLossBackward>)
# train tensor(0.4608, grad_fn=<NllLossBackward>)
# train tensor(0.5684, grad_fn=<NllLossBackward>)
# train tensor(0.2953, grad_fn=<NllLossBackward>)
# train tensor(0.5371, grad_fn=<NllLossBackward>)
# train tensor(0.2875, grad_fn=<NllLossBackward>)
# train tensor(0.4735, grad_fn=<NllLossBackward>)
# train tensor(0.5120, grad_fn=<NllLossBackward>)
# train tensor(0.3336, grad_fn=<NllLossBackward>)
# train tensor(0.4445, grad_fn=<NllLossBackward>)
# train tensor(0.1883, grad_fn=<NllLossBackward>)
# train tensor(0.3369, grad_fn=<NllLossBackward>)
# train tensor(0.2576, grad_fn=<NllLossBackward>)
# train tensor(0.5498, grad_fn=<NllLossBackward>)
# train tensor(0.5386, grad_fn=<NllLossBackward>)
# train tensor(0.3346, grad_fn=<NllLossBackward>)
# train tensor(0.2607, grad_fn=<NllLossBackward>)
# train tensor(0.3878, grad_fn=<NllLossBackward>)
# train tensor(0.4207, grad_fn=<NllLossBackward>)
# train tensor(0.5216, grad_fn=<NllLossBackward>)
# train tensor(0.3613, grad_fn=<NllLossBackward>)
# train tensor(0.6955, grad_fn=<NllLossBackward>)
# train tensor(0.3328, grad_fn=<NllLossBackward>)
# train tensor(0.3438, grad_fn=<NllLossBackward>)
# train tensor(0.3608, grad_fn=<NllLossBackward>)
# train tensor(0.4098, grad_fn=<NllLossBackward>)
# train tensor(0.4259, grad_fn=<NllLossBackward>)
# train tensor(0.3422, grad_fn=<NllLossBackward>)
# train tensor(0.5311, grad_fn=<NllLossBackward>)
# train tensor(0.7324, grad_fn=<NllLossBackward>)
# train tensor(0.3201, grad_fn=<NllLossBackward>)
# train tensor(0.3567, grad_fn=<NllLossBackward>)
# train tensor(0.5333, grad_fn=<NllLossBackward>)
# train tensor(0.3842, grad_fn=<NllLossBackward>)
# train tensor(0.4770, grad_fn=<NllLossBackward>)
# train tensor(0.4189, grad_fn=<NllLossBackward>)
# train tensor(0.1426, grad_fn=<NllLossBackward>)
# train tensor(0.6388, grad_fn=<NllLossBackward>)
# train tensor(0.5222, grad_fn=<NllLossBackward>)
# train tensor(0.3934, grad_fn=<NllLossBackward>)
# train tensor(0.5339, grad_fn=<NllLossBackward>)
# train tensor(0.3051, grad_fn=<NllLossBackward>)
# train tensor(0.5653, grad_fn=<NllLossBackward>)
# train tensor(0.4931, grad_fn=<NllLossBackward>)
# train tensor(0.3484, grad_fn=<NllLossBackward>)
# train tensor(0.4587, grad_fn=<NllLossBackward>)
# train tensor(0.6218, grad_fn=<NllLossBackward>)
# train tensor(0.5521, grad_fn=<NllLossBackward>)
# train tensor(0.4978, grad_fn=<NllLossBackward>)
# train tensor(0.3719, grad_fn=<NllLossBackward>)
# train tensor(0.2206, grad_fn=<NllLossBackward>)
# train tensor(0.1779, grad_fn=<NllLossBackward>)
# train tensor(0.3564, grad_fn=<NllLossBackward>)
# train tensor(0.3929, grad_fn=<NllLossBackward>)
# train tensor(0.5751, grad_fn=<NllLossBackward>)
# train tensor(0.4484, grad_fn=<NllLossBackward>)
# train tensor(0.4201, grad_fn=<NllLossBackward>)
# train tensor(0.2893, grad_fn=<NllLossBackward>)
# train tensor(0.4346, grad_fn=<NllLossBackward>)
# train tensor(0.6102, grad_fn=<NllLossBackward>)
# train tensor(0.3873, grad_fn=<NllLossBackward>)
# train tensor(0.2271, grad_fn=<NllLossBackward>)
# train tensor(0.3610, grad_fn=<NllLossBackward>)
# train tensor(0.5485, grad_fn=<NllLossBackward>)
# train tensor(0.3667, grad_fn=<NllLossBackward>)
# train tensor(0.4284, grad_fn=<NllLossBackward>)
# train tensor(0.3288, grad_fn=<NllLossBackward>)
# train tensor(0.3135, grad_fn=<NllLossBackward>)
# train tensor(0.4608, grad_fn=<NllLossBackward>)
# train tensor(0.5523, grad_fn=<NllLossBackward>)
# train tensor(0.4551, grad_fn=<NllLossBackward>)
# train tensor(0.4432, grad_fn=<NllLossBackward>)
# train tensor(0.3617, grad_fn=<NllLossBackward>)
# train tensor(0.4844, grad_fn=<NllLossBackward>)
# train tensor(0.6101, grad_fn=<NllLossBackward>)
# train tensor(0.4449, grad_fn=<NllLossBackward>)
# train tensor(0.3969, grad_fn=<NllLossBackward>)
# train tensor(0.3822, grad_fn=<NllLossBackward>)
# train tensor(0.3961, grad_fn=<NllLossBackward>)
# train tensor(0.2500, grad_fn=<NllLossBackward>)
# train tensor(0.3456, grad_fn=<NllLossBackward>)
# train tensor(0.6361, grad_fn=<NllLossBackward>)
# train tensor(0.3129, grad_fn=<NllLossBackward>)
# train tensor(0.3465, grad_fn=<NllLossBackward>)
# train tensor(0.2842, grad_fn=<NllLossBackward>)
# train tensor(0.6499, grad_fn=<NllLossBackward>)
# train tensor(0.3354, grad_fn=<NllLossBackward>)
# train tensor(0.4443, grad_fn=<NllLossBackward>)
# train tensor(0.3900, grad_fn=<NllLossBackward>)
# train tensor(0.3468, grad_fn=<NllLossBackward>)
# train tensor(0.3792, grad_fn=<NllLossBackward>)
# train tensor(0.4179, grad_fn=<NllLossBackward>)
# train tensor(0.3973, grad_fn=<NllLossBackward>)
# train tensor(0.4562, grad_fn=<NllLossBackward>)
# train tensor(0.4143, grad_fn=<NllLossBackward>)
# train tensor(0.6448, grad_fn=<NllLossBackward>)
# train tensor(0.5817, grad_fn=<NllLossBackward>)
# train tensor(0.3905, grad_fn=<NllLossBackward>)
# train tensor(0.3021, grad_fn=<NllLossBackward>)
# train tensor(0.5477, grad_fn=<NllLossBackward>)
# train tensor(0.6765, grad_fn=<NllLossBackward>)
# train tensor(0.4168, grad_fn=<NllLossBackward>)
# train tensor(0.3929, grad_fn=<NllLossBackward>)
# train tensor(0.3652, grad_fn=<NllLossBackward>)
# train tensor(0.4382, grad_fn=<NllLossBackward>)
# train tensor(0.3154, grad_fn=<NllLossBackward>)
# train tensor(0.3639, grad_fn=<NllLossBackward>)
# train tensor(0.4768, grad_fn=<NllLossBackward>)
# train tensor(0.3535, grad_fn=<NllLossBackward>)
# train tensor(0.5247, grad_fn=<NllLossBackward>)
# train tensor(0.4685, grad_fn=<NllLossBackward>)
# train tensor(0.3285, grad_fn=<NllLossBackward>)
# train tensor(0.3026, grad_fn=<NllLossBackward>)
# train tensor(0.3306, grad_fn=<NllLossBackward>)
# train tensor(0.4790, grad_fn=<NllLossBackward>)
# ...
# train tensor(0.1745, grad_fn=<NllLossBackward>)
# train tensor(0.2289, grad_fn=<NllLossBackward>)
# train tensor(0.3927, grad_fn=<NllLossBackward>)
# train tensor(0.3434, grad_fn=<NllLossBackward>)
# train tensor(0.3994, grad_fn=<NllLossBackward>)
# train tensor(0.2095, grad_fn=<NllLossBackward>)
# train tensor(0.2494, grad_fn=<NllLossBackward>)
# train tensor(0.2750, grad_fn=<NllLossBackward>)
# train tensor(0.6993, grad_fn=<NllLossBackward>)
# train tensor(0.7610, grad_fn=<NllLossBackward>)
# train tensor(0.2870, grad_fn=<NllLossBackward>)
# train tensor(0.2601, grad_fn=<NllLossBackward>)
# train tensor(0.5471, grad_fn=<NllLossBackward>)
# train tensor(0.2565, grad_fn=<NllLossBackward>)
# train tensor(0.3121, grad_fn=<NllLossBackward>)
# train tensor(0.5057, grad_fn=<NllLossBackward>)
# train tensor(0.2935, grad_fn=<NllLossBackward>)
# train tensor(0.3782, grad_fn=<NllLossBackward>)
# train tensor(0.2307, grad_fn=<NllLossBackward>)
# train tensor(0.4054, grad_fn=<NllLossBackward>)
# train tensor(0.2726, grad_fn=<NllLossBackward>)
# train tensor(0.2535, grad_fn=<NllLossBackward>)
# train tensor(0.5434, grad_fn=<NllLossBackward>)
# train tensor(0.3472, grad_fn=<NllLossBackward>)
# train tensor(0.2269, grad_fn=<NllLossBackward>)
# train tensor(0.1349, grad_fn=<NllLossBackward>)
# train tensor(0.3512, grad_fn=<NllLossBackward>)
# train tensor(0.3724, grad_fn=<NllLossBackward>)
# train tensor(0.5236, grad_fn=<NllLossBackward>)
# train tensor(0.2722, grad_fn=<NllLossBackward>)
# train tensor(0.3107, grad_fn=<NllLossBackward>)
# train tensor(0.5860, grad_fn=<NllLossBackward>)
# train tensor(0.6598, grad_fn=<NllLossBackward>)
# train tensor(0.3312, grad_fn=<NllLossBackward>)
# train tensor(0.1189, grad_fn=<NllLossBackward>)
# train tensor(0.2959, grad_fn=<NllLossBackward>)
# train tensor(0.2289, grad_fn=<NllLossBackward>)
# train tensor(0.3207, grad_fn=<NllLossBackward>)
# train tensor(0.3752, grad_fn=<NllLossBackward>)
# train tensor(0.4422, grad_fn=<NllLossBackward>)
# train tensor(0.3405, grad_fn=<NllLossBackward>)
# train tensor(0.2248, grad_fn=<NllLossBackward>)
# train tensor(0.2311, grad_fn=<NllLossBackward>)
# train tensor(0.2079, grad_fn=<NllLossBackward>)
# train tensor(0.3052, grad_fn=<NllLossBackward>)
# train tensor(0.2897, grad_fn=<NllLossBackward>)
# train tensor(0.5555, grad_fn=<NllLossBackward>)
# train tensor(0.3164, grad_fn=<NllLossBackward>)
# train tensor(0.2751, grad_fn=<NllLossBackward>)
# train tensor(0.1746, grad_fn=<NllLossBackward>)
# train tensor(0.2844, grad_fn=<NllLossBackward>)
# train tensor(0.3176, grad_fn=<NllLossBackward>)
# train tensor(0.4078, grad_fn=<NllLossBackward>)
# train tensor(0.1664, grad_fn=<NllLossBackward>)
# train tensor(0.3545, grad_fn=<NllLossBackward>)
# train tensor(0.2213, grad_fn=<NllLossBackward>)
# train tensor(0.2098, grad_fn=<NllLossBackward>)
# train tensor(0.2703, grad_fn=<NllLossBackward>)
# train tensor(0.2441, grad_fn=<NllLossBackward>)
# train tensor(0.3656, grad_fn=<NllLossBackward>)
# train tensor(0.2759, grad_fn=<NllLossBackward>)
# train tensor(0.4569, grad_fn=<NllLossBackward>)
# train tensor(0.3747, grad_fn=<NllLossBackward>)
# train tensor(0.1590, grad_fn=<NllLossBackward>)
# train tensor(0.4645, grad_fn=<NllLossBackward>)
# train tensor(0.3462, grad_fn=<NllLossBackward>)
# train tensor(0.4611, grad_fn=<NllLossBackward>)
# train tensor(0.4130, grad_fn=<NllLossBackward>)
# train tensor(0.3105, grad_fn=<NllLossBackward>)
# train tensor(0.2742, grad_fn=<NllLossBackward>)
# train tensor(0.1867, grad_fn=<NllLossBackward>)
# train tensor(0.3160, grad_fn=<NllLossBackward>)
# train tensor(0.3247, grad_fn=<NllLossBackward>)
# train tensor(0.2206, grad_fn=<NllLossBackward>)
# train tensor(0.3438, grad_fn=<NllLossBackward>)
# train tensor(0.3206, grad_fn=<NllLossBackward>)
# train tensor(0.1996, grad_fn=<NllLossBackward>)
# train tensor(0.3573, grad_fn=<NllLossBackward>)
# train tensor(0.2858, grad_fn=<NllLossBackward>)
# train tensor(0.2949, grad_fn=<NllLossBackward>)
# train tensor(0.3523, grad_fn=<NllLossBackward>)
# train tensor(0.4450, grad_fn=<NllLossBackward>)
# train tensor(0.3718, grad_fn=<NllLossBackward>)
# train tensor(0.3956, grad_fn=<NllLossBackward>)
# train tensor(0.4062, grad_fn=<NllLossBackward>)
# train tensor(0.3008, grad_fn=<NllLossBackward>)
# train tensor(0.3562, grad_fn=<NllLossBackward>)
# train tensor(0.2884, grad_fn=<NllLossBackward>)
# train tensor(0.2094, grad_fn=<NllLossBackward>)
# train tensor(0.2626, grad_fn=<NllLossBackward>)
# train tensor(0.3063, grad_fn=<NllLossBackward>)
# train tensor(0.3972, grad_fn=<NllLossBackward>)
# train tensor(0.5212, grad_fn=<NllLossBackward>)
# train tensor(0.3644, grad_fn=<NllLossBackward>)
# train tensor(0.4504, grad_fn=<NllLossBackward>)
# train tensor(0.2580, grad_fn=<NllLossBackward>)
# train tensor(0.5929, grad_fn=<NllLossBackward>)
# train tensor(0.3806, grad_fn=<NllLossBackward>)
# train tensor(0.5213, grad_fn=<NllLossBackward>)
# train tensor(0.4094, grad_fn=<NllLossBackward>)
# train tensor(0.2239, grad_fn=<NllLossBackward>)
# train tensor(0.1309, grad_fn=<NllLossBackward>)
# train tensor(0.3121, grad_fn=<NllLossBackward>)
# train tensor(0.3838, grad_fn=<NllLossBackward>)
# train tensor(0.2906, grad_fn=<NllLossBackward>)
# train tensor(0.2649, grad_fn=<NllLossBackward>)
# train tensor(0.3638, grad_fn=<NllLossBackward>)
# train tensor(0.5742, grad_fn=<NllLossBackward>)
# train tensor(0.3441, grad_fn=<NllLossBackward>)
# train tensor(0.2075, grad_fn=<NllLossBackward>)
# train tensor(0.5174, grad_fn=<NllLossBackward>)
# train tensor(0.2082, grad_fn=<NllLossBackward>)
# train tensor(0.2308, grad_fn=<NllLossBackward>)
# train tensor(0.2970, grad_fn=<NllLossBackward>)
# train tensor(0.3900, grad_fn=<NllLossBackward>)
# train tensor(0.2624, grad_fn=<NllLossBackward>)
# train tensor(0.3922, grad_fn=<NllLossBackward>)
# train tensor(0.2417, grad_fn=<NllLossBackward>)
# train tensor(0.4922, grad_fn=<NllLossBackward>)
# train tensor(0.2316, grad_fn=<NllLossBackward>)
# train tensor(0.3294, grad_fn=<NllLossBackward>)
# train tensor(0.3645, grad_fn=<NllLossBackward>)
# train tensor(0.1989, grad_fn=<NllLossBackward>)
# train tensor(0.2898, grad_fn=<NllLossBackward>)
# train tensor(0.3449, grad_fn=<NllLossBackward>)
# train tensor(0.1964, grad_fn=<NllLossBackward>)
# train tensor(0.4932, grad_fn=<NllLossBackward>)
# train tensor(0.3668, grad_fn=<NllLossBackward>)
# train tensor(0.3333, grad_fn=<NllLossBackward>)
# train tensor(0.2544, grad_fn=<NllLossBackward>)
# train tensor(0.4565, grad_fn=<NllLossBackward>)
# train tensor(0.2360, grad_fn=<NllLossBackward>)
# train tensor(0.4093, grad_fn=<NllLossBackward>)
# train tensor(0.3551, grad_fn=<NllLossBackward>)
# train tensor(0.2391, grad_fn=<NllLossBackward>)
# train tensor(0.2003, grad_fn=<NllLossBackward>)
# train tensor(0.5439, grad_fn=<NllLossBackward>)
# train tensor(0.2982, grad_fn=<NllLossBackward>)
# train tensor(0.2281, grad_fn=<NllLossBackward>)
# train tensor(0.5129, grad_fn=<NllLossBackward>)
# train tensor(0.1600, grad_fn=<NllLossBackward>)
# train tensor(0.2680, grad_fn=<NllLossBackward>)
# train tensor(0.2824, grad_fn=<NllLossBackward>)
# train tensor(0.4175, grad_fn=<NllLossBackward>)
# train tensor(0.2927, grad_fn=<NllLossBackward>)
# train tensor(0.1298, grad_fn=<NllLossBackward>)
# train tensor(0.4011, grad_fn=<NllLossBackward>)
# train tensor(0.2576, grad_fn=<NllLossBackward>)
# train tensor(0.3572, grad_fn=<NllLossBackward>)
# train tensor(0.2151, grad_fn=<NllLossBackward>)
# train tensor(0.4114, grad_fn=<NllLossBackward>)
# train tensor(0.4346, grad_fn=<NllLossBackward>)
# train tensor(0.4705, grad_fn=<NllLossBackward>)
# train tensor(0.2622, grad_fn=<NllLossBackward>)
# train tensor(0.3441, grad_fn=<NllLossBackward>)
# train tensor(0.4193, grad_fn=<NllLossBackward>)
# train tensor(0.3966, grad_fn=<NllLossBackward>)
# train tensor(0.4747, grad_fn=<NllLossBackward>)
# train tensor(0.1490, grad_fn=<NllLossBackward>)
# train tensor(0.5268, grad_fn=<NllLossBackward>)
# train tensor(0.2099, grad_fn=<NllLossBackward>)
# train tensor(0.3314, grad_fn=<NllLossBackward>)
# train tensor(0.3000, grad_fn=<NllLossBackward>)
# train tensor(0.3254, grad_fn=<NllLossBackward>)
# train tensor(0.4221, grad_fn=<NllLossBackward>)
# train tensor(0.3642, grad_fn=<NllLossBackward>)
# train tensor(0.3697, grad_fn=<NllLossBackward>)
# train tensor(0.2978, grad_fn=<NllLossBackward>)
# train tensor(0.2295, grad_fn=<NllLossBackward>)
# train tensor(0.2290, grad_fn=<NllLossBackward>)
# train tensor(0.3433, grad_fn=<NllLossBackward>)
# train tensor(0.3897, grad_fn=<NllLossBackward>)
# train tensor(0.1978, grad_fn=<NllLossBackward>)
# train tensor(0.2726, grad_fn=<NllLossBackward>)
# train tensor(0.3370, grad_fn=<NllLossBackward>)
# train tensor(0.1561, grad_fn=<NllLossBackward>)
# train tensor(0.5244, grad_fn=<NllLossBackward>)
# train tensor(0.4463, grad_fn=<NllLossBackward>)
# train tensor(0.1989, grad_fn=<NllLossBackward>)
# train tensor(0.3346, grad_fn=<NllLossBackward>)
# train tensor(0.2538, grad_fn=<NllLossBackward>)
# train tensor(0.4060, grad_fn=<NllLossBackward>)
# train tensor(0.2774, grad_fn=<NllLossBackward>)
# train tensor(0.2620, grad_fn=<NllLossBackward>)
# train tensor(0.4040, grad_fn=<NllLossBackward>)
# train tensor(0.3126, grad_fn=<NllLossBackward>)
# train tensor(0.1764, grad_fn=<NllLossBackward>)
# train tensor(0.4744, grad_fn=<NllLossBackward>)
# train tensor(0.3457, grad_fn=<NllLossBackward>)
# train tensor(0.3846, grad_fn=<NllLossBackward>)
# train tensor(0.1254, grad_fn=<NllLossBackward>)
# train tensor(0.2420, grad_fn=<NllLossBackward>)
# train tensor(0.3198, grad_fn=<NllLossBackward>)
# train tensor(0.3661, grad_fn=<NllLossBackward>)
# train tensor(0.3811, grad_fn=<NllLossBackward>)
# train tensor(0.2545, grad_fn=<NllLossBackward>)
# train tensor(0.3208, grad_fn=<NllLossBackward>)
# train tensor(0.3911, grad_fn=<NllLossBackward>)
# train tensor(0.3517, grad_fn=<NllLossBackward>)
# train tensor(0.4053, grad_fn=<NllLossBackward>)
# train tensor(0.3626, grad_fn=<NllLossBackward>)
# train tensor(0.6007, grad_fn=<NllLossBackward>)
# train tensor(0.2587, grad_fn=<NllLossBackward>)
# train tensor(0.1934, grad_fn=<NllLossBackward>)
# train tensor(0.4001, grad_fn=<NllLossBackward>)
# train tensor(0.4650, grad_fn=<NllLossBackward>)
# train tensor(0.3457, grad_fn=<NllLossBackward>)
# train tensor(0.2379, grad_fn=<NllLossBackward>)
# train tensor(0.4037, grad_fn=<NllLossBackward>)
# train tensor(0.3112, grad_fn=<NllLossBackward>)
# train tensor(0.6552, grad_fn=<NllLossBackward>)
# train tensor(0.3939, grad_fn=<NllLossBackward>)
# train tensor(0.2114, grad_fn=<NllLossBackward>)
# train tensor(0.1941, grad_fn=<NllLossBackward>)
# train tensor(0.4012, grad_fn=<NllLossBackward>)
# train tensor(0.2804, grad_fn=<NllLossBackward>)
# train tensor(0.3630, grad_fn=<NllLossBackward>)
# train tensor(0.3192, grad_fn=<NllLossBackward>)
# train tensor(0.4052, grad_fn=<NllLossBackward>)
# train tensor(0.3058, grad_fn=<NllLossBackward>)
# train tensor(0.3010, grad_fn=<NllLossBackward>)
# train tensor(0.1736, grad_fn=<NllLossBackward>)
# train tensor(0.4922, grad_fn=<NllLossBackward>)
# train tensor(0.3323, grad_fn=<NllLossBackward>)
# train tensor(0.1523, grad_fn=<NllLossBackward>)
# train tensor(0.3039, grad_fn=<NllLossBackward>)
# train tensor(0.3542, grad_fn=<NllLossBackward>)
# train tensor(0.3043, grad_fn=<NllLossBackward>)
# train tensor(0.5479, grad_fn=<NllLossBackward>)
# train tensor(0.3409, grad_fn=<NllLossBackward>)
# train tensor(0.3622, grad_fn=<NllLossBackward>)
# train tensor(0.3236, grad_fn=<NllLossBackward>)
# train tensor(0.5586, grad_fn=<NllLossBackward>)
# train tensor(0.3610, grad_fn=<NllLossBackward>)
# train tensor(0.4022, grad_fn=<NllLossBackward>)
# train tensor(0.2222, grad_fn=<NllLossBackward>)
# train tensor(0.6620, grad_fn=<NllLossBackward>)
# train tensor(0.4573, grad_fn=<NllLossBackward>)
# train tensor(0.3289, grad_fn=<NllLossBackward>)
# train tensor(0.3434, grad_fn=<NllLossBackward>)
# train tensor(0.4176, grad_fn=<NllLossBackward>)
# train tensor(0.4752, grad_fn=<NllLossBackward>)
# train tensor(0.2564, grad_fn=<NllLossBackward>)
# train tensor(0.4550, grad_fn=<NllLossBackward>)
# train tensor(0.1106, grad_fn=<NllLossBackward>)
# train tensor(0.4179, grad_fn=<NllLossBackward>)
# train tensor(0.0632, grad_fn=<NllLossBackward>)
# train tensor(0.3178, grad_fn=<NllLossBackward>)
# train tensor(0.3815, grad_fn=<NllLossBackward>)
# train tensor(0.5520, grad_fn=<NllLossBackward>)
# train tensor(0.1997, grad_fn=<NllLossBackward>)
# train tensor(0.2630, grad_fn=<NllLossBackward>)
# train tensor(0.3675, grad_fn=<NllLossBackward>)
# train tensor(0.2535, grad_fn=<NllLossBackward>)
# train tensor(0.3384, grad_fn=<NllLossBackward>)
# train tensor(0.3534, grad_fn=<NllLossBackward>)
# train tensor(0.1839, grad_fn=<NllLossBackward>)
# train tensor(0.2714, grad_fn=<NllLossBackward>)
# train tensor(0.1734, grad_fn=<NllLossBackward>)
# train tensor(0.1372, grad_fn=<NllLossBackward>)
# train tensor(0.3068, grad_fn=<NllLossBackward>)
# train tensor(0.2049, grad_fn=<NllLossBackward>)
# train tensor(0.3103, grad_fn=<NllLossBackward>)
# train tensor(0.3646, grad_fn=<NllLossBackward>)
# train tensor(0.3697, grad_fn=<NllLossBackward>)
# train tensor(0.5237, grad_fn=<NllLossBackward>)
# train tensor(0.6607, grad_fn=<NllLossBackward>)
# tensor(0.2161, grad_fn=<AddBackward0>)
# tensor(0.6131, grad_fn=<AddBackward0>)
# tensor(1.0274, grad_fn=<AddBackward0>)
# tensor(1.4746, grad_fn=<AddBackward0>)
# tensor(1.9254, grad_fn=<AddBackward0>)
# tensor(2.2330, grad_fn=<AddBackward0>)
# tensor(2.4865, grad_fn=<AddBackward0>)
# tensor(2.7672, grad_fn=<AddBackward0>)
# tensor(2.9362, grad_fn=<AddBackward0>)
# tensor(3.3149, grad_fn=<AddBackward0>)
# tensor(3.6013, grad_fn=<AddBackward0>)
# tensor(3.7885, grad_fn=<AddBackward0>)
# tensor(4.0437, grad_fn=<AddBackward0>)
# tensor(4.2988, grad_fn=<AddBackward0>)
# tensor(4.5030, grad_fn=<AddBackward0>)
# tensor(4.8117, grad_fn=<AddBackward0>)
# tensor(5.4537, grad_fn=<AddBackward0>)
# tensor(5.7629, grad_fn=<AddBackward0>)
# tensor(5.9909, grad_fn=<AddBackward0>)
# tensor(6.1787, grad_fn=<AddBackward0>)
# tensor(6.4362, grad_fn=<AddBackward0>)
# tensor(6.8217, grad_fn=<AddBackward0>)
# tensor(7.3061, grad_fn=<AddBackward0>)
# tensor(7.6106, grad_fn=<AddBackward0>)
# tensor(7.9198, grad_fn=<AddBackward0>)
# tensor(8.1730, grad_fn=<AddBackward0>)
# tensor(8.3814, grad_fn=<AddBackward0>)
# tensor(8.7749, grad_fn=<AddBackward0>)
# tensor(9.0667, grad_fn=<AddBackward0>)
# tensor(9.2673, grad_fn=<AddBackward0>)
# tensor(9.6347, grad_fn=<AddBackward0>)
# tensor(10.1046, grad_fn=<AddBackward0>)
# tensor(10.3112, grad_fn=<AddBackward0>)
# tensor(10.5259, grad_fn=<AddBackward0>)
# tensor(10.7934, grad_fn=<AddBackward0>)
# tensor(11.0312, grad_fn=<AddBackward0>)
# tensor(11.1930, grad_fn=<AddBackward0>)
# tensor(11.4824, grad_fn=<AddBackward0>)
# tensor(12.0597, grad_fn=<AddBackward0>)
# tensor(12.3709, grad_fn=<AddBackward0>)
# tensor(12.5880, grad_fn=<AddBackward0>)
# tensor(12.8065, grad_fn=<AddBackward0>)
# tensor(13.1009, grad_fn=<AddBackward0>)
# tensor(13.2715, grad_fn=<AddBackward0>)
# tensor(13.5026, grad_fn=<AddBackward0>)
# tensor(13.7383, grad_fn=<AddBackward0>)
# tensor(13.9555, grad_fn=<AddBackward0>)
# tensor(14.1073, grad_fn=<AddBackward0>)
# tensor(14.4400, grad_fn=<AddBackward0>)
# tensor(14.7427, grad_fn=<AddBackward0>)
# tensor(15.0874, grad_fn=<AddBackward0>)
# tensor(15.3364, grad_fn=<AddBackward0>)
# tensor(15.5881, grad_fn=<AddBackward0>)
# tensor(15.8009, grad_fn=<AddBackward0>)
# tensor(15.9670, grad_fn=<AddBackward0>)
# tensor(16.1883, grad_fn=<AddBackward0>)
# tensor(16.4890, grad_fn=<AddBackward0>)
# tensor(16.7331, grad_fn=<AddBackward0>)
# tensor(17.0143, grad_fn=<AddBackward0>)
# tensor(17.3896, grad_fn=<AddBackward0>)
# tensor(17.6551, grad_fn=<AddBackward0>)
# tensor(17.8911, grad_fn=<AddBackward0>)
# tensor(18.1379, grad_fn=<AddBackward0>)
# tensor(18.2632, grad_fn=<AddBackward0>)
# tensor(18.3759, grad_fn=<AddBackward0>)
# tensor(18.5415, grad_fn=<AddBackward0>)
# tensor(18.6392, grad_fn=<AddBackward0>)
# tensor(18.8168, grad_fn=<AddBackward0>)
# tensor(18.9646, grad_fn=<AddBackward0>)
# tensor(19.0909, grad_fn=<AddBackward0>)
# tensor(19.1521, grad_fn=<AddBackward0>)
# tensor(19.2352, grad_fn=<AddBackward0>)
# tensor(19.5922, grad_fn=<AddBackward0>)
# tensor(19.9779, grad_fn=<AddBackward0>)
# tensor(20.0238, grad_fn=<AddBackward0>)
# tensor(20.3580, grad_fn=<AddBackward0>)
# tensor(20.6201, grad_fn=<AddBackward0>)
# tensor(20.8007, grad_fn=<AddBackward0>)
# tensor(20.8463, grad_fn=<AddBackward0>)
# Epoch 1: 0.264

# %% [markdown]
# # nn.Sequential

# %% [markdown]
# PyTorch provides a class `nn.Sequential` for simplifying the definition of modules that only consist of a stack of layers. Since these are exactly the models we have been using so far we will now switch to this interface.
#
# Because not all functions are defined as PyTorch layers we will start by defining a module that just converts a function to a layer.

# %%
class Lambda(nn.Module):
    def __init__(self, func):
        super().__init__()
        self.func = func

    def forward(self, x):
        return self.func(x)

# %% [markdown]
# We can now define our CNN in a more concise manner. Note that we now use `nn.AdaptiveAvgPool2d`, which allows us to specify the size of the output tensor instead of the input tensor.

# %%
model = nn.Sequential(
    Lambda(lambda x: x.view(-1, 1, 28, 28)),
    nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1),
    nn.ReLU(),
    nn.Conv2d(16, 16, kernel_size=3, stride=2, padding=1),
    nn.ReLU(),
    nn.Conv2d(16, 10, kernel_size=3, stride=2, padding=1),
    nn.ReLU(),
    nn.AdaptiveAvgPool2d(1),
    Lambda(lambda x: x.view(x.size(0), -1)),
)

# %%
model.apply(initialize_weight)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)

fit(model, optimizer, dataloaders, num_epochs=2)
# Out:
# train tensor(2.2946, grad_fn=<NllLossBackward>)
# train tensor(2.3127, grad_fn=<NllLossBackward>)
# train tensor(2.2982, grad_fn=<NllLossBackward>)
# train tensor(2.2975, grad_fn=<NllLossBackward>)
# train tensor(2.2987, grad_fn=<NllLossBackward>)
# train tensor(2.3090, grad_fn=<NllLossBackward>)
# train tensor(2.3168, grad_fn=<NllLossBackward>)
# train tensor(2.3077, grad_fn=<NllLossBackward>)
# train tensor(2.2877, grad_fn=<NllLossBackward>)
# train tensor(2.2883, grad_fn=<NllLossBackward>)
# train tensor(2.3172, grad_fn=<NllLossBackward>)
# train tensor(2.2921, grad_fn=<NllLossBackward>)
# train tensor(2.3081, grad_fn=<NllLossBackward>)
# train tensor(2.3109, grad_fn=<NllLossBackward>)
# train tensor(2.2922, grad_fn=<NllLossBackward>)
# train tensor(2.2849, grad_fn=<NllLossBackward>)
# train tensor(2.3011, grad_fn=<NllLossBackward>)
# train tensor(2.3000, grad_fn=<NllLossBackward>)
# train tensor(2.2824, grad_fn=<NllLossBackward>)
# train tensor(2.2774, grad_fn=<NllLossBackward>)
# train tensor(2.3034, grad_fn=<NllLossBackward>)
# train tensor(2.2760, grad_fn=<NllLossBackward>)
# train tensor(2.2681, grad_fn=<NllLossBackward>)
# train tensor(2.2859, grad_fn=<NllLossBackward>)
# train tensor(2.2908, grad_fn=<NllLossBackward>)
# train tensor(2.3496, grad_fn=<NllLossBackward>)
# train tensor(2.2815, grad_fn=<NllLossBackward>)
# train tensor(2.2719, grad_fn=<NllLossBackward>)
# train tensor(2.3177, grad_fn=<NllLossBackward>)
# train tensor(2.2930, grad_fn=<NllLossBackward>)
# train tensor(2.2631, grad_fn=<NllLossBackward>)
# train tensor(2.2682, grad_fn=<NllLossBackward>)
# train tensor(2.2915, grad_fn=<NllLossBackward>)
# train tensor(2.2879, grad_fn=<NllLossBackward>)
# train tensor(2.2729, grad_fn=<NllLossBackward>)
# train tensor(2.2441, grad_fn=<NllLossBackward>)
# train tensor(2.2607, grad_fn=<NllLossBackward>)
# train tensor(2.2497, grad_fn=<NllLossBackward>)
# train tensor(2.2909, grad_fn=<NllLossBackward>)
# train tensor(2.2666, grad_fn=<NllLossBackward>)
# train tensor(2.2875, grad_fn=<NllLossBackward>)
# train tensor(2.2364, grad_fn=<NllLossBackward>)
# train tensor(2.2511, grad_fn=<NllLossBackward>)
# train tensor(2.2258, grad_fn=<NllLossBackward>)
# train tensor(2.2311, grad_fn=<NllLossBackward>)
# train tensor(2.2736, grad_fn=<NllLossBackward>)
# train tensor(2.2030, grad_fn=<NllLossBackward>)
# train tensor(2.2333, grad_fn=<NllLossBackward>)
# train tensor(2.2504, grad_fn=<NllLossBackward>)
# train tensor(2.2128, grad_fn=<NllLossBackward>)
# train tensor(2.1624, grad_fn=<NllLossBackward>)
# train tensor(2.2339, grad_fn=<NllLossBackward>)
# train tensor(2.1606, grad_fn=<NllLossBackward>)
# train tensor(2.2138, grad_fn=<NllLossBackward>)
# train tensor(2.1340, grad_fn=<NllLossBackward>)
# train tensor(2.1442, grad_fn=<NllLossBackward>)
# train tensor(2.0732, grad_fn=<NllLossBackward>)
# train tensor(2.1219, grad_fn=<NllLossBackward>)
# train tensor(2.1343, grad_fn=<NllLossBackward>)
# train tensor(2.0197, grad_fn=<NllLossBackward>)
# train tensor(2.0223, grad_fn=<NllLossBackward>)
# train tensor(2.0827, grad_fn=<NllLossBackward>)
# train tensor(1.9425, grad_fn=<NllLossBackward>)
# train tensor(1.9763, grad_fn=<NllLossBackward>)
# train tensor(1.9472, grad_fn=<NllLossBackward>)
# train tensor(2.1033, grad_fn=<NllLossBackward>)
# train tensor(2.1062, grad_fn=<NllLossBackward>)
# train tensor(2.0663, grad_fn=<NllLossBackward>)
# train tensor(2.0291, grad_fn=<NllLossBackward>)
# train tensor(2.0704, grad_fn=<NllLossBackward>)
# train tensor(1.9964, grad_fn=<NllLossBackward>)
# train tensor(1.9510, grad_fn=<NllLossBackward>)
# train tensor(2.2612, grad_fn=<NllLossBackward>)
# train tensor(1.8387, grad_fn=<NllLossBackward>)
# train tensor(1.8441, grad_fn=<NllLossBackward>)
# train tensor(1.9756, grad_fn=<NllLossBackward>)
# train tensor(2.0099, grad_fn=<NllLossBackward>)
# train tensor(1.9538, grad_fn=<NllLossBackward>)
# train tensor(1.8975, grad_fn=<NllLossBackward>)
# train tensor(1.8636, grad_fn=<NllLossBackward>)
# train tensor(1.9988, grad_fn=<NllLossBackward>)
# train tensor(1.6379, grad_fn=<NllLossBackward>)
# train tensor(1.7535, grad_fn=<NllLossBackward>)
# train tensor(1.8590, grad_fn=<NllLossBackward>)
# train tensor(1.6409, grad_fn=<NllLossBackward>)
# train tensor(1.6972, grad_fn=<NllLossBackward>)
# train tensor(1.7881, grad_fn=<NllLossBackward>)
# train tensor(2.0571, grad_fn=<NllLossBackward>)
# train tensor(1.8909, grad_fn=<NllLossBackward>)
# train tensor(1.9741, grad_fn=<NllLossBackward>)
# train tensor(1.6770, grad_fn=<NllLossBackward>)
# train tensor(1.5725, grad_fn=<NllLossBackward>)
# train tensor(1.7328, grad_fn=<NllLossBackward>)
# train tensor(1.8074, grad_fn=<NllLossBackward>)
# train tensor(1.6584, grad_fn=<NllLossBackward>)
# train tensor(1.7976, grad_fn=<NllLossBackward>)
# train tensor(1.5254, grad_fn=<NllLossBackward>)
# train tensor(1.5253, grad_fn=<NllLossBackward>)
# train tensor(1.6981, grad_fn=<NllLossBackward>)
# train tensor(1.5049, grad_fn=<NllLossBackward>)
# train tensor(1.7182, grad_fn=<NllLossBackward>)
# train tensor(1.4119, grad_fn=<NllLossBackward>)
# train tensor(1.2927, grad_fn=<NllLossBackward>)
# train tensor(1.6249, grad_fn=<NllLossBackward>)
# train tensor(1.6440, grad_fn=<NllLossBackward>)
# train tensor(1.8009, grad_fn=<NllLossBackward>)
# train tensor(1.5319, grad_fn=<NllLossBackward>)
# train tensor(1.4660, grad_fn=<NllLossBackward>)
# train tensor(1.7644, grad_fn=<NllLossBackward>)
# train tensor(1.5774, grad_fn=<NllLossBackward>)
# train tensor(1.3680, grad_fn=<NllLossBackward>)
# train tensor(1.3704, grad_fn=<NllLossBackward>)
# train tensor(1.2729, grad_fn=<NllLossBackward>)
# train tensor(1.6785, grad_fn=<NllLossBackward>)
# train tensor(1.3447, grad_fn=<NllLossBackward>)
# train tensor(1.5620, grad_fn=<NllLossBackward>)
# train tensor(1.5699, grad_fn=<NllLossBackward>)
# train tensor(1.2822, grad_fn=<NllLossBackward>)
# train tensor(1.3659, grad_fn=<NllLossBackward>)
# train tensor(1.4222, grad_fn=<NllLossBackward>)
# train tensor(1.2949, grad_fn=<NllLossBackward>)
# train tensor(1.5901, grad_fn=<NllLossBackward>)
# train tensor(1.1612, grad_fn=<NllLossBackward>)
# train tensor(1.2422, grad_fn=<NllLossBackward>)
# train tensor(1.2886, grad_fn=<NllLossBackward>)
# train tensor(1.7718, grad_fn=<NllLossBackward>)
# train tensor(1.3329, grad_fn=<NllLossBackward>)
# train tensor(1.2554, grad_fn=<NllLossBackward>)
# train tensor(1.3495, grad_fn=<NllLossBackward>)
# train tensor(1.4083, grad_fn=<NllLossBackward>)
# train tensor(1.4620, grad_fn=<NllLossBackward>)
# train tensor(1.0199, grad_fn=<NllLossBackward>)
# train tensor(1.1647, grad_fn=<NllLossBackward>)
# train tensor(1.1302, grad_fn=<NllLossBackward>)
# train tensor(1.2395, grad_fn=<NllLossBackward>)
# train tensor(1.4263, grad_fn=<NllLossBackward>)
# train tensor(1.2542, grad_fn=<NllLossBackward>)
# train tensor(1.2142, grad_fn=<NllLossBackward>)
# train tensor(1.2326, grad_fn=<NllLossBackward>)
# train tensor(1.2466, grad_fn=<NllLossBackward>)
# train tensor(1.2083, grad_fn=<NllLossBackward>)
# train tensor(1.1346, grad_fn=<NllLossBackward>)
# train tensor(1.0185, grad_fn=<NllLossBackward>)
# train tensor(1.1432, grad_fn=<NllLossBackward>)
# train tensor(1.2856, grad_fn=<NllLossBackward>)
# train tensor(1.0495, grad_fn=<NllLossBackward>)
# train tensor(1.0767, grad_fn=<NllLossBackward>)
# train tensor(1.1234, grad_fn=<NllLossBackward>)
# train tensor(1.0954, grad_fn=<NllLossBackward>)
# train tensor(0.9145, grad_fn=<NllLossBackward>)
# train tensor(0.9158, grad_fn=<NllLossBackward>)
# train tensor(0.9259, grad_fn=<NllLossBackward>)
# train tensor(0.9955, grad_fn=<NllLossBackward>)
# train tensor(1.1292, grad_fn=<NllLossBackward>)
# train tensor(1.1639, grad_fn=<NllLossBackward>)
# train tensor(1.0696, grad_fn=<NllLossBackward>)
# train tensor(1.1498, grad_fn=<NllLossBackward>)
# train tensor(1.2011, grad_fn=<NllLossBackward>)
# train tensor(1.1205, grad_fn=<NllLossBackward>)
# train tensor(1.5401, grad_fn=<NllLossBackward>)
# train tensor(1.0469, grad_fn=<NllLossBackward>)
# train tensor(0.9602, grad_fn=<NllLossBackward>)
# train tensor(1.0550, grad_fn=<NllLossBackward>)
# train tensor(1.2077, grad_fn=<NllLossBackward>)
# train tensor(1.3386, grad_fn=<NllLossBackward>)
# train tensor(1.1024, grad_fn=<NllLossBackward>)
# train tensor(1.2274, grad_fn=<NllLossBackward>)
# train tensor(1.1878, grad_fn=<NllLossBackward>)
# train tensor(1.1709, grad_fn=<NllLossBackward>)
# train tensor(1.2587, grad_fn=<NllLossBackward>)
# train tensor(1.0813, grad_fn=<NllLossBackward>)
# train tensor(1.1259, grad_fn=<NllLossBackward>)
# train tensor(0.9569, grad_fn=<NllLossBackward>)
# train tensor(1.1923, grad_fn=<NllLossBackward>)
# train tensor(1.0372, grad_fn=<NllLossBackward>)
# train tensor(0.8507, grad_fn=<NllLossBackward>)
# train tensor(0.9249, grad_fn=<NllLossBackward>)
# train tensor(1.1402, grad_fn=<NllLossBackward>)
# train tensor(0.9375, grad_fn=<NllLossBackward>)
# train tensor(0.8200, grad_fn=<NllLossBackward>)
# train tensor(0.9212, grad_fn=<NllLossBackward>)
# train tensor(0.8654, grad_fn=<NllLossBackward>)
# train tensor(0.8963, grad_fn=<NllLossBackward>)
# train tensor(0.7924, grad_fn=<NllLossBackward>)
# train tensor(0.8569, grad_fn=<NllLossBackward>)
# train tensor(1.1207, grad_fn=<NllLossBackward>)
# train tensor(0.8853, grad_fn=<NllLossBackward>)
# train tensor(0.7986, grad_fn=<NllLossBackward>)
# train tensor(0.9721, grad_fn=<NllLossBackward>)
# train tensor(0.9392, grad_fn=<NllLossBackward>)
# train tensor(0.8448, grad_fn=<NllLossBackward>)
# train tensor(0.9993, grad_fn=<NllLossBackward>)
# train tensor(1.0942, grad_fn=<NllLossBackward>)
# train tensor(0.7570, grad_fn=<NllLossBackward>)
# train tensor(0.7655, grad_fn=<NllLossBackward>)
# train tensor(0.9027, grad_fn=<NllLossBackward>)
# train tensor(1.3236, grad_fn=<NllLossBackward>)
# train tensor(0.7668, grad_fn=<NllLossBackward>)
# train tensor(0.8189, grad_fn=<NllLossBackward>)
# train tensor(0.8935, grad_fn=<NllLossBackward>)
# train tensor(1.0125, grad_fn=<NllLossBackward>)
# train tensor(0.6419, grad_fn=<NllLossBackward>)
# train tensor(0.7580, grad_fn=<NllLossBackward>)
# train tensor(1.0119, grad_fn=<NllLossBackward>)
# train tensor(1.2307, grad_fn=<NllLossBackward>)
# train tensor(1.0742, grad_fn=<NllLossBackward>)
# train tensor(0.8977, grad_fn=<NllLossBackward>)
# train tensor(0.8186, grad_fn=<NllLossBackward>)
# train tensor(0.6342, grad_fn=<NllLossBackward>)
# train tensor(1.0412, grad_fn=<NllLossBackward>)
# train tensor(0.8119, grad_fn=<NllLossBackward>)
# train tensor(0.9354, grad_fn=<NllLossBackward>)
# train tensor(0.7243, grad_fn=<NllLossBackward>)
# train tensor(0.8459, grad_fn=<NllLossBackward>)
# train tensor(1.0132, grad_fn=<NllLossBackward>)
# train tensor(0.8759, grad_fn=<NllLossBackward>)
# train tensor(0.8379, grad_fn=<NllLossBackward>)
# train tensor(0.6985, grad_fn=<NllLossBackward>)
# train tensor(0.9882, grad_fn=<NllLossBackward>)
# train tensor(1.1748, grad_fn=<NllLossBackward>)
# train tensor(0.5948, grad_fn=<NllLossBackward>)
# train tensor(1.0480, grad_fn=<NllLossBackward>)
# train tensor(0.9766, grad_fn=<NllLossBackward>)
# train tensor(0.5432, grad_fn=<NllLossBackward>)
# train tensor(0.7365, grad_fn=<NllLossBackward>)
# train tensor(0.9110, grad_fn=<NllLossBackward>)
# train tensor(0.8924, grad_fn=<NllLossBackward>)
# train tensor(0.8783, grad_fn=<NllLossBackward>)
# train tensor(0.5837, grad_fn=<NllLossBackward>)
# train tensor(0.8670, grad_fn=<NllLossBackward>)
# train tensor(0.6447, grad_fn=<NllLossBackward>)
# train tensor(0.8199, grad_fn=<NllLossBackward>)
# train tensor(0.7980, grad_fn=<NllLossBackward>)
# train tensor(0.7475, grad_fn=<NllLossBackward>)
# train tensor(0.8561, grad_fn=<NllLossBackward>)
# train tensor(1.0253, grad_fn=<NllLossBackward>)
# train tensor(0.6142, grad_fn=<NllLossBackward>)
# train tensor(0.6899, grad_fn=<NllLossBackward>)
# train tensor(0.7859, grad_fn=<NllLossBackward>)
# train tensor(0.6110, grad_fn=<NllLossBackward>)
# train tensor(0.7418, grad_fn=<NllLossBackward>)
# train tensor(0.8789, grad_fn=<NllLossBackward>)
# train tensor(0.6976, grad_fn=<NllLossBackward>)
# train tensor(0.6310, grad_fn=<NllLossBackward>)
# train tensor(0.9776, grad_fn=<NllLossBackward>)
# train tensor(0.9793, grad_fn=<NllLossBackward>)
# train tensor(0.8479, grad_fn=<NllLossBackward>)
# train tensor(0.7279, grad_fn=<NllLossBackward>)
# train tensor(0.6767, grad_fn=<NllLossBackward>)
# train tensor(0.9440, grad_fn=<NllLossBackward>)
# train tensor(0.7134, grad_fn=<NllLossBackward>)
# train tensor(0.9116, grad_fn=<NllLossBackward>)
# train tensor(0.9045, grad_fn=<NllLossBackward>)
# train tensor(0.6402, grad_fn=<NllLossBackward>)
# train tensor(0.7450, grad_fn=<NllLossBackward>)
# train tensor(0.9252, grad_fn=<NllLossBackward>)
# train tensor(0.6892, grad_fn=<NllLossBackward>)
# train tensor(0.7329, grad_fn=<NllLossBackward>)
# train tensor(0.5453, grad_fn=<NllLossBackward>)
# train tensor(1.0178, grad_fn=<NllLossBackward>)
# train tensor(0.5830, grad_fn=<NllLossBackward>)
# train tensor(0.6867, grad_fn=<NllLossBackward>)
# train tensor(0.7639, grad_fn=<NllLossBackward>)
# train tensor(0.7422, grad_fn=<NllLossBackward>)
# train tensor(0.6383, grad_fn=<NllLossBackward>)
# train tensor(0.6050, grad_fn=<NllLossBackward>)
# train tensor(0.6328, grad_fn=<NllLossBackward>)
# train tensor(0.5664, grad_fn=<NllLossBackward>)
# train tensor(0.7267, grad_fn=<NllLossBackward>)
# train tensor(0.8325, grad_fn=<NllLossBackward>)
# train tensor(0.4687, grad_fn=<NllLossBackward>)
# train tensor(0.5692, grad_fn=<NllLossBackward>)
# train tensor(0.8112, grad_fn=<NllLossBackward>)
# train tensor(0.7193, grad_fn=<NllLossBackward>)
# train tensor(0.6127, grad_fn=<NllLossBackward>)
# train tensor(0.9797, grad_fn=<NllLossBackward>)
# train tensor(0.5033, grad_fn=<NllLossBackward>)
# train tensor(0.6402, grad_fn=<NllLossBackward>)
# train tensor(1.0762, grad_fn=<NllLossBackward>)
# train tensor(0.7902, grad_fn=<NllLossBackward>)
# train tensor(0.8616, grad_fn=<NllLossBackward>)
# train tensor(0.8651, grad_fn=<NllLossBackward>)
# train tensor(0.5044, grad_fn=<NllLossBackward>)
# train tensor(0.9465, grad_fn=<NllLossBackward>)
# train tensor(0.7967, grad_fn=<NllLossBackward>)
# train tensor(0.6959, grad_fn=<NllLossBackward>)
# train tensor(0.6629, grad_fn=<NllLossBackward>)
# train tensor(0.9238, grad_fn=<NllLossBackward>)
# train tensor(0.6755, grad_fn=<NllLossBackward>)
# train tensor(0.5141, grad_fn=<NllLossBackward>)
# train tensor(0.6392, grad_fn=<NllLossBackward>)
# train tensor(0.6109, grad_fn=<NllLossBackward>)
# train tensor(0.6106, grad_fn=<NllLossBackward>)
# train tensor(0.7849, grad_fn=<NllLossBackward>)
# train tensor(0.5784, grad_fn=<NllLossBackward>)
# train tensor(1.0227, grad_fn=<NllLossBackward>)
# train tensor(0.5136, grad_fn=<NllLossBackward>)
# train tensor(0.8102, grad_fn=<NllLossBackward>)
# train tensor(0.7610, grad_fn=<NllLossBackward>)
# train tensor(0.6994, grad_fn=<NllLossBackward>)
# train tensor(0.6245, grad_fn=<NllLossBackward>)
# train tensor(0.6884, grad_fn=<NllLossBackward>)
# train tensor(0.7993, grad_fn=<NllLossBackward>)
# train tensor(0.6372, grad_fn=<NllLossBackward>)
# train tensor(0.5744, grad_fn=<NllLossBackward>)
# train tensor(0.6907, grad_fn=<NllLossBackward>)
# train tensor(0.5156, grad_fn=<NllLossBackward>)
# train tensor(0.5855, grad_fn=<NllLossBackward>)
# train tensor(0.5588, grad_fn=<NllLossBackward>)
# train tensor(0.8175, grad_fn=<NllLossBackward>)
# train tensor(0.9781, grad_fn=<NllLossBackward>)
# train tensor(0.7645, grad_fn=<NllLossBackward>)
# train tensor(0.7158, grad_fn=<NllLossBackward>)
# train tensor(0.6104, grad_fn=<NllLossBackward>)
# train tensor(0.8769, grad_fn=<NllLossBackward>)
# train tensor(0.7571, grad_fn=<NllLossBackward>)
# train tensor(0.5965, grad_fn=<NllLossBackward>)
# train tensor(0.8502, grad_fn=<NllLossBackward>)
# train tensor(0.7674, grad_fn=<NllLossBackward>)
# train tensor(0.7653, grad_fn=<NllLossBackward>)
# train tensor(0.5484, grad_fn=<NllLossBackward>)
# train tensor(0.6947, grad_fn=<NllLossBackward>)
# train tensor(0.7709, grad_fn=<NllLossBackward>)
# train tensor(0.6538, grad_fn=<NllLossBackward>)
# train tensor(0.5012, grad_fn=<NllLossBackward>)
# train tensor(0.8513, grad_fn=<NllLossBackward>)
# train tensor(0.6578, grad_fn=<NllLossBackward>)
# train tensor(0.4125, grad_fn=<NllLossBackward>)
# train tensor(0.5360, grad_fn=<NllLossBackward>)
# train tensor(0.5992, grad_fn=<NllLossBackward>)
# train tensor(0.5552, grad_fn=<NllLossBackward>)
# train tensor(0.6260, grad_fn=<NllLossBackward>)
# train tensor(0.4448, grad_fn=<NllLossBackward>)
# train tensor(0.7616, grad_fn=<NllLossBackward>)
# train tensor(0.6163, grad_fn=<NllLossBackward>)
# train tensor(0.6462, grad_fn=<NllLossBackward>)
# train tensor(0.6672, grad_fn=<NllLossBackward>)
# train tensor(0.5689, grad_fn=<NllLossBackward>)
# train tensor(0.4434, grad_fn=<NllLossBackward>)
# train tensor(0.5239, grad_fn=<NllLossBackward>)
# train tensor(0.4185, grad_fn=<NllLossBackward>)
# train tensor(0.8474, grad_fn=<NllLossBackward>)
# train tensor(0.8054, grad_fn=<NllLossBackward>)
# train tensor(0.6684, grad_fn=<NllLossBackward>)
# train tensor(0.8464, grad_fn=<NllLossBackward>)
# train tensor(0.5889, grad_fn=<NllLossBackward>)
# train tensor(0.6458, grad_fn=<NllLossBackward>)
# train tensor(0.4854, grad_fn=<NllLossBackward>)
# train tensor(0.8312, grad_fn=<NllLossBackward>)
# train tensor(0.6775, grad_fn=<NllLossBackward>)
# train tensor(0.6052, grad_fn=<NllLossBackward>)
# train tensor(0.6226, grad_fn=<NllLossBackward>)
# train tensor(0.6599, grad_fn=<NllLossBackward>)
# train tensor(0.5857, grad_fn=<NllLossBackward>)
# train tensor(0.9219, grad_fn=<NllLossBackward>)
# train tensor(0.8427, grad_fn=<NllLossBackward>)
# train tensor(0.8025, grad_fn=<NllLossBackward>)
# train tensor(0.6512, grad_fn=<NllLossBackward>)
# train tensor(0.7924, grad_fn=<NllLossBackward>)
# train tensor(0.5042, grad_fn=<NllLossBackward>)
# train tensor(0.4144, grad_fn=<NllLossBackward>)
# train tensor(0.6349, grad_fn=<NllLossBackward>)
# train tensor(0.5475, grad_fn=<NllLossBackward>)
# train tensor(0.5088, grad_fn=<NllLossBackward>)
# train tensor(0.6624, grad_fn=<NllLossBackward>)
# train tensor(0.5837, grad_fn=<NllLossBackward>)
# train tensor(0.6093, grad_fn=<NllLossBackward>)
# train tensor(0.5778, grad_fn=<NllLossBackward>)
# train tensor(0.7390, grad_fn=<NllLossBackward>)
# train tensor(0.4344, grad_fn=<NllLossBackward>)
# train tensor(0.7941, grad_fn=<NllLossBackward>)
# train tensor(0.3189, grad_fn=<NllLossBackward>)
# train tensor(0.7287, grad_fn=<NllLossBackward>)
# train tensor(0.5675, grad_fn=<NllLossBackward>)
# train tensor(0.5543, grad_fn=<NllLossBackward>)
# train tensor(0.7630, grad_fn=<NllLossBackward>)
# train tensor(0.7722, grad_fn=<NllLossBackward>)
# train tensor(0.7152, grad_fn=<NllLossBackward>)
# train tensor(0.5082, grad_fn=<NllLossBackward>)
# train tensor(1.1077, grad_fn=<NllLossBackward>)
# train tensor(0.3955, grad_fn=<NllLossBackward>)
# train tensor(0.9753, grad_fn=<NllLossBackward>)
# train tensor(0.6706, grad_fn=<NllLossBackward>)
# train tensor(0.4085, grad_fn=<NllLossBackward>)
# train tensor(0.8587, grad_fn=<NllLossBackward>)
# train tensor(0.9803, grad_fn=<NllLossBackward>)
# train tensor(0.5193, grad_fn=<NllLossBackward>)
# train tensor(0.8456, grad_fn=<NllLossBackward>)
# train tensor(0.7739, grad_fn=<NllLossBackward>)
# train tensor(0.5583, grad_fn=<NllLossBackward>)
# train tensor(0.4377, grad_fn=<NllLossBackward>)
# train tensor(0.6122, grad_fn=<NllLossBackward>)
# train tensor(0.6015, grad_fn=<NllLossBackward>)
# train tensor(0.5088, grad_fn=<NllLossBackward>)
# train tensor(0.3995, grad_fn=<NllLossBackward>)
# train tensor(0.5049, grad_fn=<NllLossBackward>)
# train tensor(0.5814, grad_fn=<NllLossBackward>)
# train tensor(0.4946, grad_fn=<NllLossBackward>)
# train tensor(0.6222, grad_fn=<NllLossBackward>)
# train tensor(0.7196, grad_fn=<NllLossBackward>)
# train tensor(0.5393, grad_fn=<NllLossBackward>)
# train tensor(0.6036, grad_fn=<NllLossBackward>)
# train tensor(0.7380, grad_fn=<NllLossBackward>)
# train tensor(0.6650, grad_fn=<NllLossBackward>)
# train tensor(0.5616, grad_fn=<NllLossBackward>)
# train tensor(0.6229, grad_fn=<NllLossBackward>)
# train tensor(0.8123, grad_fn=<NllLossBackward>)
# train tensor(0.4645, grad_fn=<NllLossBackward>)
# train tensor(0.8262, grad_fn=<NllLossBackward>)
# train tensor(0.4290, grad_fn=<NllLossBackward>)
# train tensor(0.5929, grad_fn=<NllLossBackward>)
# train tensor(0.3551, grad_fn=<NllLossBackward>)
# train tensor(0.5994, grad_fn=<NllLossBackward>)
# train tensor(0.4572, grad_fn=<NllLossBackward>)
# train tensor(0.6023, grad_fn=<NllLossBackward>)
# train tensor(0.4561, grad_fn=<NllLossBackward>)
# train tensor(0.5342, grad_fn=<NllLossBackward>)
# train tensor(0.5655, grad_fn=<NllLossBackward>)
# train tensor(0.3977, grad_fn=<NllLossBackward>)
# train tensor(0.6215, grad_fn=<NllLossBackward>)
# train tensor(0.3010, grad_fn=<NllLossBackward>)
# train tensor(0.4823, grad_fn=<NllLossBackward>)
# train tensor(0.5357, grad_fn=<NllLossBackward>)
# train tensor(0.3767, grad_fn=<NllLossBackward>)
# train tensor(0.6414, grad_fn=<NllLossBackward>)
# train tensor(0.4706, grad_fn=<NllLossBackward>)
# train tensor(1.0916, grad_fn=<NllLossBackward>)
# train tensor(0.5181, grad_fn=<NllLossBackward>)
# train tensor(0.5150, grad_fn=<NllLossBackward>)
# train tensor(0.3686, grad_fn=<NllLossBackward>)
# train tensor(0.3441, grad_fn=<NllLossBackward>)
# train tensor(0.4204, grad_fn=<NllLossBackward>)
# train tensor(0.4783, grad_fn=<NllLossBackward>)
# train tensor(0.7047, grad_fn=<NllLossBackward>)
# train tensor(0.5971, grad_fn=<NllLossBackward>)
# train tensor(0.4762, grad_fn=<NllLossBackward>)
# train tensor(0.4808, grad_fn=<NllLossBackward>)
# train tensor(0.6810, grad_fn=<NllLossBackward>)
# train tensor(0.5012, grad_fn=<NllLossBackward>)
# train tensor(0.4834, grad_fn=<NllLossBackward>)
# train tensor(0.4376, grad_fn=<NllLossBackward>)
# train tensor(0.4401, grad_fn=<NllLossBackward>)
# train tensor(0.7389, grad_fn=<NllLossBackward>)
# train tensor(0.4699, grad_fn=<NllLossBackward>)
# train tensor(0.7701, grad_fn=<NllLossBackward>)
# train tensor(0.4129, grad_fn=<NllLossBackward>)
# train tensor(0.6970, grad_fn=<NllLossBackward>)
# train tensor(0.4340, grad_fn=<NllLossBackward>)
# train tensor(0.3996, grad_fn=<NllLossBackward>)
# train tensor(0.5212, grad_fn=<NllLossBackward>)
# train tensor(0.2798, grad_fn=<NllLossBackward>)
# train tensor(0.4999, grad_fn=<NllLossBackward>)
# train tensor(0.5180, grad_fn=<NllLossBackward>)
# train tensor(0.3243, grad_fn=<NllLossBackward>)
# train tensor(0.4363, grad_fn=<NllLossBackward>)
# train tensor(0.5670, grad_fn=<NllLossBackward>)
# train tensor(0.4720, grad_fn=<NllLossBackward>)
# train tensor(0.4456, grad_fn=<NllLossBackward>)
# train tensor(0.6926, grad_fn=<NllLossBackward>)
# train tensor(0.6743, grad_fn=<NllLossBackward>)
# train tensor(0.3614, grad_fn=<NllLossBackward>)
# train tensor(0.4850, grad_fn=<NllLossBackward>)
# train tensor(0.4866, grad_fn=<NllLossBackward>)
# train tensor(0.5753, grad_fn=<NllLossBackward>)
# train tensor(0.3196, grad_fn=<NllLossBackward>)
# train tensor(0.3530, grad_fn=<NllLossBackward>)
# train tensor(0.7775, grad_fn=<NllLossBackward>)
# train tensor(0.3030, grad_fn=<NllLossBackward>)
# train tensor(0.6692, grad_fn=<NllLossBackward>)
# train tensor(0.3564, grad_fn=<NllLossBackward>)
# train tensor(0.4379, grad_fn=<NllLossBackward>)
# train tensor(0.4571, grad_fn=<NllLossBackward>)
# train tensor(0.4555, grad_fn=<NllLossBackward>)
# train tensor(0.7591, grad_fn=<NllLossBackward>)
# train tensor(0.5124, grad_fn=<NllLossBackward>)
# train tensor(0.6315, grad_fn=<NllLossBackward>)
# train tensor(0.5393, grad_fn=<NllLossBackward>)
# train tensor(0.4198, grad_fn=<NllLossBackward>)
# train tensor(0.6302, grad_fn=<NllLossBackward>)
# train tensor(0.5139, grad_fn=<NllLossBackward>)
# train tensor(0.3869, grad_fn=<NllLossBackward>)
# train tensor(0.5525, grad_fn=<NllLossBackward>)
# train tensor(0.3992, grad_fn=<NllLossBackward>)
# train tensor(0.5112, grad_fn=<NllLossBackward>)
# train tensor(0.5524, grad_fn=<NllLossBackward>)
# train tensor(0.4883, grad_fn=<NllLossBackward>)
# train tensor(0.3919, grad_fn=<NllLossBackward>)
# train tensor(0.4169, grad_fn=<NllLossBackward>)
# train tensor(0.4485, grad_fn=<NllLossBackward>)
# train tensor(0.4599, grad_fn=<NllLossBackward>)
# train tensor(0.5507, grad_fn=<NllLossBackward>)
# train tensor(0.5256, grad_fn=<NllLossBackward>)
# train tensor(0.5005, grad_fn=<NllLossBackward>)
# train tensor(0.6214, grad_fn=<NllLossBackward>)
# train tensor(0.7764, grad_fn=<NllLossBackward>)
# train tensor(0.2337, grad_fn=<NllLossBackward>)
# train tensor(0.4829, grad_fn=<NllLossBackward>)
# train tensor(0.4808, grad_fn=<NllLossBackward>)
# train tensor(0.4866, grad_fn=<NllLossBackward>)
# train tensor(0.4338, grad_fn=<NllLossBackward>)
# train tensor(0.2420, grad_fn=<NllLossBackward>)
# train tensor(0.3992, grad_fn=<NllLossBackward>)
# train tensor(0.8926, grad_fn=<NllLossBackward>)
# train tensor(0.3659, grad_fn=<NllLossBackward>)
# train tensor(0.3405, grad_fn=<NllLossBackward>)
# train tensor(0.4701, grad_fn=<NllLossBackward>)
# train tensor(0.4473, grad_fn=<NllLossBackward>)
# train tensor(0.3628, grad_fn=<NllLossBackward>)
# train tensor(0.5109, grad_fn=<NllLossBackward>)
# train tensor(0.4233, grad_fn=<NllLossBackward>)
# train tensor(0.2961, grad_fn=<NllLossBackward>)
# train tensor(0.5611, grad_fn=<NllLossBackward>)
# train tensor(0.3003, grad_fn=<NllLossBackward>)
# train tensor(0.4935, grad_fn=<NllLossBackward>)
# train tensor(0.4375, grad_fn=<NllLossBackward>)
# train tensor(0.5161, grad_fn=<NllLossBackward>)
# train tensor(0.4389, grad_fn=<NllLossBackward>)
# train tensor(0.2913, grad_fn=<NllLossBackward>)
# train tensor(0.6725, grad_fn=<NllLossBackward>)
# train tensor(0.2833, grad_fn=<NllLossBackward>)
# train tensor(0.3780, grad_fn=<NllLossBackward>)
# train tensor(0.5322, grad_fn=<NllLossBackward>)
# train tensor(0.4586, grad_fn=<NllLossBackward>)
# train tensor(0.5035, grad_fn=<NllLossBackward>)
# train tensor(0.6980, grad_fn=<NllLossBackward>)
# train tensor(0.4429, grad_fn=<NllLossBackward>)
# train tensor(0.3858, grad_fn=<NllLossBackward>)
# train tensor(0.7988, grad_fn=<NllLossBackward>)
# train tensor(0.5509, grad_fn=<NllLossBackward>)
# train tensor(0.6083, grad_fn=<NllLossBackward>)
# train tensor(0.3841, grad_fn=<NllLossBackward>)
# train tensor(0.6257, grad_fn=<NllLossBackward>)
# train tensor(0.7414, grad_fn=<NllLossBackward>)
# train tensor(0.3720, grad_fn=<NllLossBackward>)
# train tensor(0.3872, grad_fn=<NllLossBackward>)
# train tensor(0.4049, grad_fn=<NllLossBackward>)
# train tensor(0.5233, grad_fn=<NllLossBackward>)
# train tensor(0.3750, grad_fn=<NllLossBackward>)
# train tensor(0.4498, grad_fn=<NllLossBackward>)
# train tensor(0.5045, grad_fn=<NllLossBackward>)
# train tensor(0.4052, grad_fn=<NllLossBackward>)
# train tensor(0.4588, grad_fn=<NllLossBackward>)
# train tensor(0.5864, grad_fn=<NllLossBackward>)
# train tensor(0.7251, grad_fn=<NllLossBackward>)
# train tensor(0.4377, grad_fn=<NllLossBackward>)
# train tensor(0.5230, grad_fn=<NllLossBackward>)
# train tensor(0.3723, grad_fn=<NllLossBackward>)
# train tensor(0.4793, grad_fn=<NllLossBackward>)
# train tensor(0.7271, grad_fn=<NllLossBackward>)
# train tensor(0.2464, grad_fn=<NllLossBackward>)
# train tensor(0.2584, grad_fn=<NllLossBackward>)
# train tensor(0.6751, grad_fn=<NllLossBackward>)
# train tensor(0.5660, grad_fn=<NllLossBackward>)
# train tensor(0.4153, grad_fn=<NllLossBackward>)
# train tensor(0.4636, grad_fn=<NllLossBackward>)
# train tensor(0.4986, grad_fn=<NllLossBackward>)
# train tensor(0.3829, grad_fn=<NllLossBackward>)
# train tensor(0.5944, grad_fn=<NllLossBackward>)
# train tensor(0.4142, grad_fn=<NllLossBackward>)
# train tensor(0.5173, grad_fn=<NllLossBackward>)
# train tensor(0.5570, grad_fn=<NllLossBackward>)
# train tensor(0.7025, grad_fn=<NllLossBackward>)
# train tensor(0.6598, grad_fn=<NllLossBackward>)
# train tensor(0.3696, grad_fn=<NllLossBackward>)
# train tensor(0.4390, grad_fn=<NllLossBackward>)
# train tensor(0.4030, grad_fn=<NllLossBackward>)
# train tensor(0.4873, grad_fn=<NllLossBackward>)
# train tensor(0.5401, grad_fn=<NllLossBackward>)
# train tensor(0.5200, grad_fn=<NllLossBackward>)
# train tensor(0.4841, grad_fn=<NllLossBackward>)
# train tensor(0.4151, grad_fn=<NllLossBackward>)
# train tensor(0.4178, grad_fn=<NllLossBackward>)
# train tensor(0.4234, grad_fn=<NllLossBackward>)
# train tensor(0.2201, grad_fn=<NllLossBackward>)
# train tensor(0.5861, grad_fn=<NllLossBackward>)
# train tensor(0.2790, grad_fn=<NllLossBackward>)
# train tensor(0.2720, grad_fn=<NllLossBackward>)
# train tensor(0.7559, grad_fn=<NllLossBackward>)
# train tensor(0.2361, grad_fn=<NllLossBackward>)
# train tensor(0.3367, grad_fn=<NllLossBackward>)
# train tensor(0.4426, grad_fn=<NllLossBackward>)
# train tensor(0.4446, grad_fn=<NllLossBackward>)
# train tensor(0.3806, grad_fn=<NllLossBackward>)
# train tensor(0.3143, grad_fn=<NllLossBackward>)
# train tensor(0.5267, grad_fn=<NllLossBackward>)
# train tensor(0.2672, grad_fn=<NllLossBackward>)
# train tensor(0.5077, grad_fn=<NllLossBackward>)
# train tensor(0.5612, grad_fn=<NllLossBackward>)
# train tensor(0.5153, grad_fn=<NllLossBackward>)
# train tensor(0.6535, grad_fn=<NllLossBackward>)
# train tensor(0.2838, grad_fn=<NllLossBackward>)
# train tensor(0.3831, grad_fn=<NllLossBackward>)
# train tensor(0.4029, grad_fn=<NllLossBackward>)
# train tensor(0.4513, grad_fn=<NllLossBackward>)
# train tensor(0.4154, grad_fn=<NllLossBackward>)
# train tensor(0.5410, grad_fn=<NllLossBackward>)
# train tensor(0.4922, grad_fn=<NllLossBackward>)
# train tensor(0.3349, grad_fn=<NllLossBackward>)
# train tensor(0.4996, grad_fn=<NllLossBackward>)
# train tensor(0.4530, grad_fn=<NllLossBackward>)
# train tensor(0.3634, grad_fn=<NllLossBackward>)
# train tensor(0.4009, grad_fn=<NllLossBackward>)
# train tensor(0.4394, grad_fn=<NllLossBackward>)
# train tensor(0.2758, grad_fn=<NllLossBackward>)
# train tensor(0.6826, grad_fn=<NllLossBackward>)
# train tensor(0.4629, grad_fn=<NllLossBackward>)
# train tensor(0.5484, grad_fn=<NllLossBackward>)
# train tensor(0.3156, grad_fn=<NllLossBackward>)
# train tensor(0.5105, grad_fn=<NllLossBackward>)
# train tensor(0.6705, grad_fn=<NllLossBackward>)
# train tensor(0.4515, grad_fn=<NllLossBackward>)
# train tensor(0.4879, grad_fn=<NllLossBackward>)
# train tensor(0.2561, grad_fn=<NllLossBackward>)
# train tensor(0.5127, grad_fn=<NllLossBackward>)
# train tensor(0.5430, grad_fn=<NllLossBackward>)
# train tensor(0.4140, grad_fn=<NllLossBackward>)
# train tensor(0.3940, grad_fn=<NllLossBackward>)
# train tensor(0.5830, grad_fn=<NllLossBackward>)
# train tensor(0.6864, grad_fn=<NllLossBackward>)
# train tensor(0.4044, grad_fn=<NllLossBackward>)
# train tensor(0.6572, grad_fn=<NllLossBackward>)
# train tensor(0.3277, grad_fn=<NllLossBackward>)
# train tensor(0.5063, grad_fn=<NllLossBackward>)
# train tensor(0.3665, grad_fn=<NllLossBackward>)
# train tensor(0.5917, grad_fn=<NllLossBackward>)
# train tensor(0.4546, grad_fn=<NllLossBackward>)
# train tensor(0.5072, grad_fn=<NllLossBackward>)
# train tensor(0.2863, grad_fn=<NllLossBackward>)
# train tensor(0.4769, grad_fn=<NllLossBackward>)
# train tensor(0.6356, grad_fn=<NllLossBackward>)
# train tensor(0.4326, grad_fn=<NllLossBackward>)
# train tensor(0.6372, grad_fn=<NllLossBackward>)
# train tensor(0.3161, grad_fn=<NllLossBackward>)
# train tensor(0.3802, grad_fn=<NllLossBackward>)
# train tensor(0.3254, grad_fn=<NllLossBackward>)
# train tensor(0.2520, grad_fn=<NllLossBackward>)
# train tensor(0.5477, grad_fn=<NllLossBackward>)
# train tensor(0.3203, grad_fn=<NllLossBackward>)
# train tensor(0.4349, grad_fn=<NllLossBackward>)
# train tensor(0.2741, grad_fn=<NllLossBackward>)
# train tensor(0.7067, grad_fn=<NllLossBackward>)
# train tensor(0.4416, grad_fn=<NllLossBackward>)
# train tensor(0.3963, grad_fn=<NllLossBackward>)
# train tensor(0.3592, grad_fn=<NllLossBackward>)
# train tensor(0.3408, grad_fn=<NllLossBackward>)
# train tensor(0.3583, grad_fn=<NllLossBackward>)
# train tensor(0.4164, grad_fn=<NllLossBackward>)
# train tensor(0.3941, grad_fn=<NllLossBackward>)
# train tensor(0.3817, grad_fn=<NllLossBackward>)
# train tensor(0.4100, grad_fn=<NllLossBackward>)
# train tensor(0.3410, grad_fn=<NllLossBackward>)
# train tensor(0.6062, grad_fn=<NllLossBackward>)
# train tensor(0.7374, grad_fn=<NllLossBackward>)
# train tensor(0.7833, grad_fn=<NllLossBackward>)
# train tensor(0.4469, grad_fn=<NllLossBackward>)
# train tensor(0.4587, grad_fn=<NllLossBackward>)
# train tensor(0.6649, grad_fn=<NllLossBackward>)
# train tensor(0.3168, grad_fn=<NllLossBackward>)
# train tensor(0.5944, grad_fn=<NllLossBackward>)
# train tensor(0.4430, grad_fn=<NllLossBackward>)
# train tensor(0.4058, grad_fn=<NllLossBackward>)
# train tensor(0.3209, grad_fn=<NllLossBackward>)
# train tensor(0.5902, grad_fn=<NllLossBackward>)
# train tensor(0.3830, grad_fn=<NllLossBackward>)
# train tensor(0.4479, grad_fn=<NllLossBackward>)
# train tensor(0.3451, grad_fn=<NllLossBackward>)
# train tensor(0.4505, grad_fn=<NllLossBackward>)
# train tensor(0.5386, grad_fn=<NllLossBackward>)
# train tensor(0.6314, grad_fn=<NllLossBackward>)
# train tensor(0.6244, grad_fn=<NllLossBackward>)
# train tensor(0.4305, grad_fn=<NllLossBackward>)
# train tensor(0.3600, grad_fn=<NllLossBackward>)
# train tensor(0.3159, grad_fn=<NllLossBackward>)
# train tensor(0.4187, grad_fn=<NllLossBackward>)
# train tensor(0.4541, grad_fn=<NllLossBackward>)
# train tensor(0.3242, grad_fn=<NllLossBackward>)
# train tensor(0.1607, grad_fn=<NllLossBackward>)
# train tensor(0.2986, grad_fn=<NllLossBackward>)
# train tensor(0.5905, grad_fn=<NllLossBackward>)
# train tensor(0.6395, grad_fn=<NllLossBackward>)
# train tensor(0.2990, grad_fn=<NllLossBackward>)
# train tensor(0.3792, grad_fn=<NllLossBackward>)
# train tensor(0.4070, grad_fn=<NllLossBackward>)
# train tensor(0.3260, grad_fn=<NllLossBackward>)
# train tensor(0.3382, grad_fn=<NllLossBackward>)
# train tensor(0.2624, grad_fn=<NllLossBackward>)
# train tensor(0.2863, grad_fn=<NllLossBackward>)
# train tensor(0.3033, grad_fn=<NllLossBackward>)
# train tensor(0.4417, grad_fn=<NllLossBackward>)
# train tensor(0.6115, grad_fn=<NllLossBackward>)
# train tensor(0.4224, grad_fn=<NllLossBackward>)
# train tensor(0.5637, grad_fn=<NllLossBackward>)
# train tensor(0.4734, grad_fn=<NllLossBackward>)
# train tensor(0.4587, grad_fn=<NllLossBackward>)
# train tensor(0.5959, grad_fn=<NllLossBackward>)
# train tensor(0.3751, grad_fn=<NllLossBackward>)
# train tensor(0.2985, grad_fn=<NllLossBackward>)
# train tensor(0.4488, grad_fn=<NllLossBackward>)
# train tensor(0.3169, grad_fn=<NllLossBackward>)
# train tensor(0.3112, grad_fn=<NllLossBackward>)
# train tensor(0.3162, grad_fn=<NllLossBackward>)
# train tensor(0.1626, grad_fn=<NllLossBackward>)
# train tensor(0.2257, grad_fn=<NllLossBackward>)
# train tensor(0.5710, grad_fn=<NllLossBackward>)
# train tensor(0.5333, grad_fn=<NllLossBackward>)
# train tensor(0.4225, grad_fn=<NllLossBackward>)
# train tensor(0.5951, grad_fn=<NllLossBackward>)
# train tensor(0.4776, grad_fn=<NllLossBackward>)
# train tensor(0.5589, grad_fn=<NllLossBackward>)
# train tensor(0.3219, grad_fn=<NllLossBackward>)
# train tensor(0.2620, grad_fn=<NllLossBackward>)
# train tensor(0.3967, grad_fn=<NllLossBackward>)
# train tensor(0.2997, grad_fn=<NllLossBackward>)
# train tensor(0.3061, grad_fn=<NllLossBackward>)
# train tensor(0.4658, grad_fn=<NllLossBackward>)
# train tensor(0.6227, grad_fn=<NllLossBackward>)
# train tensor(0.1659, grad_fn=<NllLossBackward>)
# train tensor(0.2876, grad_fn=<NllLossBackward>)
# train tensor(0.3652, grad_fn=<NllLossBackward>)
# train tensor(0.5077, grad_fn=<NllLossBackward>)
# train tensor(0.2713, grad_fn=<NllLossBackward>)
# train tensor(0.3190, grad_fn=<NllLossBackward>)
# train tensor(0.4951, grad_fn=<NllLossBackward>)
# train tensor(0.4012, grad_fn=<NllLossBackward>)
# train tensor(0.3887, grad_fn=<NllLossBackward>)
# train tensor(0.2929, grad_fn=<NllLossBackward>)
# train tensor(0.2646, grad_fn=<NllLossBackward>)
# train tensor(0.4917, grad_fn=<NllLossBackward>)
# train tensor(0.4335, grad_fn=<NllLossBackward>)
# train tensor(0.5022, grad_fn=<NllLossBackward>)
# train tensor(0.4802, grad_fn=<NllLossBackward>)
# train tensor(0.3796, grad_fn=<NllLossBackward>)
# train tensor(0.3131, grad_fn=<NllLossBackward>)
# train tensor(0.3043, grad_fn=<NllLossBackward>)
# train tensor(0.5524, grad_fn=<NllLossBackward>)
# train tensor(0.3561, grad_fn=<NllLossBackward>)
# train tensor(0.4438, grad_fn=<NllLossBackward>)
# train tensor(0.2538, grad_fn=<NllLossBackward>)
# train tensor(0.4092, grad_fn=<NllLossBackward>)
# train tensor(0.1974, grad_fn=<NllLossBackward>)
# train tensor(0.4628, grad_fn=<NllLossBackward>)
# train tensor(0.2801, grad_fn=<NllLossBackward>)
# train tensor(0.2721, grad_fn=<NllLossBackward>)
# train tensor(0.3723, grad_fn=<NllLossBackward>)
# train tensor(0.2258, grad_fn=<NllLossBackward>)
# train tensor(0.4408, grad_fn=<NllLossBackward>)
# train tensor(0.2282, grad_fn=<NllLossBackward>)
# train tensor(0.3430, grad_fn=<NllLossBackward>)
# train tensor(0.7729, grad_fn=<NllLossBackward>)
# train tensor(0.2162, grad_fn=<NllLossBackward>)
# train tensor(0.3206, grad_fn=<NllLossBackward>)
# train tensor(0.6492, grad_fn=<NllLossBackward>)
# train tensor(0.4821, grad_fn=<NllLossBackward>)
# train tensor(0.2405, grad_fn=<NllLossBackward>)
# train tensor(0.4214, grad_fn=<NllLossBackward>)
# train tensor(0.3914, grad_fn=<NllLossBackward>)
# train tensor(0.3051, grad_fn=<NllLossBackward>)
# train tensor(0.4169, grad_fn=<NllLossBackward>)
# train tensor(0.4955, grad_fn=<NllLossBackward>)
# train tensor(0.4732, grad_fn=<NllLossBackward>)
# train tensor(0.3013, grad_fn=<NllLossBackward>)
# train tensor(0.2773, grad_fn=<NllLossBackward>)
# train tensor(0.3115, grad_fn=<NllLossBackward>)
# train tensor(0.3195, grad_fn=<NllLossBackward>)
# train tensor(0.5387, grad_fn=<NllLossBackward>)
# train tensor(0.1346, grad_fn=<NllLossBackward>)
# train tensor(0.5866, grad_fn=<NllLossBackward>)
# train tensor(0.6705, grad_fn=<NllLossBackward>)
# train tensor(0.2836, grad_fn=<NllLossBackward>)
# train tensor(0.4486, grad_fn=<NllLossBackward>)
# train tensor(0.3605, grad_fn=<NllLossBackward>)
# train tensor(0.2704, grad_fn=<NllLossBackward>)
# train tensor(0.3049, grad_fn=<NllLossBackward>)
# train tensor(0.6916, grad_fn=<NllLossBackward>)
# train tensor(0.4498, grad_fn=<NllLossBackward>)
# train tensor(0.2676, grad_fn=<NllLossBackward>)
# train tensor(0.5491, grad_fn=<NllLossBackward>)
# train tensor(0.4545, grad_fn=<NllLossBackward>)
# train tensor(0.3946, grad_fn=<NllLossBackward>)
# train tensor(0.2665, grad_fn=<NllLossBackward>)
# train tensor(0.5404, grad_fn=<NllLossBackward>)
# train tensor(0.0560, grad_fn=<NllLossBackward>)
# tensor(0.3134, grad_fn=<AddBackward0>)
# tensor(0.8232, grad_fn=<AddBackward0>)
# tensor(1.3441, grad_fn=<AddBackward0>)
# tensor(1.9030, grad_fn=<AddBackward0>)
# tensor(2.4178, grad_fn=<AddBackward0>)
# tensor(2.7995, grad_fn=<AddBackward0>)
# tensor(3.0456, grad_fn=<AddBackward0>)
# tensor(3.4208, grad_fn=<AddBackward0>)
# tensor(3.6884, grad_fn=<AddBackward0>)
# tensor(4.1646, grad_fn=<AddBackward0>)
# tensor(4.5420, grad_fn=<AddBackward0>)
# tensor(4.7641, grad_fn=<AddBackward0>)
# tensor(5.0745, grad_fn=<AddBackward0>)
# tensor(5.3000, grad_fn=<AddBackward0>)
# tensor(5.5711, grad_fn=<AddBackward0>)
# tensor(5.9212, grad_fn=<AddBackward0>)
# tensor(6.5967, grad_fn=<AddBackward0>)
# tensor(6.9529, grad_fn=<AddBackward0>)
# tensor(7.2243, grad_fn=<AddBackward0>)
# tensor(7.4090, grad_fn=<AddBackward0>)
# tensor(7.6911, grad_fn=<AddBackward0>)
# tensor(8.2030, grad_fn=<AddBackward0>)
# tensor(8.8758, grad_fn=<AddBackward0>)
# tensor(9.3255, grad_fn=<AddBackward0>)
# tensor(9.6160, grad_fn=<AddBackward0>)
# tensor(9.9104, grad_fn=<AddBackward0>)
# tensor(10.1842, grad_fn=<AddBackward0>)
# tensor(10.6748, grad_fn=<AddBackward0>)
# tensor(11.0473, grad_fn=<AddBackward0>)
# tensor(11.3197, grad_fn=<AddBackward0>)
# tensor(11.7431, grad_fn=<AddBackward0>)
# tensor(12.1617, grad_fn=<AddBackward0>)
# tensor(12.4170, grad_fn=<AddBackward0>)
# tensor(12.6483, grad_fn=<AddBackward0>)
# tensor(12.9428, grad_fn=<AddBackward0>)
# tensor(13.2390, grad_fn=<AddBackward0>)
# tensor(13.4525, grad_fn=<AddBackward0>)
# tensor(13.7873, grad_fn=<AddBackward0>)
# tensor(14.3458, grad_fn=<AddBackward0>)
# tensor(14.7165, grad_fn=<AddBackward0>)
# tensor(14.9615, grad_fn=<AddBackward0>)
# tensor(15.2305, grad_fn=<AddBackward0>)
# tensor(15.5267, grad_fn=<AddBackward0>)
# tensor(15.8399, grad_fn=<AddBackward0>)
# tensor(16.1764, grad_fn=<AddBackward0>)
# tensor(16.4278, grad_fn=<AddBackward0>)
# tensor(16.6735, grad_fn=<AddBackward0>)
# tensor(16.8522, grad_fn=<AddBackward0>)
# tensor(17.2697, grad_fn=<AddBackward0>)
# tensor(17.6814, grad_fn=<AddBackward0>)
# tensor(18.1999, grad_fn=<AddBackward0>)
# tensor(18.4605, grad_fn=<AddBackward0>)
# tensor(18.6768, grad_fn=<AddBackward0>)
# tensor(18.9296, grad_fn=<AddBackward0>)
# tensor(19.1333, grad_fn=<AddBackward0>)
# tensor(19.4200, grad_fn=<AddBackward0>)
# tensor(19.7898, grad_fn=<AddBackward0>)
# tensor(20.0548, grad_fn=<AddBackward0>)
# tensor(20.3314, grad_fn=<AddBackward0>)
# tensor(20.7641, grad_fn=<AddBackward0>)
# tensor(21.1892, grad_fn=<AddBackward0>)
# tensor(21.4547, grad_fn=<AddBackward0>)
# tensor(21.8315, grad_fn=<AddBackward0>)
# tensor(22.0491, grad_fn=<AddBackward0>)
# tensor(22.1819, grad_fn=<AddBackward0>)
# tensor(22.4840, grad_fn=<AddBackward0>)
# tensor(22.6666, grad_fn=<AddBackward0>)
# tensor(22.9256, grad_fn=<AddBackward0>)
# tensor(23.0963, grad_fn=<AddBackward0>)
# tensor(23.3503, grad_fn=<AddBackward0>)
# tensor(23.4590, grad_fn=<AddBackward0>)
# tensor(23.5756, grad_fn=<AddBackward0>)
# tensor(23.9862, grad_fn=<AddBackward0>)
# tensor(24.5446, grad_fn=<AddBackward0>)
# tensor(24.6564, grad_fn=<AddBackward0>)
# tensor(25.2003, grad_fn=<AddBackward0>)
# tensor(25.6366, grad_fn=<AddBackward0>)
# tensor(25.9896, grad_fn=<AddBackward0>)
# tensor(26.1333, grad_fn=<AddBackward0>)
# Epoch 0: 0.331
# train tensor(0.4645, grad_fn=<NllLossBackward>)
# train tensor(0.4218, grad_fn=<NllLossBackward>)
# train tensor(0.4026, grad_fn=<NllLossBackward>)
# train tensor(0.3784, grad_fn=<NllLossBackward>)
# train tensor(0.4379, grad_fn=<NllLossBackward>)
# train tensor(0.2198, grad_fn=<NllLossBackward>)
# train tensor(0.2830, grad_fn=<NllLossBackward>)
# train tensor(0.3584, grad_fn=<NllLossBackward>)
# train tensor(0.3431, grad_fn=<NllLossBackward>)
# train tensor(0.3903, grad_fn=<NllLossBackward>)
# train tensor(0.3233, grad_fn=<NllLossBackward>)
# train tensor(0.2487, grad_fn=<NllLossBackward>)
# train tensor(0.1031, grad_fn=<NllLossBackward>)
# train tensor(0.2329, grad_fn=<NllLossBackward>)
# train tensor(0.3742, grad_fn=<NllLossBackward>)
# train tensor(0.3869, grad_fn=<NllLossBackward>)
# train tensor(0.4161, grad_fn=<NllLossBackward>)
# train tensor(0.7017, grad_fn=<NllLossBackward>)
# train tensor(0.3909, grad_fn=<NllLossBackward>)
# train tensor(0.3831, grad_fn=<NllLossBackward>)
# train tensor(0.5498, grad_fn=<NllLossBackward>)
# train tensor(0.5867, grad_fn=<NllLossBackward>)
# train tensor(0.2127, grad_fn=<NllLossBackward>)
# train tensor(0.8276, grad_fn=<NllLossBackward>)
# train tensor(0.5906, grad_fn=<NllLossBackward>)
# train tensor(0.2411, grad_fn=<NllLossBackward>)
# train tensor(0.3958, grad_fn=<NllLossBackward>)
# train tensor(0.4874, grad_fn=<NllLossBackward>)
# train tensor(0.5298, grad_fn=<NllLossBackward>)
# train tensor(0.2991, grad_fn=<NllLossBackward>)
# train tensor(0.3274, grad_fn=<NllLossBackward>)
# train tensor(0.2998, grad_fn=<NllLossBackward>)
# train tensor(0.4167, grad_fn=<NllLossBackward>)
# train tensor(0.6044, grad_fn=<NllLossBackward>)
# train tensor(0.4875, grad_fn=<NllLossBackward>)
# train tensor(0.3375, grad_fn=<NllLossBackward>)
# train tensor(0.3279, grad_fn=<NllLossBackward>)
# train tensor(0.2659, grad_fn=<NllLossBackward>)
# train tensor(0.4438, grad_fn=<NllLossBackward>)
# train tensor(0.4257, grad_fn=<NllLossBackward>)
# train tensor(0.3985, grad_fn=<NllLossBackward>)
# train tensor(0.2957, grad_fn=<NllLossBackward>)
# train tensor(0.4791, grad_fn=<NllLossBackward>)
# train tensor(0.5896, grad_fn=<NllLossBackward>)
# train tensor(0.3201, grad_fn=<NllLossBackward>)
# train tensor(0.3075, grad_fn=<NllLossBackward>)
# train tensor(0.2039, grad_fn=<NllLossBackward>)
# train tensor(0.2007, grad_fn=<NllLossBackward>)
# train tensor(0.3402, grad_fn=<NllLossBackward>)
# train tensor(0.3811, grad_fn=<NllLossBackward>)
# train tensor(0.2149, grad_fn=<NllLossBackward>)
# train tensor(0.4414, grad_fn=<NllLossBackward>)
# train tensor(0.5173, grad_fn=<NllLossBackward>)
# train tensor(0.3895, grad_fn=<NllLossBackward>)
# train tensor(0.4052, grad_fn=<NllLossBackward>)
# train tensor(0.6133, grad_fn=<NllLossBackward>)
# train tensor(0.3056, grad_fn=<NllLossBackward>)
# train tensor(0.3147, grad_fn=<NllLossBackward>)
# train tensor(0.4535, grad_fn=<NllLossBackward>)
# train tensor(0.3216, grad_fn=<NllLossBackward>)
# train tensor(0.3695, grad_fn=<NllLossBackward>)
# train tensor(0.4541, grad_fn=<NllLossBackward>)
# train tensor(0.3757, grad_fn=<NllLossBackward>)
# train tensor(0.6893, grad_fn=<NllLossBackward>)
# train tensor(0.5185, grad_fn=<NllLossBackward>)
# train tensor(0.3453, grad_fn=<NllLossBackward>)
# train tensor(0.2061, grad_fn=<NllLossBackward>)
# train tensor(0.2873, grad_fn=<NllLossBackward>)
# train tensor(0.2961, grad_fn=<NllLossBackward>)
# train tensor(0.3319, grad_fn=<NllLossBackward>)
# train tensor(0.3071, grad_fn=<NllLossBackward>)
# train tensor(0.2311, grad_fn=<NllLossBackward>)
# train tensor(0.5015, grad_fn=<NllLossBackward>)
# train tensor(0.5081, grad_fn=<NllLossBackward>)
# train tensor(0.4448, grad_fn=<NllLossBackward>)
# train tensor(0.2855, grad_fn=<NllLossBackward>)
# train tensor(0.3189, grad_fn=<NllLossBackward>)
# train tensor(0.2913, grad_fn=<NllLossBackward>)
# train tensor(0.3547, grad_fn=<NllLossBackward>)
# train tensor(0.2097, grad_fn=<NllLossBackward>)
# train tensor(0.2121, grad_fn=<NllLossBackward>)
# train tensor(0.2572, grad_fn=<NllLossBackward>)
# train tensor(0.4234, grad_fn=<NllLossBackward>)
# train tensor(0.4421, grad_fn=<NllLossBackward>)
# train tensor(0.2860, grad_fn=<NllLossBackward>)
# train tensor(0.2505, grad_fn=<NllLossBackward>)
# train tensor(0.4597, grad_fn=<NllLossBackward>)
# train tensor(0.2446, grad_fn=<NllLossBackward>)
# train tensor(0.2877, grad_fn=<NllLossBackward>)
# train tensor(0.4018, grad_fn=<NllLossBackward>)
# train tensor(0.6784, grad_fn=<NllLossBackward>)
# train tensor(0.2982, grad_fn=<NllLossBackward>)
# train tensor(0.3484, grad_fn=<NllLossBackward>)
# train tensor(0.3452, grad_fn=<NllLossBackward>)
# train tensor(0.3101, grad_fn=<NllLossBackward>)
# train tensor(0.2482, grad_fn=<NllLossBackward>)
# train tensor(0.3167, grad_fn=<NllLossBackward>)
# train tensor(0.5285, grad_fn=<NllLossBackward>)
# train tensor(0.3992, grad_fn=<NllLossBackward>)
# train tensor(0.5604, grad_fn=<NllLossBackward>)
# train tensor(0.4939, grad_fn=<NllLossBackward>)
# train tensor(0.3809, grad_fn=<NllLossBackward>)
# train tensor(0.4227, grad_fn=<NllLossBackward>)
# train tensor(0.3009, grad_fn=<NllLossBackward>)
# train tensor(0.4836, grad_fn=<NllLossBackward>)
# train tensor(0.3620, grad_fn=<NllLossBackward>)
# train tensor(0.7532, grad_fn=<NllLossBackward>)
# train tensor(0.3704, grad_fn=<NllLossBackward>)
# train tensor(0.3127, grad_fn=<NllLossBackward>)
# train tensor(0.4880, grad_fn=<NllLossBackward>)
# train tensor(0.2387, grad_fn=<NllLossBackward>)
# train tensor(0.3135, grad_fn=<NllLossBackward>)
# train tensor(0.2380, grad_fn=<NllLossBackward>)
# train tensor(0.3935, grad_fn=<NllLossBackward>)
# train tensor(0.3100, grad_fn=<NllLossBackward>)
# train tensor(0.2919, grad_fn=<NllLossBackward>)
# train tensor(0.2164, grad_fn=<NllLossBackward>)
# train tensor(0.3014, grad_fn=<NllLossBackward>)
# train tensor(0.3583, grad_fn=<NllLossBackward>)
# train tensor(0.2573, grad_fn=<NllLossBackward>)
# train tensor(0.5593, grad_fn=<NllLossBackward>)
# train tensor(0.3726, grad_fn=<NllLossBackward>)
# train tensor(0.2317, grad_fn=<NllLossBackward>)
# train tensor(0.4178, grad_fn=<NllLossBackward>)
# train tensor(0.2746, grad_fn=<NllLossBackward>)
# train tensor(0.1947, grad_fn=<NllLossBackward>)
# train tensor(0.4988, grad_fn=<NllLossBackward>)
# train tensor(0.4019, grad_fn=<NllLossBackward>)
# train tensor(0.2576, grad_fn=<NllLossBackward>)
# train tensor(0.1983, grad_fn=<NllLossBackward>)
# train tensor(0.2896, grad_fn=<NllLossBackward>)
# train tensor(0.3085, grad_fn=<NllLossBackward>)
# train tensor(0.4351, grad_fn=<NllLossBackward>)
# train tensor(0.1794, grad_fn=<NllLossBackward>)
# train tensor(0.1739, grad_fn=<NllLossBackward>)
# train tensor(0.3313, grad_fn=<NllLossBackward>)
# train tensor(0.3471, grad_fn=<NllLossBackward>)
# train tensor(0.4871, grad_fn=<NllLossBackward>)
# train tensor(0.2143, grad_fn=<NllLossBackward>)
# train tensor(0.5041, grad_fn=<NllLossBackward>)
# train tensor(0.3738, grad_fn=<NllLossBackward>)
# train tensor(0.2211, grad_fn=<NllLossBackward>)
# train tensor(0.1217, grad_fn=<NllLossBackward>)
# train tensor(0.2178, grad_fn=<NllLossBackward>)
# train tensor(0.3075, grad_fn=<NllLossBackward>)
# train tensor(0.3314, grad_fn=<NllLossBackward>)
# train tensor(0.4957, grad_fn=<NllLossBackward>)
# train tensor(0.1802, grad_fn=<NllLossBackward>)
# train tensor(0.2621, grad_fn=<NllLossBackward>)
# train tensor(0.3765, grad_fn=<NllLossBackward>)
# train tensor(0.4173, grad_fn=<NllLossBackward>)
# train tensor(0.5127, grad_fn=<NllLossBackward>)
# ...
# train tensor(0.4006, grad_fn=<NllLossBackward>)
# train tensor(0.4759, grad_fn=<NllLossBackward>)
# train tensor(0.2551, grad_fn=<NllLossBackward>)
# train tensor(0.2501, grad_fn=<NllLossBackward>)
# train tensor(0.2864, grad_fn=<NllLossBackward>)
# train tensor(0.4215, grad_fn=<NllLossBackward>)
# train tensor(0.2623, grad_fn=<NllLossBackward>)
# train tensor(0.2495, grad_fn=<NllLossBackward>)
# train tensor(0.2597, grad_fn=<NllLossBackward>)
# train tensor(0.2158, grad_fn=<NllLossBackward>)
# train tensor(0.4457, grad_fn=<NllLossBackward>)
# train tensor(0.3251, grad_fn=<NllLossBackward>)
# train tensor(0.4473, grad_fn=<NllLossBackward>)
# train tensor(0.2482, grad_fn=<NllLossBackward>)
# train tensor(0.3272, grad_fn=<NllLossBackward>)
# train tensor(0.2820, grad_fn=<NllLossBackward>)
# train tensor(0.3423, grad_fn=<NllLossBackward>)
# train tensor(0.4029, grad_fn=<NllLossBackward>)
# train tensor(0.1940, grad_fn=<NllLossBackward>)
# train tensor(0.2232, grad_fn=<NllLossBackward>)
# train tensor(0.3274, grad_fn=<NllLossBackward>)
# train tensor(0.4397, grad_fn=<NllLossBackward>)
# train tensor(0.3125, grad_fn=<NllLossBackward>)
# train tensor(0.3325, grad_fn=<NllLossBackward>)
# train tensor(0.3709, grad_fn=<NllLossBackward>)
# train tensor(0.2215, grad_fn=<NllLossBackward>)
# train tensor(0.4150, grad_fn=<NllLossBackward>)
# train tensor(0.2401, grad_fn=<NllLossBackward>)
# train tensor(0.2414, grad_fn=<NllLossBackward>)
# train tensor(0.2626, grad_fn=<NllLossBackward>)
# train tensor(0.2965, grad_fn=<NllLossBackward>)
# train tensor(0.2604, grad_fn=<NllLossBackward>)
# train tensor(0.2793, grad_fn=<NllLossBackward>)
# train tensor(0.4195, grad_fn=<NllLossBackward>)
# train tensor(0.2097, grad_fn=<NllLossBackward>)
# train tensor(0.3332, grad_fn=<NllLossBackward>)
# train tensor(0.3390, grad_fn=<NllLossBackward>)
# train tensor(0.2068, grad_fn=<NllLossBackward>)
# train tensor(0.1780, grad_fn=<NllLossBackward>)
# train tensor(0.3851, grad_fn=<NllLossBackward>)
# train tensor(0.2309, grad_fn=<NllLossBackward>)
# train tensor(0.1439, grad_fn=<NllLossBackward>)
# train tensor(0.3639, grad_fn=<NllLossBackward>)
# train tensor(0.3894, grad_fn=<NllLossBackward>)
# train tensor(0.1526, grad_fn=<NllLossBackward>)
# train tensor(0.5387, grad_fn=<NllLossBackward>)
# train tensor(0.3175, grad_fn=<NllLossBackward>)
# train tensor(0.2259, grad_fn=<NllLossBackward>)
# train tensor(0.4288, grad_fn=<NllLossBackward>)
# train tensor(0.0921, grad_fn=<NllLossBackward>)
# train tensor(0.3436, grad_fn=<NllLossBackward>)
# train tensor(0.3185, grad_fn=<NllLossBackward>)
# train tensor(0.5234, grad_fn=<NllLossBackward>)
# train tensor(0.3013, grad_fn=<NllLossBackward>)
# train tensor(0.1360, grad_fn=<NllLossBackward>)
# train tensor(0.2836, grad_fn=<NllLossBackward>)
# train tensor(0.2250, grad_fn=<NllLossBackward>)
# train tensor(0.6571, grad_fn=<NllLossBackward>)
# train tensor(0.4549, grad_fn=<NllLossBackward>)
# train tensor(0.2294, grad_fn=<NllLossBackward>)
# train tensor(0.2225, grad_fn=<NllLossBackward>)
# train tensor(0.2486, grad_fn=<NllLossBackward>)
# train tensor(0.2467, grad_fn=<NllLossBackward>)
# train tensor(0.2944, grad_fn=<NllLossBackward>)
# train tensor(0.2975, grad_fn=<NllLossBackward>)
# train tensor(0.3855, grad_fn=<NllLossBackward>)
# train tensor(0.1837, grad_fn=<NllLossBackward>)
# train tensor(0.3447, grad_fn=<NllLossBackward>)
# train tensor(0.4219, grad_fn=<NllLossBackward>)
# train tensor(0.3163, grad_fn=<NllLossBackward>)
# train tensor(0.1666, grad_fn=<NllLossBackward>)
# train tensor(0.1374, grad_fn=<NllLossBackward>)
# train tensor(0.1620, grad_fn=<NllLossBackward>)
# train tensor(0.3868, grad_fn=<NllLossBackward>)
# train tensor(0.2092, grad_fn=<NllLossBackward>)
# train tensor(0.1355, grad_fn=<NllLossBackward>)
# train tensor(0.3365, grad_fn=<NllLossBackward>)
# train tensor(0.4380, grad_fn=<NllLossBackward>)
# train tensor(0.3074, grad_fn=<NllLossBackward>)
# train tensor(0.3308, grad_fn=<NllLossBackward>)
# train tensor(0.2625, grad_fn=<NllLossBackward>)
# train tensor(0.1803, grad_fn=<NllLossBackward>)
# train tensor(0.1804, grad_fn=<NllLossBackward>)
# train tensor(0.2160, grad_fn=<NllLossBackward>)
# train tensor(0.2739, grad_fn=<NllLossBackward>)
# train tensor(0.2063, grad_fn=<NllLossBackward>)
# train tensor(0.1940, grad_fn=<NllLossBackward>)
# train tensor(0.3115, grad_fn=<NllLossBackward>)
# train tensor(0.4745, grad_fn=<NllLossBackward>)
# train tensor(0.3947, grad_fn=<NllLossBackward>)
# train tensor(0.2639, grad_fn=<NllLossBackward>)
# train tensor(0.2028, grad_fn=<NllLossBackward>)
# train tensor(0.2498, grad_fn=<NllLossBackward>)
# train tensor(0.1724, grad_fn=<NllLossBackward>)
# train tensor(0.3670, grad_fn=<NllLossBackward>)
# train tensor(0.3381, grad_fn=<NllLossBackward>)
# train tensor(0.1467, grad_fn=<NllLossBackward>)
# train tensor(0.5043, grad_fn=<NllLossBackward>)
# train tensor(0.3643, grad_fn=<NllLossBackward>)
# train tensor(0.3791, grad_fn=<NllLossBackward>)
# train tensor(0.1619, grad_fn=<NllLossBackward>)
# train tensor(0.2575, grad_fn=<NllLossBackward>)
# train tensor(0.2532, grad_fn=<NllLossBackward>)
# train tensor(0.2558, grad_fn=<NllLossBackward>)
# train tensor(0.2311, grad_fn=<NllLossBackward>)
# train tensor(0.3745, grad_fn=<NllLossBackward>)
# train tensor(0.3193, grad_fn=<NllLossBackward>)
# train tensor(0.3276, grad_fn=<NllLossBackward>)
# train tensor(0.3910, grad_fn=<NllLossBackward>)
# train tensor(0.3952, grad_fn=<NllLossBackward>)
# train tensor(0.1816, grad_fn=<NllLossBackward>)
# train tensor(0.1369, grad_fn=<NllLossBackward>)
# train tensor(0.1406, grad_fn=<NllLossBackward>)
# train tensor(0.1698, grad_fn=<NllLossBackward>)
# train tensor(0.2901, grad_fn=<NllLossBackward>)
# train tensor(0.1973, grad_fn=<NllLossBackward>)
# train tensor(0.6096, grad_fn=<NllLossBackward>)
# train tensor(0.1274, grad_fn=<NllLossBackward>)
# train tensor(0.1583, grad_fn=<NllLossBackward>)
# train tensor(0.2012, grad_fn=<NllLossBackward>)
# train tensor(0.1484, grad_fn=<NllLossBackward>)
# train tensor(0.1676, grad_fn=<NllLossBackward>)
# train tensor(0.3313, grad_fn=<NllLossBackward>)
# train tensor(0.3473, grad_fn=<NllLossBackward>)
# train tensor(0.3351, grad_fn=<NllLossBackward>)
# train tensor(0.2227, grad_fn=<NllLossBackward>)
# train tensor(0.3263, grad_fn=<NllLossBackward>)
# train tensor(0.1580, grad_fn=<NllLossBackward>)
# train tensor(0.3931, grad_fn=<NllLossBackward>)
# train tensor(0.1628, grad_fn=<NllLossBackward>)
# train tensor(0.3926, grad_fn=<NllLossBackward>)
# train tensor(0.4027, grad_fn=<NllLossBackward>)
# train tensor(0.1492, grad_fn=<NllLossBackward>)
# train tensor(0.5285, grad_fn=<NllLossBackward>)
# train tensor(0.2626, grad_fn=<NllLossBackward>)
# train tensor(0.2334, grad_fn=<NllLossBackward>)
# train tensor(0.3141, grad_fn=<NllLossBackward>)
# train tensor(0.2612, grad_fn=<NllLossBackward>)
# train tensor(0.2039, grad_fn=<NllLossBackward>)
# train tensor(0.2378, grad_fn=<NllLossBackward>)
# train tensor(0.2804, grad_fn=<NllLossBackward>)
# train tensor(0.1200, grad_fn=<NllLossBackward>)
# train tensor(0.2257, grad_fn=<NllLossBackward>)
# train tensor(0.4595, grad_fn=<NllLossBackward>)
# train tensor(0.3602, grad_fn=<NllLossBackward>)
# train tensor(0.3152, grad_fn=<NllLossBackward>)
# train tensor(0.1946, grad_fn=<NllLossBackward>)
# train tensor(0.2203, grad_fn=<NllLossBackward>)
# train tensor(0.3972, grad_fn=<NllLossBackward>)
# train tensor(0.2960, grad_fn=<NllLossBackward>)
# train tensor(0.2537, grad_fn=<NllLossBackward>)
# train tensor(0.5892, grad_fn=<NllLossBackward>)
# train tensor(0.2491, grad_fn=<NllLossBackward>)
# train tensor(0.2730, grad_fn=<NllLossBackward>)
# train tensor(0.2671, grad_fn=<NllLossBackward>)
# train tensor(0.3116, grad_fn=<NllLossBackward>)
# train tensor(0.1534, grad_fn=<NllLossBackward>)
# train tensor(0.2758, grad_fn=<NllLossBackward>)
# train tensor(0.2504, grad_fn=<NllLossBackward>)
# train tensor(0.3333, grad_fn=<NllLossBackward>)
# train tensor(0.2676, grad_fn=<NllLossBackward>)
# train tensor(0.2415, grad_fn=<NllLossBackward>)
# train tensor(0.1731, grad_fn=<NllLossBackward>)
# train tensor(0.2346, grad_fn=<NllLossBackward>)
# train tensor(0.2100, grad_fn=<NllLossBackward>)
# train tensor(0.1843, grad_fn=<NllLossBackward>)
# train tensor(0.1231, grad_fn=<NllLossBackward>)
# train tensor(0.1789, grad_fn=<NllLossBackward>)
# train tensor(0.5951, grad_fn=<NllLossBackward>)
# train tensor(0.2153, grad_fn=<NllLossBackward>)
# train tensor(0.4192, grad_fn=<NllLossBackward>)
# train tensor(0.2887, grad_fn=<NllLossBackward>)
# train tensor(0.2246, grad_fn=<NllLossBackward>)
# train tensor(0.2705, grad_fn=<NllLossBackward>)
# train tensor(0.3504, grad_fn=<NllLossBackward>)
# train tensor(0.3722, grad_fn=<NllLossBackward>)
# train tensor(0.3112, grad_fn=<NllLossBackward>)
# train tensor(0.2128, grad_fn=<NllLossBackward>)
# train tensor(0.3780, grad_fn=<NllLossBackward>)
# train tensor(0.2167, grad_fn=<NllLossBackward>)
# train tensor(0.2204, grad_fn=<NllLossBackward>)
# train tensor(0.3023, grad_fn=<NllLossBackward>)
# train tensor(0.2374, grad_fn=<NllLossBackward>)
# train tensor(0.2251, grad_fn=<NllLossBackward>)
# train tensor(0.2492, grad_fn=<NllLossBackward>)
# train tensor(0.2539, grad_fn=<NllLossBackward>)
# train tensor(0.5335, grad_fn=<NllLossBackward>)
# train tensor(0.6201, grad_fn=<NllLossBackward>)
# train tensor(0.2866, grad_fn=<NllLossBackward>)
# train tensor(0.2196, grad_fn=<NllLossBackward>)
# train tensor(0.2333, grad_fn=<NllLossBackward>)
# train tensor(0.4563, grad_fn=<NllLossBackward>)
# train tensor(0.3020, grad_fn=<NllLossBackward>)
# train tensor(0.2944, grad_fn=<NllLossBackward>)
# train tensor(0.1976, grad_fn=<NllLossBackward>)
# train tensor(0.2443, grad_fn=<NllLossBackward>)
# train tensor(0.4449, grad_fn=<NllLossBackward>)
# train tensor(0.3935, grad_fn=<NllLossBackward>)
# train tensor(0.2220, grad_fn=<NllLossBackward>)
# train tensor(0.2820, grad_fn=<NllLossBackward>)
# train tensor(0.2955, grad_fn=<NllLossBackward>)
# train tensor(0.1033, grad_fn=<NllLossBackward>)
# train tensor(0.1940, grad_fn=<NllLossBackward>)
# train tensor(0.0989, grad_fn=<NllLossBackward>)
# train tensor(0.3926, grad_fn=<NllLossBackward>)
# train tensor(0.2926, grad_fn=<NllLossBackward>)
# train tensor(0.0564, grad_fn=<NllLossBackward>)
# train tensor(0.3015, grad_fn=<NllLossBackward>)
# train tensor(0.2523, grad_fn=<NllLossBackward>)
# train tensor(0.1835, grad_fn=<NllLossBackward>)
# train tensor(0.3970, grad_fn=<NllLossBackward>)
# train tensor(0.2322, grad_fn=<NllLossBackward>)
# train tensor(0.2380, grad_fn=<NllLossBackward>)
# train tensor(0.3311, grad_fn=<NllLossBackward>)
# train tensor(0.2564, grad_fn=<NllLossBackward>)
# train tensor(0.1851, grad_fn=<NllLossBackward>)
# train tensor(0.3197, grad_fn=<NllLossBackward>)
# train tensor(0.3609, grad_fn=<NllLossBackward>)
# train tensor(0.3316, grad_fn=<NllLossBackward>)
# train tensor(0.4678, grad_fn=<NllLossBackward>)
# train tensor(0.3838, grad_fn=<NllLossBackward>)
# train tensor(0.2038, grad_fn=<NllLossBackward>)
# train tensor(0.3192, grad_fn=<NllLossBackward>)
# train tensor(0.3085, grad_fn=<NllLossBackward>)
# train tensor(0.2271, grad_fn=<NllLossBackward>)
# train tensor(0.2316, grad_fn=<NllLossBackward>)
# train tensor(0.1018, grad_fn=<NllLossBackward>)
# train tensor(0.2586, grad_fn=<NllLossBackward>)
# train tensor(0.1327, grad_fn=<NllLossBackward>)
# train tensor(0.3840, grad_fn=<NllLossBackward>)
# train tensor(0.5828, grad_fn=<NllLossBackward>)
# train tensor(0.2273, grad_fn=<NllLossBackward>)
# train tensor(0.3639, grad_fn=<NllLossBackward>)
# train tensor(0.3597, grad_fn=<NllLossBackward>)
# train tensor(0.2809, grad_fn=<NllLossBackward>)
# train tensor(0.2118, grad_fn=<NllLossBackward>)
# train tensor(0.1992, grad_fn=<NllLossBackward>)
# train tensor(0.5066, grad_fn=<NllLossBackward>)
# train tensor(0.1879, grad_fn=<NllLossBackward>)
# train tensor(0.4425, grad_fn=<NllLossBackward>)
# train tensor(0.3066, grad_fn=<NllLossBackward>)
# train tensor(0.3409, grad_fn=<NllLossBackward>)
# train tensor(0.3200, grad_fn=<NllLossBackward>)
# train tensor(0.3602, grad_fn=<NllLossBackward>)
# train tensor(0.4652, grad_fn=<NllLossBackward>)
# train tensor(0.3187, grad_fn=<NllLossBackward>)
# train tensor(0.3974, grad_fn=<NllLossBackward>)
# train tensor(0.5273, grad_fn=<NllLossBackward>)
# train tensor(0.3458, grad_fn=<NllLossBackward>)
# train tensor(0.3821, grad_fn=<NllLossBackward>)
# train tensor(0.2389, grad_fn=<NllLossBackward>)
# train tensor(0.4087, grad_fn=<NllLossBackward>)
# train tensor(0.3603, grad_fn=<NllLossBackward>)
# train tensor(0.2624, grad_fn=<NllLossBackward>)
# train tensor(0.3640, grad_fn=<NllLossBackward>)
# train tensor(0.2228, grad_fn=<NllLossBackward>)
# train tensor(0.2283, grad_fn=<NllLossBackward>)
# train tensor(0.2527, grad_fn=<NllLossBackward>)
# train tensor(0.4724, grad_fn=<NllLossBackward>)
# train tensor(0.2801, grad_fn=<NllLossBackward>)
# train tensor(0.3468, grad_fn=<NllLossBackward>)
# train tensor(0.3034, grad_fn=<NllLossBackward>)
# train tensor(0.2940, grad_fn=<NllLossBackward>)
# train tensor(0.3072, grad_fn=<NllLossBackward>)
# train tensor(0.3013, grad_fn=<NllLossBackward>)
# train tensor(0.2719, grad_fn=<NllLossBackward>)
# train tensor(0.0895, grad_fn=<NllLossBackward>)
# tensor(0.2131, grad_fn=<AddBackward0>)
# tensor(0.5583, grad_fn=<AddBackward0>)
# tensor(0.9527, grad_fn=<AddBackward0>)
# tensor(1.3609, grad_fn=<AddBackward0>)
# tensor(1.7563, grad_fn=<AddBackward0>)
# tensor(2.0437, grad_fn=<AddBackward0>)
# tensor(2.2685, grad_fn=<AddBackward0>)
# tensor(2.5335, grad_fn=<AddBackward0>)
# tensor(2.7190, grad_fn=<AddBackward0>)
# tensor(3.1278, grad_fn=<AddBackward0>)
# tensor(3.4530, grad_fn=<AddBackward0>)
# tensor(3.7133, grad_fn=<AddBackward0>)
# tensor(3.9950, grad_fn=<AddBackward0>)
# tensor(4.2208, grad_fn=<AddBackward0>)
# tensor(4.4623, grad_fn=<AddBackward0>)
# tensor(4.8021, grad_fn=<AddBackward0>)
# tensor(5.2368, grad_fn=<AddBackward0>)
# tensor(5.4990, grad_fn=<AddBackward0>)
# tensor(5.6960, grad_fn=<AddBackward0>)
# tensor(5.8131, grad_fn=<AddBackward0>)
# tensor(6.0160, grad_fn=<AddBackward0>)
# tensor(6.4574, grad_fn=<AddBackward0>)
# tensor(6.9702, grad_fn=<AddBackward0>)
# tensor(7.4005, grad_fn=<AddBackward0>)
# tensor(7.6653, grad_fn=<AddBackward0>)
# tensor(7.9481, grad_fn=<AddBackward0>)
# tensor(8.0653, grad_fn=<AddBackward0>)
# tensor(8.4075, grad_fn=<AddBackward0>)
# tensor(8.6787, grad_fn=<AddBackward0>)
# tensor(8.8900, grad_fn=<AddBackward0>)
# tensor(9.1821, grad_fn=<AddBackward0>)
# tensor(9.5527, grad_fn=<AddBackward0>)
# tensor(9.7512, grad_fn=<AddBackward0>)
# tensor(9.9250, grad_fn=<AddBackward0>)
# tensor(10.1795, grad_fn=<AddBackward0>)
# tensor(10.4330, grad_fn=<AddBackward0>)
# tensor(10.5641, grad_fn=<AddBackward0>)
# tensor(10.8069, grad_fn=<AddBackward0>)
# tensor(11.2517, grad_fn=<AddBackward0>)
# tensor(11.5317, grad_fn=<AddBackward0>)
# tensor(11.7064, grad_fn=<AddBackward0>)
# tensor(11.9400, grad_fn=<AddBackward0>)
# tensor(12.1344, grad_fn=<AddBackward0>)
# tensor(12.3833, grad_fn=<AddBackward0>)
# tensor(12.6452, grad_fn=<AddBackward0>)
# tensor(12.9033, grad_fn=<AddBackward0>)
# tensor(13.0784, grad_fn=<AddBackward0>)
# tensor(13.1953, grad_fn=<AddBackward0>)
# tensor(13.4636, grad_fn=<AddBackward0>)
# tensor(13.7095, grad_fn=<AddBackward0>)
# tensor(14.1184, grad_fn=<AddBackward0>)
# tensor(14.3905, grad_fn=<AddBackward0>)
# tensor(14.5637, grad_fn=<AddBackward0>)
# tensor(14.7991, grad_fn=<AddBackward0>)
# tensor(14.9657, grad_fn=<AddBackward0>)
# tensor(15.1925, grad_fn=<AddBackward0>)
# tensor(15.5397, grad_fn=<AddBackward0>)
# tensor(15.8630, grad_fn=<AddBackward0>)
# tensor(16.0507, grad_fn=<AddBackward0>)
# tensor(16.4367, grad_fn=<AddBackward0>)
# tensor(16.7657, grad_fn=<AddBackward0>)
# tensor(17.0189, grad_fn=<AddBackward0>)
# tensor(17.2855, grad_fn=<AddBackward0>)
# tensor(17.4296, grad_fn=<AddBackward0>)
# tensor(17.5166, grad_fn=<AddBackward0>)
# tensor(17.6487, grad_fn=<AddBackward0>)
# tensor(17.8128, grad_fn=<AddBackward0>)
# tensor(17.9746, grad_fn=<AddBackward0>)
# tensor(18.1351, grad_fn=<AddBackward0>)
# tensor(18.2887, grad_fn=<AddBackward0>)
# tensor(18.3489, grad_fn=<AddBackward0>)
# tensor(18.4768, grad_fn=<AddBackward0>)
# tensor(18.8025, grad_fn=<AddBackward0>)
# tensor(19.4604, grad_fn=<AddBackward0>)
# tensor(19.5254, grad_fn=<AddBackward0>)
# tensor(20.0416, grad_fn=<AddBackward0>)
# tensor(20.4370, grad_fn=<AddBackward0>)
# tensor(20.6549, grad_fn=<AddBackward0>)
# tensor(20.7216, grad_fn=<AddBackward0>)
# Epoch 1: 0.262

# %% [markdown]
# # GPUs

# %% [markdown]
# PyTorch can run significantly faster on a GPU than on a CPU, so you should always try to leverage that hardware. To do so, you need to move both your model and your data to the device.
#
# So let's first check if you have a GPU and choose the appropriate device.

# %%
print(torch.cuda.is_available())
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# Out:
# False

# %% [markdown]
# Next, we move our model to the device.

# %%
model.to(device);

# %% [markdown]
# Then, we redefine the DataLoader to pin the memory. This is a trick that will accelerate moving data between CPU and GPU.

# %%
dataloaders = {}
dataloaders['train'] = DataLoader(train_set, batch_size=batch_size, shuffle=True, pin_memory=True)
dataloaders['val'] = DataLoader(val_set, batch_size=2 * batch_size, pin_memory=True)

# %% [markdown]
# Finally, we need to slightly change our training loop to send each batch to the device first.

# %%
def fit(model, optimizer, dataloaders, num_epochs):
    for epoch in range(num_epochs):
        
        # Training
        model.train()
        for xb, yb in dataloaders['train']:
            xb, yb = xb.to(device), yb.to(device)
            
            pred = model(xb)
            loss = loss_fn(pred, yb)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        # Evaluation
        model.eval()
        loss = 0
        for xb, yb in dataloaders['val']:
            xb, yb = xb.to(device), yb.to(device)
            
            pred = model(xb)
            loss += loss_fn(pred, yb).sum()
            
        avg_loss = loss / len(dataloaders['val'])
            
        print(f"Epoch {epoch}: {avg_loss:.3f}")

# %% [markdown]
# And now we can run our CNN on the GPU!

# %%
model.apply(initialize_weight)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)

fit(model, optimizer, dataloaders, num_epochs=2)
# Out:
# Epoch 0: 0.470
# Epoch 1: 0.283

# %% [markdown]
# # Summary
# Great, so now we have a concise, but general training loop and know how to quickly define new models! Now let us sum up what we have learned during this journey:
# - `torch.tensor`: PyTorch tensors work like Numpy arrays, but can remember gradients and be sent to the GPU.
# - `torch.nn`
#     - `torch.nn.functional`: Provides various useful functions (non stateful) for training neural networks, e.g. activation and loss functions.
#     - `nn.Module`: Subclass from this to create a callable that acts like a function, but can remember state. It knows what `Parameter`s and submodules it contains and provides various functionality based on that.
#     - `nn.Parameter`: Wraps a tensor and tells the containing Module that it needs updating during backpropagation.
#     - `torch.nn`: Many useful layers are already implemented in this library, e.g. `nn.Linear` or `nn.Conv2d`.
#     - `nn.Sequential`: Provides an easy way of defining purely stacked modules.
# - `torch.optim`: Optimizers such as `SGD` or `Adam`, which let you easily update and train the `Parameter`s inside the passed model.
# - `Dataset`: Interface for data using only the `__len__` and `__getitem__` functions. Tensors can be converted into a `Dataset` by using `TensorDataset`.
# - `DataLoader`: Takes any `Dataset` and provides an iterator for returning mini-batches with various advanced functionality.
# - `GPU`: To use your GPU you need to move your model and each mini-batch to your GPU using `.to(device)`.
